# %% [markdown]
# # Part 2 - Enriching Study Areas

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Enriching-Study-Areas" data-toc-modified-id="Enriching-Study-Areas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Enriching Study Areas</a></span><ul class="toc-item"><li><span><a href="#Data-collections-and-analysis-variables" data-toc-modified-id="Data-collections-and-analysis-variables-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data collections and analysis variables</a></span></li><li><span><a href="#Enriching-street-address" data-toc-modified-id="Enriching-street-address-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Enriching street address</a></span><ul class="toc-item"><li><span><a href="#Single-line-address" data-toc-modified-id="Single-line-address-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Single line address</a></span><ul class="toc-item"><li><span><a href="#Visualize-results-on-a-map" data-toc-modified-id="Visualize-results-on-a-map-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>Visualize results on a map</a></span></li></ul></li><li><span><a href="#Multiple-field-input" data-toc-modified-id="Multiple-field-input-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Multiple field input</a></span></li></ul></li><li><span><a href="#Enriching-point,-line-and-polygon-geometries" data-toc-modified-id="Enriching-point,-line-and-polygon-geometries-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Enriching point, line and polygon geometries</a></span><ul class="toc-item"><li><span><a href="#Single-Point-described-as-map-coordinates" data-toc-modified-id="Single-Point-described-as-map-coordinates-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Single Point described as map coordinates</a></span></li><li><span><a href="#Multiple-points-with-attributes-described-as-map-coordinates" data-toc-modified-id="Multiple-points-with-attributes-described-as-map-coordinates-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Multiple points with attributes described as map coordinates</a></span></li><li><span><a href="#Line-feature-described-as-geometry" data-toc-modified-id="Line-feature-described-as-geometry-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Line feature described as geometry</a></span><ul class="toc-item"><li><span><a href="#Visualize-results-on-a-map" data-toc-modified-id="Visualize-results-on-a-map-1.3.3.1"><span class="toc-item-num">1.3.3.1&nbsp;&nbsp;</span>Visualize results on a map</a></span></li></ul></li><li><span><a href="#Map-area-described-as-polygons" data-toc-modified-id="Map-area-described-as-polygons-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Map area described as polygons</a></span></li></ul></li><li><span><a href="#Enriching-Buffered-study-areas" data-toc-modified-id="Enriching-Buffered-study-areas-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Enriching Buffered study areas</a></span><ul class="toc-item"><li><span><a href="#Buffering-location-using-driving-distance" data-toc-modified-id="Buffering-location-using-driving-distance-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Buffering location using driving distance</a></span><ul class="toc-item"><li><span><a href="#Visualize-results-on-a-map" data-toc-modified-id="Visualize-results-on-a-map-1.4.1.1"><span class="toc-item-num">1.4.1.1&nbsp;&nbsp;</span>Visualize results on a map</a></span></li></ul></li><li><span><a href="#Buffering-location-using-drive-times" data-toc-modified-id="Buffering-location-using-drive-times-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Buffering location using drive times</a></span><ul class="toc-item"><li><span><a href="#Visualize-results-on-a-map" data-toc-modified-id="Visualize-results-on-a-map-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>Visualize results on a map</a></span></li></ul></li></ul></li><li><span><a href="#Enriching-a-named-statistical-area" data-toc-modified-id="Enriching-a-named-statistical-area-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Enriching a named statistical area</a></span><ul class="toc-item"><li><span><a href="#Enriching-a-zip-code" data-toc-modified-id="Enriching-a-zip-code-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Enriching a zip code</a></span><ul class="toc-item"><li><span><a href="#Visualize-results-on-a-map" data-toc-modified-id="Visualize-results-on-a-map-1.5.1.1"><span class="toc-item-num">1.5.1.1&nbsp;&nbsp;</span>Visualize results on a map</a></span></li></ul></li><li><span><a href="#Enriching-all-counties-in-a-state" data-toc-modified-id="Enriching-all-counties-in-a-state-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Enriching all counties in a state</a></span><ul class="toc-item"><li><span><a href="#Visualize-results-on-a-map" data-toc-modified-id="Visualize-results-on-a-map-1.5.2.1"><span class="toc-item-num">1.5.2.1&nbsp;&nbsp;</span>Visualize results on a map</a></span></li></ul></li><li><span><a href="#Using-comparison-levels" data-toc-modified-id="Using-comparison-levels-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Using comparison levels</a></span></li></ul></li><li><span><a href="#Enriching-Arbitrary-Geometries" data-toc-modified-id="Enriching-Arbitrary-Geometries-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Enriching Arbitrary Geometries</a></span><ul class="toc-item"><li><span><a href="#Create-a-Map" data-toc-modified-id="Create-a-Map-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Create a Map</a></span></li><li><span><a href="#Enable-User-Input" data-toc-modified-id="Enable-User-Input-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Enable User Input</a></span></li><li><span><a href="#Enrich-Drawn-Geometry" data-toc-modified-id="Enrich-Drawn-Geometry-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Enrich Drawn Geometry</a></span></li><li><span><a href="#Visualize-Enriched-Geometry" data-toc-modified-id="Visualize-Enriched-Geometry-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>Visualize Enriched Geometry</a></span></li></ul></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# ## Enriching Study Areas
# GeoEnrichment uses the concept of a study area to define the location of the point or area that you want to enrich with additional information or create reports about. The accepted forms of study areas are:
# 1. Street address locations
#     - a. Single line input
#     - b. Multiple field input
# 2. Point, line and polygon geometries
# 3. Buffered study areas
# 4. Named statistical areas
#
# Before we look at the exmaples of study areas, let's understand the concept of Data collections and analysis variables. We will look at Data collections in detail in a later section.

# %% [markdown]
# ### Data collections and analysis variables
# GeoEnrichment uses the concept of a data collection to define the data attributes returned by the enrichment service. A data collection is a preassembled list of attributes that will be used to enrich the input features. Collection attributes can describe various types of information, such as demographic characteristics and geographic context of the locations or areas submitted as input features. We will introduce the concept of data collections here and look at the details in the next guide.
#
# The `Country` class can be used to discover the data collections, sub-geographies and available reports for a country. When working with a particular country, you will find it convenient to get a reference to it using the Country.get() method.
#
# The `data_collections` property of a `Country` object lists a combination of available data collections and analysis variables for each data collection as a [Pandas](https://pandas.pydata.org/) dataframe.
#
# Once we know the data collection we would like to use, we can look at all the unique `analysisVariable`  available in that data collection.

# %%
# Import Libraries
from arcgis.gis import GIS
from arcgis.geoenrichment import *

# %%
# Create a GIS Connection
gis = GIS(profile='your_online_profile')

# %%
# Get US as a country
usa = Country.get('US')
type(usa)
# Out:
# arcgis.geoenrichment.enrichment.Country

# %%
df = usa.data_collections

# print a few rows of the DataFrame
df.head()
# Out:
#                          analysisVariable                   alias  \
# dataCollectionID
# 1yearincrements   1yearincrements.AGE0_CY  2020 Population Age <1
# 1yearincrements   1yearincrements.AGE1_CY   2020 Population Age 1
# 1yearincrements   1yearincrements.AGE2_CY   2020 Population Age 2
# 1yearincrements   1yearincrements.AGE3_CY   2020 Population Age 3
# 1yearincrements   1yearincrements.AGE4_CY   2020 Population Age 4
#
#                                        fieldCategory vintage
# dataCollectionID
# 1yearincrements   2020 Age: 1 Year Increments (Esri)    2020
# 1yearincrements   2020 Age: 1 Year Increments (Esri)    2020
# 1yearincrements   2020 Age: 1 Year Increments (Esri)    2020
# 1yearincrements   2020 Age: 1 Year Increments (Esri)    2020
# 1yearincrements   2020 Age: 1 Year Increments (Esri)    2020

# %%
# call the shape property to get the total number of rows and columns
df.shape
# Out:
# (17608, 4)

# %% [markdown]
# Each data collection and analysis variable has a unique ID. When calling the `enrich()` method, these analysis variables can be passed in the `data_collections` and `analysis_variables` parameters.
#
# You can filter the `data_collections` and query the collections `analysis_variables` using Pandas expressions.

# %%
# get all the unique data collections available
df.index.unique()
# Out:
# Index(['1yearincrements', '5yearincrements', 'ACS_Housing_Summary_rep',
#        'ACS_Population_Summary_rep', 'Age', 'AgeDependency',
#        'Age_50_Profile_rep', 'Age_by_Sex_Profile_rep',
#        'Age_by_Sex_by_Race_Profile_rep', 'AtRisk',
#        ...
#        'transportation', 'travelMPI', 'unitsinstructure',
#        'urbanizationgroupsNEW', 'vacant', 'vehiclesavailable', 'veterans',
#        'women', 'yearbuilt', 'yearmovedin'],
#       dtype='object', name='dataCollectionID', length=150)

# %% [markdown]
# The snippet below shows how you can query the `Age` data collection and get all the unique `analysisVariable`s under that collection.

# %%
df.loc['Age']['analysisVariable'].unique()
# Out:
# array(['Age.MALE0', 'Age.MALE5', 'Age.MALE10', 'Age.MALE15', 'Age.MALE20',
#        'Age.MALE25', 'Age.MALE30', 'Age.MALE35', 'Age.MALE40',
#        'Age.MALE45', 'Age.MALE50', 'Age.MALE55', 'Age.MALE60',
#        'Age.MALE65', 'Age.MALE70', 'Age.MALE75', 'Age.MALE80',
#        'Age.MALE85', 'Age.FEM0', 'Age.FEM5', 'Age.FEM10', 'Age.FEM15',
#        'Age.FEM20', 'Age.FEM25', 'Age.FEM30', 'Age.FEM35', 'Age.FEM40',
#        'Age.FEM45', 'Age.FEM50', 'Age.FEM55', 'Age.FEM60', 'Age.FEM65',
#        'Age.FEM70', 'Age.FEM75', 'Age.FEM80', 'Age.FEM85'], dtype=object)

# %%
# View a sample of the `Age` data collection
df.loc['Age'].head()
# Out:
#                  analysisVariable                 alias  \
# dataCollectionID
# Age                     Age.MALE0    2020 Males Age 0-4
# Age                     Age.MALE5    2020 Males Age 5-9
# Age                    Age.MALE10  2020 Males Age 10-14
# Age                    Age.MALE15  2020 Males Age 15-19
# Age                    Age.MALE20  2020 Males Age 20-24
#
#                                        fieldCategory vintage
# dataCollectionID
# Age               2020 Age: 5 Year Increments (Esri)    2020
# Age               2020 Age: 5 Year Increments (Esri)    2020
# Age               2020 Age: 5 Year Increments (Esri)    2020
# Age               2020 Age: 5 Year Increments (Esri)    2020
# Age               2020 Age: 5 Year Increments (Esri)    2020

# %% [markdown]
# Now, let's look at some examples of enriching each of the study areas.

# %% [markdown]
# ### Enriching street address
# Street address locations can be passed as strings of input street addresses, points of interest or place names. A street address can be passed as a single line or as a multiple field input. If a point (e.g. a street address) is used as a study area, the service will create a 1 mile ring buffer around the point to collect and append enrichment data.
#
# The example below uses a `street address` as a study area for enrichment using `Age` data collection.

# %% [markdown]
# #### Single line address

# %%
# Enriching single address as single line imput
single_address = enrich(study_areas=["380 New York St Redlands CA 92373"], 
                       data_collections=['Age'])

# %%
single_address
# Out:
#   ID  OBJECTID sourceCountry           X          Y    areaType bufferUnits  \
# 0  0         1            US -117.194872  34.057237  RingBuffer   esriMiles
#
#   bufferUnitsAlias  bufferRadii                  aggregationMethod  ...  \
# 0            Miles            1  BlockApportionment:US.BlockGroups  ...
#
#    FEM45  FEM50  FEM55  FEM60  FEM65  FEM70  FEM75  FEM80  FEM85  \
# 0    376    398    374    340    310    262    153     98    129
#
#                                                SHAPE
# 0  {"rings": [[[-117.19487199429183, 34.071745616...
#
# [1 rows x 50 columns]

# %% [markdown]
# ##### Visualize results on a map
#
# The returned spatial dataframe can be visualized on a map as shown below:

# %%
# Plot on a map
address_map = gis.map('Redlands, CA',13)
address_map
# Out:
# <img src=data:image/png;base64,...></img>

# %% [markdown]
# A buffer of 1 mile is created by default, as seen on this map, for any address.

# %%
single_address.spatial.plot(address_map)
# Out:
# True

# %% [markdown]
# __Multiple addresses as single line input__

# %%
# Enriching multiple addresses as single line input
enrich(study_areas=[{"address":{"text":"12 Concorde Place Toronto ON M3C 3R8","sourceCountry":"Canada"}},
                    {"address":{"text":"380 New York St Redlands CA 92373","sourceCountry":"US"}}], 
       data_collections=['Age'])
# Out:
#   ID  OBJECTID sourceCountry           X          Y    areaType bufferUnits  \
# 0  0         1            CA  -79.328740  43.729720  RingBuffer   esriMiles
# 1  1         2            US -117.194872  34.057237  RingBuffer   esriMiles
#
#   bufferUnitsAlias  bufferRadii                  aggregationMethod  ...  \
# 0            Miles            1          BlockApportionment:CAN.DA  ...
# 1            Miles            1  BlockApportionment:US.BlockGroups  ...
#
#    ECYPFA4549  ECYPFA5054  ECYPFA5559  ECYPFA6064  ECYPFA6569  ECYPFA7074  \
# 0      1351.0      1264.0      1323.0      1138.0      1156.0       973.0
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    ECYPFA7579  ECYPFA8084  ECYPFA85P  \
# 0       784.0       576.0      970.0
# 1         NaN         NaN        NaN
#
#                                                SHAPE
# 0  {"rings": [[[-79.3287400246266, 43.74420464321...
# 1  {"rings": [[[-117.19487199429183, 34.071745616...
#
# [2 rows x 50 columns]

# %% [markdown]
# #### Multiple field input

# %%
enrich(study_areas=[{"address":{"Address":"380 New York Street", 
                                "City":"Redlands", "Region":"CA", "Postal":92373}}], 
       data_collections=['Age'])
# Out:
#   ID  OBJECTID sourceCountry           X          Y    areaType bufferUnits  \
# 0  0         1            US -117.194872  34.057237  RingBuffer   esriMiles
#
#   bufferUnitsAlias  bufferRadii                  aggregationMethod  ...  \
# 0            Miles            1  BlockApportionment:US.BlockGroups  ...
#
#    FEM45  FEM50  FEM55  FEM60  FEM65  FEM70  FEM75  FEM80  FEM85  \
# 0    376    398    374    340    310    262    153     98    129
#
#                                                SHAPE
# 0  {"rings": [[[-117.19487199429183, 34.071745616...
#
# [1 rows x 50 columns]

# %% [markdown]
# Enriching with various analysis variables for age such as `FEM45, FEM50, FEM65` etc.

# %%
enrich(study_areas=["380 New York St Redlands CA 92373"], 
       analysis_variables=["Age.FEM45","Age.FEM55","Age.FEM65"])
# Out:
#   ID  OBJECTID sourceCountry           X          Y    areaType bufferUnits  \
# 0  0         1            US -117.194872  34.057237  RingBuffer   esriMiles
#
#   bufferUnitsAlias  bufferRadii                  aggregationMethod  \
# 0            Miles            1  BlockApportionment:US.BlockGroups
#
#    populationToPolygonSizeRating  apportionmentConfidence  HasData  FEM45  \
# 0                          2.191                    2.576        1    376
#
#    FEM55  FEM65                                              SHAPE
# 0    374    310  {"rings": [[[-117.19487199429183, 34.071745616...

# %% [markdown]
# ### Enriching point, line and polygon geometries
#
# Point geometries can be passed as x and y coordinates to `study_areas` parameter. When points are specified as studyAreas, the service will analyze map areas surrounding or associated with the input point locations. Unless otherwise specified, the service will analyze a one mile ring around a point. This is also true for a line. Locations can also be given as polygon geometries.

# %% [markdown]
# #### Single Point described as map coordinates

# %%
from arcgis.geometry import Point

# %%
pt = Point({"x" : -117.1956, "y" : 34.0572, "spatialReference" : {"wkid" : 4326}})
enrich(study_areas=[pt], data_collections=['Age'])
# Out:
#   ID  OBJECTID sourceCountry    areaType bufferUnits bufferUnitsAlias  \
# 0  0         1            US  RingBuffer   esriMiles            Miles
#
#    bufferRadii                  aggregationMethod  \
# 0            1  BlockApportionment:US.BlockGroups
#
#    populationToPolygonSizeRating  apportionmentConfidence  ...  FEM45  FEM50  \
# 0                          2.191                    2.576  ...    364    388
#
#    FEM55  FEM60  FEM65  FEM70  FEM75  FEM80  FEM85  \
# 0    361    329    300    253    147     92    122
#
#                                                SHAPE
# 0  {"rings": [[[-117.19559999999998, 34.071708616...
#
# [1 rows x 48 columns]

# %% [markdown]
# #### Multiple points with attributes described as map coordinates

# %%
pt1 = Point({"x" : -122.435, "y" : 37.785, "spatialReference" : {"wkid" : 4326}})
pt2 = Point({"x" : -122.433, "y" : 37.734, "spatialReference" : {"wkid" : 4326}})

enrich(study_areas=[pt1, pt2], data_collections=['Age'])
# Out:
#   ID  OBJECTID sourceCountry    areaType bufferUnits bufferUnitsAlias  \
# 0  0         1            US  RingBuffer   esriMiles            Miles
# 1  1         2            US  RingBuffer   esriMiles            Miles
#
#    bufferRadii                  aggregationMethod  \
# 0            1  BlockApportionment:US.BlockGroups
# 1            1  BlockApportionment:US.BlockGroups
#
#    populationToPolygonSizeRating  apportionmentConfidence  ...  FEM45  FEM50  \
# 0                          2.191                    2.576  ...   2994   2581
# 1                          2.191                    2.576  ...   2444   2373
#
#    FEM55  FEM60  FEM65  FEM70  FEM75  FEM80  FEM85  \
# 0   2615   2773   2602   2394   1926   1564   2351
# 1   2378   2164   2004   1660   1097    798   1040
#
#                                                SHAPE
# 0  {"rings": [[[-122.43499999999999, 37.799499596...
# 1  {"rings": [[[-122.43299999999999, 37.748499722...
#
# [2 rows x 48 columns]

# %% [markdown]
# #### Line feature described as geometry

# %%
from arcgis.geometry import Polyline

# %%
line = Polyline({"paths":[[[-13048580,4036370],[-13046151,4036366]]],
                 "spatialReference":{"wkid":102100}})
enriched_line_df = enrich(study_areas=[line], data_collections=['Age'])

# %%
enriched_line_df
# Out:
#   ID  OBJECTID sourceCountry    areaType bufferUnits bufferUnitsAlias  \
# 0  0         1            US  RingBuffer   esriMiles            Miles
#
#    bufferRadii                  aggregationMethod  \
# 0            1  BlockApportionment:US.BlockGroups
#
#    populationToPolygonSizeRating  apportionmentConfidence  ...  FEM45  FEM50  \
# 0                          2.191                    2.576  ...    585    585
#
#    FEM55  FEM60  FEM65  FEM70  FEM75  FEM80  FEM85  \
# 0    528    498    443    389    227    151    228
#
#                                                SHAPE
# 0  {"rings": [[[-117.21736177272676, 34.070851408...
#
# [1 rows x 48 columns]

# %% [markdown]
# ##### Visualize results on a map
#
# The returned spatial dataframe can be visualized on a map as shown below:

# %%
# Plot on a map
line_map = gis.map('Redlands, CA',13)
line_map
# Out:
# <img src=data:image/png;base64,...></img>

# %% [markdown]
# We can clearly see the line and a 1 mile buffer around the line in this map

# %%
# Draw line
line_map.draw(line)

# Plot enriched area around line
enriched_line_df.spatial.plot(line_map)
# Out:
# True

# %% [markdown]
# #### Map area described as polygons

# %%
from arcgis.geometry import Polygon

# %%
poly = Polygon({"rings":[[[-117.185412,34.063170],[-122.81,37.81],
                        [-117.200570,34.057196],[-117.185412,34.063170]]],
                        "spatialReference":{"wkid":4326}})

enrich(study_areas=[poly], data_collections=['Age'])
# Out:
#   ID  OBJECTID sourceCountry                  aggregationMethod  \
# 0  0         1            US  BlockApportionment:US.BlockGroups
#
#    populationToPolygonSizeRating  apportionmentConfidence  HasData  MALE0  \
# 0                          2.191                    2.576        1   5532
#
#    MALE5  MALE10  ...  FEM45  FEM50  FEM55  FEM60  FEM65  FEM70  FEM75  FEM80  \
# 0   5473    5286  ...   3865   3905   3896   3528   2710   1997   1303    844
#
#    FEM85                                              SHAPE
# 0    943  {"rings": [[[-117.20057, 34.057196], [-122.809...
#
# [1 rows x 44 columns]

# %% [markdown]
# ### Enriching Buffered study areas
#
# `BufferStudyArea` instances are used to change the ring buffer size or create drive-time service areas around points specified using one of the above methods. BufferStudyArea allows you to buffer point and street address study areas. They can be created using the following parameters:
#         * area: the point geometry or street address (string) study area to be buffered
#         * radii: list of distances by which to buffer the study area, eg. [1, 2, 3]
#         * units: distance unit, eg. Miles, Kilometers, Minutes (when using drive times/travel_mode)
#         * overlap: boolean, uses overlapping rings/network service areas when True, or non-overlapping disks when False
#         * travel_mode: None or string, one of the supported travel modes when using network service areas
#
#
# `BufferStudyArea` also allows you to define drive time service areas around points as well as other advanced service areas such as walking and trucking.

# %% [markdown]
# #### Buffering location using driving distance
#
# The example below creates non-overlapping disks of radii 1, 3 and 5 Miles respectively from a street address and enriches these using the 'Age' data collection.

# %%
buffered = BufferStudyArea(area='380 New York St Redlands CA 92373',
                           radii=[1,3,5], units='Miles', overlap=False)
drive_dist_df = enrich(study_areas=[buffered], data_collections=['Age'])

# %%
drive_dist_df
# Out:
#   ID  OBJECTID sourceCountry           X          Y         areaType  \
# 0  0         1            US -117.194872  34.057237  RingBufferBands
# 1  0         2            US -117.194872  34.057237  RingBufferBands
# 2  0         3            US -117.194872  34.057237  RingBufferBands
#
#   bufferUnits bufferUnitsAlias  bufferRadii  \
# 0       Miles            Miles            1
# 1       Miles            Miles            3
# 2       Miles            Miles            5
#
#                    aggregationMethod  ...  FEM45  FEM50  FEM55  FEM60  FEM65  \
# 0  BlockApportionment:US.BlockGroups  ...    376    398    374    340    310
# 1  BlockApportionment:US.BlockGroups  ...   1935   1936   1999   2073   1789
# 2  BlockApportionment:US.BlockGroups  ...   2375   2493   2601   2478   2008
#
#    FEM70  FEM75  FEM80  FEM85  \
# 0    262    153     98    129
# 1   1430    986    719    947
# 2   1500   1062    780   1018
#
#                                                SHAPE
# 0  {"rings": [[[-117.19487199429183, 34.071745616...
# 1  {"rings": [[[-117.19487199429183, 34.100762745...
# 2  {"rings": [[[-117.19487199429183, 34.129779737...
#
# [3 rows x 50 columns]

# %% [markdown]
# ##### Visualize results on a map
#
# The returned spatial dataframe can be visualized on a map as shown below:

# %%
# Plot on a map
buffer_map1 = gis.map('Redlands, CA')
buffer_map1.basemap = 'dark-gray-vector'
buffer_map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-50aebe9f-74fd-49a0-a255-d8ac0f4d203e"><img src=""></img></div>

# %%
drive_dist_df.spatial.plot(map_widget=buffer_map1,
               renderer_type='c',  # for class breaks renderer
               method='esriClassifyNaturalBreaks',  # classification algorithm
               class_count=4,  # choose the number of classes
               col='bufferRadii',  # numeric column to classify
               cmap='viridis',  # color map to pick colors from for each class
               alpha=0.7  # specify opacity
               )
# Out:
# True

# %% [markdown]
# #### Buffering location using drive times
#
# The example below creates 5 and 10 minute drive times from a street address and enriches these using the 'Age' data collection.

# %%
buffered = BufferStudyArea(area='380 New York St Redlands CA 92373', 
                           radii=[5, 10], units='Minutes', 
                           travel_mode='Driving')
drive_time_df = enrich(study_areas=[buffered], data_collections=['Age'])

# %%
drive_time_df
# Out:
#   ID  OBJECTID sourceCountry           X          Y            areaType  \
# 0  0         1            US -117.194872  34.057237  NetworkServiceArea
# 1  0         2            US -117.194872  34.057237  NetworkServiceArea
#
#   bufferUnits    bufferUnitsAlias  bufferRadii  \
# 0     Minutes  Drive Time Minutes            5
# 1     Minutes  Drive Time Minutes           10
#
#                    aggregationMethod  ...  FEM45  FEM50  FEM55  FEM60  FEM65  \
# 0  BlockApportionment:US.BlockGroups  ...    658    661    657    617    567
# 1  BlockApportionment:US.BlockGroups  ...   3208   3232   3352   3355   2874
#
#    FEM70  FEM75  FEM80  FEM85  \
# 0    463    300    212    280
# 1   2259   1545   1145   1651
#
#                                                SHAPE
# 0  {"rings": [[[-117.19120531126502, 34.080999174...
# 1  {"rings": [[[-117.19165446621216, 34.143207222...
#
# [2 rows x 50 columns]

# %% [markdown]
# ##### Visualize results on a map
#
# The returned spatial dataframe can be visualized on a map as shown below:

# %%
# Plot on a map
buffer_map2 = gis.map('Redlands, CA')
buffer_map2.basemap = 'dark-gray-vector'
buffer_map2
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-33ae5fa0-50bc-44f4-b295-65a31c5082e9"><img src=""></img></div>

# %%
drive_time_df.spatial.plot(map_widget=buffer_map2,
                   renderer_type='c',  # for class breaks renderer
                   method='esriClassifyNaturalBreaks',  # classification algorithm
                   class_count=3,  # choose the number of classes
                   col='bufferRadii',  # numeric column to classify
                   cmap='viridis',  # color map to pick colors from for each class
                   alpha=0.7  # specify opacity
                   )
# Out:
# True

# %% [markdown]
# ### Enriching a named statistical area
#
# In all previous examples of different study area types, locations were defined as either points or polygons. Study area locations can also be passed as one or many named statistical areas. This form of study area lets you define an area as a standard geographic statistical feature, such as a census or postal area, for example, to obtain enrichment information for a U.S. state, county, or ZIP Code or a Canadian province or postal code. We will explore Named statistical areas in detail in the next section.

# %% [markdown]
# #### Enriching a zip code
# Enriching zip code 92373 in California using the 'Age' data collection:

# %%
usa = Country.get('US')

# %%
redlands = usa.subgeographies.states['California'].zip5['92373']

# %%
type(redlands)
# Out:
# arcgis.geoenrichment.enrichment.NamedArea

# %%
redlands_df = enrich(study_areas=[redlands], data_collections=['Age'] )

# %%
redlands_df
# Out:
#   ID  OBJECTID StdGeographyLevel StdGeographyName StdGeographyID  \
# 0  0         1           US.ZIP5         Redlands          92373
#
#   sourceCountry aggregationMethod  populationToPolygonSizeRating  \
# 0            US     Query:US.ZIP5                          2.191
#
#    apportionmentConfidence  HasData  ...  FEM45  FEM50  FEM55  FEM60  FEM65  \
# 0                    2.576        1  ...   1024   1089   1113   1184   1101
#
#    FEM70  FEM75  FEM80  FEM85  \
# 0    970    662    475    701
#
#                                                SHAPE
# 0  {"rings": [[[-117.13603999963594, 34.032169999...
#
# [1 rows x 47 columns]

# %% [markdown]
# ##### Visualize results on a map
#
# The returned spatial dataframe can be visualized on a map as shown below:

# %%
zip_map = gis.map('Redlands, CA')
zip_map
# Out:
# <img src=data:image/png;base64,...></img>

# %%
redlands_df.spatial.plot(zip_map)
# Out:
# True

# %% [markdown]
# #### Enriching all counties in a state

# %%
ca_counties = usa.subgeographies.states['California'].counties

# %%
counties_df = enrich(study_areas=ca_counties, data_collections=['Age'])
counties_df.head()
# Out:
#   ID  OBJECTID StdGeographyLevel  StdGeographyName StdGeographyID  \
# 0  0         1       US.Counties    Alameda County          06001
# 1  1         2       US.Counties     Alpine County          06003
# 2  2         3       US.Counties     Amador County          06005
# 3  3         4       US.Counties      Butte County          06007
# 4  4         5       US.Counties  Calaveras County          06009
#
#   sourceCountry  aggregationMethod  populationToPolygonSizeRating  \
# 0            US  Query:US.Counties                          2.191
# 1            US  Query:US.Counties                          2.191
# 2            US  Query:US.Counties                          2.191
# 3            US  Query:US.Counties                          2.191
# 4            US  Query:US.Counties                          2.191
#
#    apportionmentConfidence  HasData  ...  FEM45  FEM50  FEM55  FEM60  FEM65  \
# 0                    2.576        1  ...  55457  54029  55299  50442  42912
# 1                    2.576        1  ...     38     42     62     39     55
# 2                    2.576        1  ...   1011   1162   1591   1813   1739
# 3                    2.576        1  ...   5383   5817   6860   7023   6568
# 4                    2.576        1  ...   1352   1649   2219   2371   2307
#
#    FEM70  FEM75  FEM80  FEM85  \
# 0  34127  22548  15100  18391
# 1     30     12     10      5
# 2   1527    968    667    733
# 3   5293   3614   2437   3396
# 4   1942   1206    727    688
#
#                                                SHAPE
# 0  {"rings": [[[-122.2716789998329, 37.9047240001...
# 1  {"rings": [[[-119.90059599883206, 38.930759999...
# 2  {"rings": [[[-120.07763899965389, 38.708886999...
# 3  {"rings": [[[-121.4046210002662, 40.1466409995...
# 4  {"rings": [[[-120.07246000003855, 38.509156000...
#
# [5 rows x 47 columns]

# %% [markdown]
# ##### Visualize results on a map

# %%
county_map = gis.map('California')
county_map
# Out:
# <img src="data:image/jpeg;base64,..."/>

# %%
counties_df.spatial.plot(map_widget=county_map,
               renderer_type='c',  # for class breaks renderer
               method='esriClassifyNaturalBreaks',  # classification algorithm
               class_count=5,  # choose the number of classes
               col='FEM75',  # numeric column to classify
               cmap='viridis',  # color map to pick colors from for each class
               alpha=0.7  # specify opacity
               )
# Out:
# True

# %% [markdown]
# #### Using comparison levels

# %% [markdown]
# Using `comparison_levels` the information for the study areas can also be compared with standard geography areas in other levels. For example, if the study area is a zip code, you can compare enriched information for this zip code with information for the county or the state.

# %% [markdown]
# __Example 1__
#
# Let's look at an example of enriching a zip code (study area) and then comparing its enrichment information with information for the county to which the zip code belongs using `comparison_levels`.

# %%
fontana = usa.subgeographies.states['California'].zip5['92336']

# %%
testdf1 = enrich(study_areas=[fontana], data_collections=['Age'], 
                 comparison_levels=['US.Counties'])

# %%
testdf1.head()
# Out:
#   ID  OBJECTID StdGeographyLevel       StdGeographyName StdGeographyID  \
# 0  0         1           US.ZIP5                Fontana          92336
# 1  0         2       US.Counties  San Bernardino County          06071
#
#   sourceCountry  aggregationMethod  populationToPolygonSizeRating  \
# 0            US      Query:US.ZIP5                          2.191
# 1            US  Query:US.Counties                          2.191
#
#    apportionmentConfidence  HasData  ...  FEM45  FEM50  FEM55  FEM60  FEM65  \
# 0                    2.576        1  ...   3458   3134   2975   2353   1777
# 1                    2.576        1  ...  65463  64654  66066  60308  49629
#
#    FEM70  FEM75  FEM80  FEM85  \
# 0   1176    706    389    366
# 1  36487  23911  15572  16245
#
#                                                SHAPE
# 0  {"rings": [[[-117.42984999972606, 34.187269999...
# 1                                               None
#
# [2 rows x 47 columns]

# %% [markdown]
# We can see how using County as the `comparison_level`, we are able to compare enriched study area with information for county.

# %% [markdown]
# __Example 2__
#
# Let's look at another example. In this example below, the 92373 zip code in Redlands intersects with both Riverside and San Bernardino counties in California. Hence, when using `comparsion_levels` both these counties are returned along with the results for the named zip code. We can also add State to the list of `comparsion_levels` to output results for counties and well as states.

# %%
redlands = usa.subgeographies.states['California'].zip5['92373']

# %%
testdf2 = enrich(study_areas=[redlands], data_collections=['Age'], 
       comparison_levels=['US.Counties', 'US.States'])

# %%
testdf2.columns
# Out:
# Index(['ID', 'OBJECTID', 'StdGeographyLevel', 'StdGeographyName',
#        'StdGeographyID', 'sourceCountry', 'aggregationMethod',
#        'populationToPolygonSizeRating', 'apportionmentConfidence', 'HasData',
#        'MALE0', 'MALE5', 'MALE10', 'MALE15', 'MALE20', 'MALE25', 'MALE30',
#        'MALE35', 'MALE40', 'MALE45', 'MALE50', 'MALE55', 'MALE60', 'MALE65',
#        'MALE70', 'MALE75', 'MALE80', 'MALE85', 'FEM0', 'FEM5', 'FEM10',
#        'FEM15', 'FEM20', 'FEM25', 'FEM30', 'FEM35', 'FEM40', 'FEM45', 'FEM50',
#        'FEM55', 'FEM60', 'FEM65', 'FEM70', 'FEM75', 'FEM80', 'FEM85', 'SHAPE'],
#       dtype='object')

# %%
testdf2.head()
# Out:
#   ID  OBJECTID StdGeographyLevel       StdGeographyName StdGeographyID  \
# 0  0         1           US.ZIP5               Redlands          92373
# 1  0         2       US.Counties       Riverside County          06065
# 2  0         3       US.Counties  San Bernardino County          06071
# 3  0         4         US.States             California             06
#
#   sourceCountry  aggregationMethod  populationToPolygonSizeRating  \
# 0            US      Query:US.ZIP5                          2.191
# 1            US  Query:US.Counties                          2.191
# 2            US  Query:US.Counties                          2.191
# 3            US    Query:US.States                          2.191
#
#    apportionmentConfidence  HasData  ...    FEM45    FEM50    FEM55    FEM60  \
# 0                    2.576        1  ...     1024     1089     1113     1184
# 1                    2.576        1  ...    71840    71254    73314    68647
# 2                    2.576        1  ...    65463    64654    66066    60308
# 3                    2.576        1  ...  1222805  1227409  1264110  1182621
#
#      FEM65   FEM70   FEM75   FEM80   FEM85  \
# 0     1101     970     662     475     701
# 1    60386   49449   35062   23797   25463
# 2    49629   36487   23911   15572   16245
# 3  1012441  803457  549654  374499  447146
#
#                                                SHAPE
# 0  {"rings": [[[-117.13603999963594, 34.032169999...
# 1                                               None
# 2                                               None
# 3                                               None
#
# [4 rows x 47 columns]

# %%
testdf2.iloc[:, -20:]
# Out:
#    MALE85     FEM0     FEM5    FEM10    FEM15    FEM20    FEM25    FEM30  \
# 0     380      877      859      940      902     1187     1190     1150
# 1   17664    85123    86025    83957    80112    80542    98617    91315
# 2    9848    79131    78595    76288    71381    78383    95432    87077
# 3  274381  1221927  1234947  1248664  1240920  1337702  1543578  1464688
#
#      FEM35    FEM40    FEM45    FEM50    FEM55    FEM60    FEM65   FEM70  \
# 0     1273     1041     1024     1089     1113     1184     1101     970
# 1    79758    71974    71840    71254    73314    68647    60386   49449
# 2    73658    65402    65463    64654    66066    60308    49629   36487
# 3  1349773  1210247  1222805  1227409  1264110  1182621  1012441  803457
#
#     FEM75   FEM80   FEM85                                              SHAPE
# 0     662     475     701  {"rings": [[[-117.13603999963594, 34.032169999...
# 1   35062   23797   25463                                               None
# 2   23911   15572   16245                                               None
# 3  549654  374499  447146                                               None

# %% [markdown]
# To understand how the data is different between the zip code, the two counties and the state, let's plot the male to female ratio for ages 80-85.

# %%
# Create a dataframe with new Male_Female_Ratio column
bar_df = testdf2.loc[:,['StdGeographyName','FEM80','MALE80']]
bar_df['Male_Female_Ratio'] = bar_df['MALE80'] / bar_df['FEM80']
bar_df
# Out:
#         StdGeographyName   FEM80  MALE80  Male_Female_Ratio
# 0               Redlands     475     345           0.726316
# 1       Riverside County   23797   19288           0.810522
# 2  San Bernardino County   15572   11698           0.751220
# 3             California  374499  283158           0.756098

# %%
# Plot the Male_Female_Ratio
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize = (8,5))
plt.bar(x = 'StdGeographyName', height = 'Male_Female_Ratio', data = bar_df)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# From the above plot, we can see minor difference in the male/female ratio between two counties, the state and Redlands (Zip=92373).

# %% [markdown]
# ### Enriching Arbitrary Geometries

# %% [markdown]
# Enrichment not only works on clearly defined geometries such as county or state boundaries but it can also power arbitrary goemetires (random polygon on a map or an area covering parts of different counties etc.) just as well. Let's look at an example of how an arbitrary geometry can be `enrich()`ed.
#
# In this example, we will:
# 1. Draw a map of Los Angeles, CA
# 2. Ask the user to draw a polygon on the map
# 3. Enrich the polygon drawn by the user
# 4. Visualize enriched geometry on a map

# %% [markdown]
# #### Create a Map

# %%
la_map = gis.map('Los Angeles, CA')
la_map
# Out:
# <img src=data:image/png;base64,...></img>

# %% [markdown]
# #### Enable User Input
#
# Here, we will define a callback function that enables user input. If no input is provided, a default polygon geometry will be enriched.

# %%
# Define the callback function.
drawn_polygon = None
def draw_poly(la_map, g):
    global drawn_polygon
    drawn_polygon = g

# Set draw_poly as the callback function to be invoked when a polygon is drawn on the map
drawn_polygon = la_map.on_draw_end(draw_poly)

# %% [markdown]
# Now, run the cell below and then draw a polygon on `la_map`, finish drawing by double clicking the mouse pointer. If no map is drawn within 30 seconds, a default polygon geometry will be used for enrichment.

# %%
import time
# Draw polygon
la_map.draw("polygon")

# Sleep for 30 seconds
time.sleep(30)

# Use this as default polygon if no polygon drawn on map
drawn_polygon = {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
 'rings': [[[-13176442.352731517, 4035051.715228523],
   [-13167152.267973447, 4032788.462594141],
   [-13169738.58648519, 4023675.1384639805],
   [-13178995.82720767, 4028428.5661604665],
   [-13176442.352731517, 4035051.715228523]]]}

# %%
# Check drawn polygon
drawn_polygon
# Out:
# {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#  'rings': [[[-13181795.930532897, 4037434.4007196007],
#    [-13169038.11278067, 4034871.3716149125],
#    [-13172126.646454819, 4026770.8381095314],
#    [-13180793.88886522, 4029142.1774792233],
#    [-13187354.932847794, 4034394.834516697],
#    [-13181795.930532897, 4037434.4007196007]]]}

# %% [markdown]
# #### Enrich Drawn Geometry

# %%
from arcgis.geometry import Polygon
poly = Polygon(drawn_polygon)

# %%
enriched_line_df2 = enrich(study_areas=[poly], 
       analysis_variables=["Age.FEM45","Age.FEM55","Age.FEM65"])

enriched_line_df2
# Out:
#   ID  OBJECTID sourceCountry                  aggregationMethod  \
# 0  0         1            US  BlockApportionment:US.BlockGroups
#
#    populationToPolygonSizeRating  apportionmentConfidence  HasData  FEM45  \
# 0                          2.191                    2.576        1  11964
#
#    FEM55  FEM65                                              SHAPE
# 0  12174   9685  {"rings": [[[-118.41408756542211, 34.064264163...

# %% [markdown]
# #### Visualize Enriched Geometry

# %%
# Plot on a map
poly_map2 = gis.map('Los Angeles, CA')
poly_map2
# Out:
# <img src="data:image/jpeg;base64,..."/>

# %% [markdown]
# We can clearly see the enriched geometry on this map. Clicking on the geometry will display enriched features.

# %%
# Plot enriched area around line
enriched_line_df2.spatial.plot(poly_map2)
# Out:
# True

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this part of the `arcgis.geoenrichment` module guide series, you were introduced to the concept of study areas and how Geoenrichment uses a study area to define the location of the point, polyline or area that you want to enrich. You have also seen in detail how different types of study areas can be enriched and visualized on a map.
#
# In the subsequent pages, you will learn about:
# 1. Exploring Named Statistical Areas
# 2. Data Collections and GeoEnrichment coverage
# 3. Generating Reports
# 4. Standard Geography Queries
