# %% [markdown]
# # GeoEnrichment

# %% [markdown]
# GeoEnrichment provides the ability to get facts about a location or area. Using GeoEnrichment, you can get information about the people, places, and businesses in a specific area or within a certain distance or drive time from a location. It enables you to query and use information from a large collection of data sets including population, income, housing, consumer behavior, and the natural environment.
#
# This module enables you to answer questions about locations that you can't answer with maps alone. For example: What kind of people live here? What do people like to do in this area? What are their habits and lifestyles? What kind of businesses are in this area?
#
#
# The `enrich()` method to can be used retrieve demographics and other relevant characteristics associated with the area surrounding the requested places. You can also use the `arcgis.geoenrichment` module to obtain additional geographic context (for example, the ZIP Code of a location) and geographic boundaries (for example, the geometry for a drive-time service area).
#
# Site analysis is a popular application of this type of data enrichment. For example, GeoEnrichment can be leveraged to study the population that would be affected by the development of a new community center within their neighborhood. With the `enrich()` method, the proposed site can be submitted, and the demographics and other relevant characteristics associated with the area around the site will be returned.

# %% [markdown]
# ## Getting Started
#
# A user must be logged on to a GIS in order to use GeoEnrichment. The geoenrichment functionality is available in the `arcgis.geoenrichment` module.

# %%
from arcgis.gis import GIS
from arcgis.geoenrichment import *

gis = GIS('https://m1nw.mapsqa.arcgis.com', 'singhqa', 'singhqa1')

# %% [markdown]
# ## GeoEnrichment coverage
#
# The `get_countries()` method can be used to query the countries for which there is GeoEnrichment data.

# %%
countries = get_countries()

# %%
countries
# Out:
# [<Country name:Albania>,
#  <Country name:Algeria>,
#  <Country name:Andorra>,
#  <Country name:Angola>,
#  <Country name:Argentina>,
#  <Country name:Armenia>,
#  <Country name:Aruba>,
#  <Country name:Australia>,
#  <Country name:Austria>,
#  <Country name:Azerbaijan>,
#  <Country name:Bahamas>,
#  <Country name:Bahrain>,
#  <Country name:Bangladesh>,
#  <Country name:Belarus>,
#  <Country name:Belgium>,
#  <Country name:Bermuda>,
#  <Country name:Bolivia>,
#  <Country name:Bosnia and Herzegovina>,
#  <Country name:Botswana>,
#  <Country name:Brazil>,
#  <Country name:Bulgaria>,
#  <Country name:Cameroon>,
#  <Country name:Canada>,
#  <Country name:Cayman Islands>,
#  <Country name:Chile>,
#  <Country name:China>,
#  <Country name:Colombia>,
#  <Country name:Costa Rica>,
#  <Country name:Cote d'Ivoire>,
#  <Country name:Croatia>,
#  <Country name:Cyprus>,
#  <Country name:Czech Republic>,
#  <Country name:Denmark>,
#  <Country name:Dominican Republic>,
#  <Country name:Ecuador>,
#  <Country name:Egypt>,
#  <Country name:El Salvador>,
#  <Country name:Estonia>,
#  <Country name:Faroe Islands>,
#  <Country name:Finland>,
#  <Country name:France>,
#  <Country name:French Polynesia>,
#  <Country name:Georgia>,
#  <Country name:Germany>,
#  <Country name:Ghana>,
#  <Country name:Greece>,
#  <Country name:Greenland>,
#  <Country name:Guadeloupe>,
#  <Country name:Guatemala>,
#  <Country name:Honduras>,
#  <Country name:Hong Kong>,
#  <Country name:Hungary>,
#  <Country name:Iceland>,
#  <Country name:India>,
#  <Country name:Indonesia>,
#  <Country name:Ireland>,
#  <Country name:Israel>,
#  <Country name:Italy>,
#  <Country name:Jamaica>,
#  <Country name:Japan>,
#  <Country name:Jordan>,
#  <Country name:Kazakhstan>,
#  <Country name:Kenya>,
#  <Country name:Kosovo>,
#  <Country name:Kuwait>,
#  <Country name:Kyrgyzstan>,
#  <Country name:Latvia>,
#  <Country name:Lebanon>,
#  <Country name:Lesotho>,
#  <Country name:Liechtenstein>,
#  <Country name:Lithuania>,
#  <Country name:Luxembourg>,
#  <Country name:Macao>,
#  <Country name:Macedonia>,
#  <Country name:Malawi>,
#  <Country name:Malaysia>,
#  <Country name:Malta>,
#  <Country name:Martinique>,
#  <Country name:Mauritius>,
#  <Country name:Mexico>,
#  <Country name:Moldova>,
#  <Country name:Monaco>,
#  <Country name:Mongolia>,
#  <Country name:Montenegro>,
#  <Country name:Morocco>,
#  <Country name:Mozambique>,
#  <Country name:Namibia>,
#  <Country name:Netherlands>,
#  <Country name:New Caledonia>,
#  <Country name:New Zealand>,
#  <Country name:Nicaragua>,
#  <Country name:Nigeria>,
#  <Country name:Norway>,
#  <Country name:Oman>,
#  <Country name:Pakistan>,
#  <Country name:Panama>,
#  <Country name:Paraguay>,
#  <Country name:Peru>,
#  <Country name:Philippines>,
#  <Country name:Poland>,
#  <Country name:Portugal>,
#  <Country name:Puerto Rico>,
#  <Country name:Qatar>,
#  <Country name:Reunion>,
#  <Country name:Romania>,
#  <Country name:Russia>,
#  <Country name:Saudi Arabia>,
#  <Country name:Serbia>,
#  <Country name:Singapore>,
#  <Country name:Slovakia>,
#  <Country name:Slovenia>,
#  <Country name:South Africa>,
#  <Country name:South Korea>,
#  <Country name:Spain>,
#  <Country name:Sri Lanka>,
#  <Country name:Sudan>,
#  <Country name:Swaziland>,
#  <Country name:Sweden>,
#  <Country name:Switzerland>,
#  <Country name:Syria>,
#  <Country name:Taiwan>,
#  <Country name:Tajikistan>,
#  <Country name:Tanzania>,
#  <Country name:Thailand>,
#  <Country name:Trinidad and Tobago>,
#  <Country name:Tunisia>,
#  <Country name:Turkey>,
#  <Country name:Uganda>,
#  <Country name:Ukraine>,
#  <Country name:United Arab Emirates>,
#  <Country name:United Kingdom>,
#  <Country name:United States>,
#  <Country name:Uruguay>,
#  <Country name:Uzbekistan>,
#  <Country name:Venezuela>,
#  <Country name:Vietnam>,
#  <Country name:Zambia>]

# %%
len(countries)
# Out:
# 137

# %% [markdown]
# ### Filtering countries by properties

# %%
[c.properties.name for c in countries if c.properties.continent == 'Australia']
# Out:
# ['Australia',
#  'French Polynesia',
#  'Indonesia',
#  'Malaysia',
#  'New Caledonia',
#  'New Zealand',
#  'Philippines']

# %% [markdown]
# # Discovering information for a country
#
# The Country class can be used to discover the data collections, sub-geographies and available reports for a country.

# %% [markdown]
# When working with a particular country, you will find it convenient to get a reference to it using the `Country.get()` method. This method accepts the country name or its [2 letter abbreviation](http://www.nationsonline.org/oneworld/country_code_list.htm) or [ISO3 code](https://unstats.un.org/unsd/tradekb/knowledgebase/country-code) and returns an instance of that country.

# %%
usa = Country.get('US')

# %% [markdown]
# Commonly used properties for the country are accessible using `Country.properties`.

# %%
usa.properties.name
# Out:
# 'United States'

# %%
usa.properties.datasets
# Out:
# ['USA_ESRI_2017', 'USA_ACS_2017', 'USA_ASR_2017', 'USA_RMP_2017', 'Landscape']

# %% [markdown]
# ## Data Collections and analysis variables
# GeoEnrichment uses the concept of a data collection to define the data attributes returned by the enrichment service.

# %% [markdown]
# A data collection is a preassembled list of attributes that will be used to enrich the input features. Collection attributes can describe various types of information, such as demographic characteristics and geographic context, of the locations or areas submitted as input features.
#
# The `data_collections` property of a country lists its available data collections and analysis variables as a [Pandas](https://pandas.pydata.org/) dataframe.

# %%
df = usa.data_collections
df
# Out:
#                           analysisVariable  \
# dataCollectionID
# 1yearincrements    1yearincrements.AGE0_CY
# 1yearincrements    1yearincrements.AGE1_CY
# 1yearincrements    1yearincrements.AGE2_CY
# 1yearincrements    1yearincrements.AGE3_CY
# 1yearincrements    1yearincrements.AGE4_CY
# 1yearincrements    1yearincrements.AGE5_CY
# 1yearincrements    1yearincrements.AGE6_CY
# 1yearincrements    1yearincrements.AGE7_CY
# 1yearincrements    1yearincrements.AGE8_CY
# 1yearincrements    1yearincrements.AGE9_CY
# 1yearincrements   1yearincrements.AGE10_CY
# 1yearincrements   1yearincrements.AGE11_CY
# 1yearincrements   1yearincrements.AGE12_CY
# 1yearincrements   1yearincrements.AGE13_CY
# 1yearincrements   1yearincrements.AGE14_CY
# 1yearincrements   1yearincrements.AGE15_CY
# 1yearincrements   1yearincrements.AGE16_CY
# 1yearincrements   1yearincrements.AGE17_CY
# 1yearincrements   1yearincrements.AGE18_CY
# 1yearincrements   1yearincrements.AGE19_CY
# 1yearincrements   1yearincrements.AGE20_CY
# 1yearincrements   1yearincrements.AGE21_CY
# 1yearincrements   1yearincrements.AGE22_CY
# 1yearincrements   1yearincrements.AGE23_CY
# 1yearincrements   1yearincrements.AGE24_CY
# 1yearincrements   1yearincrements.AGE25_CY
# 1yearincrements   1yearincrements.AGE26_CY
# 1yearincrements   1yearincrements.AGE27_CY
# 1yearincrements   1yearincrements.AGE28_CY
# 1yearincrements   1yearincrements.AGE29_CY
# ...                                    ...
# yearmovedin         yearmovedin.ACSOMV1980
# yearmovedin         yearmovedin.MOEOMV1980
# yearmovedin         yearmovedin.RELOMV1980
# yearmovedin         yearmovedin.ACSOMV1979
# yearmovedin         yearmovedin.MOEOMV1979
# yearmovedin         yearmovedin.RELOMV1979
# yearmovedin         yearmovedin.ACSRMV2015
# yearmovedin         yearmovedin.MOERMV2015
# yearmovedin         yearmovedin.RELRMV2015
# yearmovedin         yearmovedin.ACSRMV2010
# yearmovedin         yearmovedin.MOERMV2010
# yearmovedin         yearmovedin.RELRMV2010
# yearmovedin         yearmovedin.ACSRMV2000
# yearmovedin         yearmovedin.MOERMV2000
# yearmovedin         yearmovedin.RELRMV2000
# yearmovedin         yearmovedin.ACSRMV1990
# yearmovedin         yearmovedin.MOERMV1990
# yearmovedin         yearmovedin.RELRMV1990
# yearmovedin         yearmovedin.ACSRMV1980
# yearmovedin         yearmovedin.MOERMV1980
# yearmovedin         yearmovedin.RELRMV1980
# yearmovedin         yearmovedin.ACSRMV1979
# yearmovedin         yearmovedin.MOERMV1979
# yearmovedin         yearmovedin.RELRMV1979
# yearmovedin         yearmovedin.ACSMEDYRMV
# yearmovedin         yearmovedin.MOEMEDYRMV
# yearmovedin         yearmovedin.RELMEDYRMV
# yearmovedin           yearmovedin.ACSOWNER
# yearmovedin           yearmovedin.MOEOWNER
# yearmovedin           yearmovedin.RELOWNER
#
#                                                  alias  \
# dataCollectionID
# 1yearincrements                 2017 Population Age <1
# 1yearincrements                  2017 Population Age 1
# 1yearincrements                  2017 Population Age 2
# 1yearincrements                  2017 Population Age 3
# 1yearincrements                  2017 Population Age 4
# 1yearincrements                  2017 Population Age 5
# 1yearincrements                  2017 Population Age 6
# 1yearincrements                  2017 Population Age 7
# 1yearincrements                  2017 Population Age 8
# 1yearincrements                  2017 Population Age 9
# 1yearincrements                 2017 Population Age 10
# 1yearincrements                 2017 Population Age 11
# 1yearincrements                 2017 Population Age 12
# 1yearincrements                 2017 Population Age 13
# 1yearincrements                 2017 Population Age 14
# 1yearincrements                 2017 Population Age 15
# 1yearincrements                 2017 Population Age 16
# 1yearincrements                 2017 Population Age 17
# 1yearincrements                 2017 Population Age 18
# 1yearincrements                 2017 Population Age 19
# 1yearincrements                 2017 Population Age 20
# 1yearincrements                 2017 Population Age 21
# 1yearincrements                 2017 Population Age 22
# 1yearincrements                 2017 Population Age 23
# 1yearincrements                 2017 Population Age 24
# 1yearincrements                 2017 Population Age 25
# 1yearincrements                 2017 Population Age 26
# 1yearincrements                 2017 Population Age 27
# 1yearincrements                 2017 Population Age 28
# 1yearincrements                 2017 Population Age 29
# ...                                                ...
# yearmovedin               ACS OHHs/Moved In: 1980-1989
# yearmovedin               MOE OHHs/Moved In: 1980-1989
# yearmovedin               REL OHHs/Moved In: 1980-1989
# yearmovedin             ACS OHHs/Moved In: 1979/Before
# yearmovedin             MOE OHHs/Moved In: 1979/Before
# yearmovedin             REL OHHs/Moved In: 1979/Before
# yearmovedin              ACS RHHs/Moved In: 2015/Later
# yearmovedin              MOE RHHs/Moved In: 2015/Later
# yearmovedin              REL RHHs/Moved In: 2015/Later
# yearmovedin               ACS RHHs/Moved In: 2010-2014
# yearmovedin               MOE RHHs/Moved In: 2010-2014
# yearmovedin               REL RHHs/Moved In: 2010-2014
# yearmovedin               ACS RHHs/Moved In: 2000-2009
# yearmovedin               MOE RHHs/Moved In: 2000-2009
# yearmovedin               REL RHHs/Moved In: 2000-2009
# yearmovedin               ACS RHHs/Moved In: 1990-1999
# yearmovedin               MOE RHHs/Moved In: 1990-1999
# yearmovedin               REL RHHs/Moved In: 1990-1999
# yearmovedin               ACS RHHs/Moved In: 1980-1989
# yearmovedin               MOE RHHs/Moved In: 1980-1989
# yearmovedin               REL RHHs/Moved In: 1980-1989
# yearmovedin             ACS RHHs/Moved In: 1979/Before
# yearmovedin             MOE RHHs/Moved In: 1979/Before
# yearmovedin             REL RHHs/Moved In: 1979/Before
# yearmovedin       ACS Median Year Householder Moved In
# yearmovedin       MOE Median Year Householder Moved In
# yearmovedin       REL Median Year Householder Moved In
# yearmovedin                       ACS Owner Households
# yearmovedin                       MOE Owner Households
# yearmovedin                       REL Owner Households
#
#                                                       fieldCategory    vintage
# dataCollectionID
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# 1yearincrements                  2017 Age: 1 Year Increments (Esri)       2017
# ...                                                             ...        ...
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin       2011-2015 Households by Year Householder Moved...  2011-2015
# yearmovedin              2011-2015 Key Demographic Indicators (ACS)  2011-2015
# yearmovedin              2011-2015 Key Demographic Indicators (ACS)  2011-2015
# yearmovedin              2011-2015 Key Demographic Indicators (ACS)  2011-2015
#
# [14609 rows x 4 columns]

# %% [markdown]
# Each data collection and analysis variable has a unique ID that can be passed in the `data_collections` and `analysis_variables` parameters of the `enrich()` method.
#
# You can filter the data_collections and query the collections analysis variables using Pandas expressions.

# %%
df.index.unique()
# Out:
# Index(['1yearincrements', '5yearincrements', 'ACS_Housing_Summary_rep',
#        'ACS_Population_Summary_rep', 'Age', 'Age_50_Profile_rep',
#        'Age_by_Sex_Profile_rep', 'Age_by_Sex_by_Race_Profile_rep', 'AtRisk',
#        'AutomobilesAutomotiveProducts',
#        ...
#        'transportation', 'travelMPI', 'unitsinstructure',
#        'urbanizationgroupsNEW', 'vacant', 'vehiclesavailable', 'veterans',
#        'women', 'yearbuilt', 'yearmovedin'],
#       dtype='object', name='dataCollectionID', length=141)

# %%
df.loc['Age']
# Out:
#                  analysisVariable                   alias  \
# dataCollectionID
# Age                     Age.MALE0      2017 Males Age 0-4
# Age                     Age.MALE5      2017 Males Age 5-9
# Age                    Age.MALE10    2017 Males Age 10-14
# Age                    Age.MALE15    2017 Males Age 15-19
# Age                    Age.MALE20    2017 Males Age 20-24
# Age                    Age.MALE25    2017 Males Age 25-29
# Age                    Age.MALE30    2017 Males Age 30-34
# Age                    Age.MALE35    2017 Males Age 35-39
# Age                    Age.MALE40    2017 Males Age 40-44
# Age                    Age.MALE45    2017 Males Age 45-49
# Age                    Age.MALE50    2017 Males Age 50-54
# Age                    Age.MALE55    2017 Males Age 55-59
# Age                    Age.MALE60    2017 Males Age 60-64
# Age                    Age.MALE65    2017 Males Age 65-69
# Age                    Age.MALE70    2017 Males Age 70-74
# Age                    Age.MALE75    2017 Males Age 75-79
# Age                    Age.MALE80    2017 Males Age 80-84
# Age                    Age.MALE85      2017 Males Age 85+
# Age                      Age.FEM0    2017 Females Age 0-4
# Age                      Age.FEM5    2017 Females Age 5-9
# Age                     Age.FEM10  2017 Females Age 10-14
# Age                     Age.FEM15  2017 Females Age 15-19
# Age                     Age.FEM20  2017 Females Age 20-24
# Age                     Age.FEM25  2017 Females Age 25-29
# Age                     Age.FEM30  2017 Females Age 30-34
# Age                     Age.FEM35  2017 Females Age 35-39
# Age                     Age.FEM40  2017 Females Age 40-44
# Age                     Age.FEM45  2017 Females Age 45-49
# Age                     Age.FEM50  2017 Females Age 50-54
# Age                     Age.FEM55  2017 Females Age 55-59
# Age                     Age.FEM60  2017 Females Age 60-64
# Age                     Age.FEM65  2017 Females Age 65-69
# Age                     Age.FEM70  2017 Females Age 70-74
# Age                     Age.FEM75  2017 Females Age 75-79
# Age                     Age.FEM80  2017 Females Age 80-84
# Age                     Age.FEM85    2017 Females Age 85+
#
#                                        fieldCategory vintage
# dataCollectionID
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017
# Age               2017 Age: 5 Year Increments (Esri)    2017

# %% [markdown]
# ## Available reports
#
# GeoEnrichment also enables you to create many types of high quality reports for a variety of use cases describing the input area.

# %% [markdown]
# The `reports` property of a country lists its available reports as a Pandas dataframe. The report `id` is used as an input in the `create_report()` method to create reports.

# %%
usa.reports
# Out:
#                         id                                           title  \
# 0       census2010_profile                             2010 Census Profile
# 1              acs_housing                             ACS Housing Summary
# 2           acs_population                          ACS Population Summary
# 3                   55plus                                 Age 50+ Profile
# 4               agesexrace                      Age by Sex by Race Profile
# 5                   agesex                              Age by Sex Profile
# 6                 cex_auto             Automotive Aftermarket Expenditures
# 7             business_loc                                Business Locator
# 8         business_summary                                Business Summary
# 9        community_profile                               Community Profile
# 10    Custom_Map_Landscape                            Custom Map Landscape
# 11     Custom_Map_Portrait                             Custom Map Portrait
# 12         dandicomparison       Demographic and Income Comparison Profile
# 13                   dandi                  Demographic and Income Profile
# 14                  agedet                            Detailed Age Profile
# 15                 dispinc                       Disposable Income Profile
# 16            tapestry_map                           Dominant Tapestry Map
# 17                  mpi_pc       Electronics and Internet Market Potential
# 18             execsummary                               Executive Summary
# 19          mpi_investment                       Finances Market Potential
# 20           cex_financial                          Financial Expenditures
# 21                 graphic                                 Graphic Profile
# 22              mpi_health              Health and Beauty Market Potential
# 23                cex_home                     House and Home Expenditures
# 24              cex_budget                   Household Budget Expenditures
# 25               hh_income                        Household Income Profile
# 26                 housing                                 Housing Profile
# 27  LandscapeSummaryReport                        Landscape Summary Report
# 28                shopping                   Major Shopping Center Locator
# 29    shopping_centers_map                       Major Shopping Center Map
# 30          market_profile                                  Market Profile
# 31             cex_medical                            Medical Expenditures
# 32                networth                               Net Worth Profile
# 33                 mpi_pet              Pets and Products Market Potential
# 34          cex_recreation                         Recreation Expenditures
# 35          mpi_restaurant                     Restaurant Market Potential
# 36              cex_retail          Retail Goods and Services Expenditures
# 37              mpi_retail                         Retail Market Potential
# 38           retail_market                      Retail MarketPlace Profile
# 39        site_details_map                                Site Details Map
# 40      site_map_imagery04  Site Map on Satellite Imagery - 0.4 Miles Wide
# 41      site_map_imagery08  Site Map on Satellite Imagery - 0.8 Miles Wide
# 42      site_map_imagery16  Site Map on Satellite Imagery - 1.6 Miles Wide
# 43                site_map                                        Site Map
# 44              mpi_sports             Sports and Leisure Market Potential
# 45     tapestry_profileNEW              Tapestry Segmentation Area Profile
# 46                 traffic                           Traffic Count Profile
# 47             traffic_map                               Traffic Count Map
# 48           traffic_map08                    Traffic Count Map - Close Up
#
#                  categories      formats
# 0            [Demographics]  [pdf, xlsx]
# 1            [Demographics]  [pdf, xlsx]
# 2            [Demographics]  [pdf, xlsx]
# 3            [Demographics]  [pdf, xlsx]
# 4            [Demographics]  [pdf, xlsx]
# 5            [Demographics]  [pdf, xlsx]
# 6       [Consumer Spending]  [pdf, xlsx]
# 7                [Business]  [pdf, xlsx]
# 8                [Business]  [pdf, xlsx]
# 9            [Demographics]  [pdf, xlsx]
# 10                   [Maps]        [pdf]
# 11                   [Maps]        [pdf]
# 12           [Demographics]  [pdf, xlsx]
# 13           [Demographics]  [pdf, xlsx]
# 14           [Demographics]  [pdf, xlsx]
# 15           [Demographics]  [pdf, xlsx]
# 16                   [Maps]        [pdf]
# 17       [Market Potential]  [pdf, xlsx]
# 18        [Summary Reports]  [pdf, xlsx]
# 19       [Market Potential]  [pdf, xlsx]
# 20      [Consumer Spending]  [pdf, xlsx]
# 21           [Demographics]  [pdf, xlsx]
# 22       [Market Potential]  [pdf, xlsx]
# 23      [Consumer Spending]  [pdf, xlsx]
# 24      [Consumer Spending]  [pdf, xlsx]
# 25           [Demographics]  [pdf, xlsx]
# 26           [Demographics]  [pdf, xlsx]
# 27              [Landscape]  [pdf, xlsx]
# 28               [Business]  [pdf, xlsx]
# 29                   [Maps]        [pdf]
# 30           [Demographics]  [pdf, xlsx]
# 31      [Consumer Spending]  [pdf, xlsx]
# 32           [Demographics]  [pdf, xlsx]
# 33       [Market Potential]  [pdf, xlsx]
# 34      [Consumer Spending]  [pdf, xlsx]
# 35       [Market Potential]  [pdf, xlsx]
# 36      [Consumer Spending]  [pdf, xlsx]
# 37       [Market Potential]  [pdf, xlsx]
# 38               [Business]  [pdf, xlsx]
# 39                   [Maps]        [pdf]
# 40                   [Maps]        [pdf]
# 41                   [Maps]        [pdf]
# 42                   [Maps]        [pdf]
# 43                   [Maps]        [pdf]
# 44       [Market Potential]  [pdf, xlsx]
# 45  [Tapestry Segmentation]  [pdf, xlsx]
# 46                [Traffic]  [pdf, xlsx]
# 47                   [Maps]        [pdf]
# 48                   [Maps]        [pdf]

# %% [markdown]
# # Finding named statistical areas
#
# Each country has several named statistical areas in a hierarchy of geography levels (such as states, counties, zip codes, etc).

# %% [markdown]
# The `subgeographies` property of a country can be used to discover these standard geographic/statistical areas within that country.
#
# This information is available through a heirarchy of dynamic properties (like states, counties, tracts, zip-codes,...). Each such dynamic property reflects the geographical levels within that country, with subgeographies grouped logically under the higher levels of geographies. The properties are dictionaries containing the names of the standard geographic places and their values are instances of `NamedArea` class. The `NamedArea` objects can be used as study areas in the `enrich()` method.

# %% [markdown]
# *Note: Setting the `IPCompleter.greedy=True` configuration option in Jupyter notebook enables you to dynamically discover the various levels of subgeographies using intellisense, as in the example below:*

# %%
# %config IPCompleter.greedy=True

# %%
usa.subgeographies.states['California'].counties['San_Bernardino_County']
# Out:
# <NamedArea name:"San Bernardino County" area_id="06071", level="US.Counties", country="United States">

# %%
usa.subgeographies.states['California'].counties['San_Bernardino_County'].tracts['060710001.03']
# Out:
# <NamedArea name:"060710001.03" area_id="06071000103", level="US.Tracts", country="United States">

# %%
usa.subgeographies.states['California'].zip5['92373']
# Out:
# <NamedArea name:"Redlands" area_id="92373", level="US.ZIP5", country="United States">

# %% [markdown]
# The named areas can also be drawn on a map, as they include a `geometry` property.

# %%
m = gis.map('Redlands, CA', zoomlevel=11)
m
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oceans', 'osm', 'satellite', 'streets', 'streets-navigation-vector', 'streets-night-vector', 'streets-relief-vector', 'streets-vector', 'terrain', 'topo', 'topo-vector'], center=[34.05538000000007, -117.18258999999995], zoom=11)

# %%
m.draw(usa.subgeographies.states['California'].zip5['92373'].geometry)

# %% [markdown]
# The subgeography levels and their hierarchies are different for each country, and can also be different for the different datasets (which can be set using the `Country.dataset` property).

# %%
india = Country.get('India')

# %%
india.subgeographies.states['Uttar_Pradesh'].districts['Baghpat'].subdistricts['Baraut']
# Out:
# <NamedArea name:"Baraut" area_id="09080001", level="IN.Subdistricts", country="India">

# %% [markdown]
# ## Searching for named areas within a country

# %%
riversides_in_usa = usa.search('Riverside')
riversides_in_usa
# Out:
# [<NamedArea name:"Riverside" area_id="147435", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147436", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147437", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147438", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147439", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147440", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147441", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147442", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147443", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147444", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147445", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="147446", level="Cities", country="United States">,
#  <NamedArea name:"Riverside" area_id="02915", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="06878", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="08075", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="17868", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="35135", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="52327", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92501", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92503", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92504", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92505", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92506", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92507", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92508", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92509", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="92521", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="97917", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="98849", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="60546", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="64150", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside" area_id="84334", level="US.ZIP5", country="United States">,
#  <NamedArea name:"Riverside Twp" area_id="147431", level="Cities", country="United States">,
#  <NamedArea name:"North Riverside" area_id="124848", level="Cities", country="United States">,
#  <NamedArea name:"Riverside township" area_id="3809167100", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside city" area_id="3911367468", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside borough" area_id="4209765112", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="4601354980", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="4602755020", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="4605955100", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="4609555180", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside CCD" area_id="4847193255", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="1700164408", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="1703164434", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="1907193639", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="1911993642", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="2017360125", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="2019560150", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="2611368820", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="2707354646", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="2904362116", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="3102141585", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="3106741620", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside precinct" area_id="3108792750", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside township" area_id="3400563510", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside County" area_id="06065", level="US.Counties", country="United States">,
#  <NamedArea name:"Riverside CCD" area_id="0606592640", level="US.CSD", country="United States">,
#  <NamedArea name:"Riverside town" area_id="5666075", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside city" area_id="3967468", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside CDP" area_id="4162412", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside CDP" area_id="4265088", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside borough" area_id="4265112", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside city" area_id="4862408", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside CDP" area_id="4964230", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside town" area_id="5358795", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside CDP" area_id="2466762", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside city" area_id="2962156", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside village" area_id="3662061", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside CDP" area_id="3662066", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside town" area_id="0164920", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside city" area_id="0662000", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside CDP" area_id="0964530", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside town" area_id="1365604", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside CDP" area_id="1668230", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside village" area_id="1764421", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside city" area_id="1967440", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside County" area_id="06065", level="Landscape.cy", country="United States">,
#  <NamedArea name:"Conconully-Riverside CCD" area_id="5304790736", level="US.CSD", country="United States">,
#  <NamedArea name:"Bonner-West Riverside CDP" area_id="3008462", level="US.Places", country="United States">,
#  <NamedArea name:"Lake Riverside CDP" area_id="0639715", level="US.Places", country="United States">,
#  <NamedArea name:"North Riverside village" area_id="1754144", level="US.Places", country="United States">,
#  <NamedArea name:"Riverside Oil Field-Pawnee River" area_id="1103000505", level="Landscape.huc10", country="United States">,
#  <NamedArea name:"Riverside-San Bernardino-Ontario, CA Metropolitan Statistical Area" area_id="40140", level="US.CBSA", country="United States">]

# %%
usamap = gis.map('United States', zoomlevel=4)
usamap
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oceans', 'osm', 'satellite', 'streets', 'streets-navigation-vector', 'streets-night-vector', 'streets-relief-vector', 'streets-vector', 'terrain', 'topo', 'topo-vector'], center=[39.39870315600007, -99.41461918999994], zoom=4)

# %%
for riverside in riversides_in_usa:
    usamap.draw(riverside.geometry)

# %% [markdown]
# ## Filtering searched places by geography level

# %%
[level['id'] for level in usa.levels]
# Out:
# ['US.WholeUSA',
#  'US.States',
#  'US.DMA',
#  'US.CD',
#  'US.CBSA',
#  'US.Counties',
#  'US.CSD',
#  'US.ZIP5',
#  'US.Places',
#  'US.Tracts',
#  'US.BlockGroups']

# %%
usa.search('Riverside', ['US.Counties'])
# Out:
# [<NamedArea name:"Riverside County" area_id="06065", level="US.Counties", country="United States">]

# %% [markdown]
# # Finding businesses
#
# The `find_businesses()` method returns business points matching a given search criteria.

# %% [markdown]
# Business points can be selected using any combination of three search criteria: search string, spatial filter and business type. A business point will be selected if it matches all search criteria specified.

# %%
businesses = find_businesses(search_string="Starbucks",
                          return_geometry=True,
                          spatial_filter={"Locations":["NY,TONAWANDA,14150",
                                                       "NJ, CAMDEN, 08102",
                                                       "KY,LOUISVILLE,40204",
                                                       "WA,SEATTLE,98108"]})
businesses.head()
# Out:
#                         ADDR        CITY     CONAME  EMPNUM FRNCOD HDBRCH  \
# 0             972 BAXTER AVE  LOUISVILLE  STARBUCKS      16      4      2
# 1  5963 CORSON AVE S # A-184     SEATTLE  STARBUCKS      20      4      2
# 2                406 PENN ST      CAMDEN  STARBUCKS      15      4      2
# 3                326 PENN ST      CAMDEN  STARBUCKS      12      4      2
# 4            4502 12TH AVE S     SEATTLE  STARBUCKS      15      4      2
#
#   ISCODE     LOCNUM       LOC_NAME     NAICS  \
# 0         210648473   PointAddress  72251505
# 1         243104437  StreetAddress  72251505
# 2         243189941  StreetAddress  72251505
# 3         683534911  StreetAddress  72251505
# 4         714927777   PointAddress  72251505
#
#                         ...                            SIC     SOURCE  \
# 0                       ...                         581228  INFOGROUP
# 1                       ...                         581228  INFOGROUP
# 2                       ...                         581228  INFOGROUP
# 3                       ...                         581228  INFOGROUP
# 4                       ...                         581228  INFOGROUP
#
#    SQFTCODE STATE  STATE_NAME STATUS        STREET    ZIP  ZIP4  \
# 0         A    KY    Kentucky      M    BAXTER AVE  40204  2064
# 1         B    WA  Washington      M  CORSON AVE S  98108  2619
# 2         A    NJ  New Jersey      M       PENN ST  08102  1400
# 3         A    NJ  New Jersey      M       PENN ST  08102  1410
# 4         A    WA  Washington      M    12TH AVE S  98108  1805
#
#                                              SHAPE
# 0  {'y': 38.2401999999322, 'x': -85.7242000003527}
# 1  {'y': 47.5483999998966, 'x': -122.321199999801}
# 2  {'y': 39.9480999999659, 'x': -75.1212000001827}
# 3  {'y': 39.9482999997207, 'x': -75.1220000002487}
# 4  {'y': 47.5633000002997, 'x': -122.317000000352}
#
# [5 rows x 23 columns]

# %%
arcgis.geometry.Geometry(businesses.iloc[0]['SHAPE'])
# Out:
# {"y": 38.2401999999322, "x": -85.7242000003527}

# %% [markdown]
# # Study Areas
# GeoEnrichment uses the concept of a study area to define the location of the point or area that you want to enrich with additional information or create reports about.

# %% [markdown]
# ## Accepted forms of study areas
#
# - **Street address locations** - Locations can be passed as input street addresses, points of interest or place names, as strings.
#     + **Example:** `"380 New York St, Redlands, CA"`
#
#
# - **Multiple field input addresses** - Locations described as multiple field input addresses, using dictionaries.
#     + **Example:**
#         {"address":
#                    {"Address":"380 New York St.",
#                     "Admin1":"Redlands",
#                     "Admin2":"CA","Postal":"92373",
#                     "CountryCode":"USA"}}
#
#
# - **Point and line geometries** - Point and line locations, using `arcgis.geometry` instances.
#     + **Example Point Location: **
#
#     `arcgis.geometry.Geometry({"x":-122.435,"y":37.785})`
#
#     + ** Example Point location obtained using find_businesses() above: **
#
#      `arcgis.geometry.Geometry(businesses.iloc[0]['SHAPE'])`
#
#
# - **Buffered study areas** - `BufferStudyArea` instances to change the ring buffer size or create drive-time service areas around points specified using one of the above methods. BufferStudyArea allows you to buffer point and street address study areas. They can be created using the following parameters:
#         * area: the point geometry or street address (string) study area to be buffered
#         * radii: list of distances by which to buffer the studdy area, eg. [1, 2, 3]
#         * units: distance unit, eg. Miles, Kilometers, Minutes (when using drive times/travel_mode)
#         * overlap: boolean, uses overlapping rings/network service areas when True, or non-overlapping disks when False
#         * travel_mode: None or string, one of the supported travel modes when using network service areas
#     + **Example Buffered Location: **
#
#     `pt = arcgis.geometry.Geometry({"x":-122.435,"y":37.785})
#     buffered_area = BufferStudyArea(area=pt, radii=[1,2,3], units="Miles", overlap=False)`
#
#
# - **Network service areas** - `BufferStudyArea` also allows you to define drive time service areas around points as well as other advanced service areas such as walking and trucking.
#     + **Example: **
#
#     `pt = arcgis.geometry.Geometry({"x":-122.435,"y":37.785})
#     buffered_area = BufferStudyArea(area=pt, radii=[1,2,3], units="Minutes", travel_mode="Driving")`
#
#
# - **Named statistical areas** - In all previous examples of different study area types, locations were defined as either points or polygons. Study area locations can also be passed as one or many named statistical areas. This form of study area lets you define an area as a standard geographic statistical feature, such as a census or postal area, for example, to obtain enrichment information for a U.S. state, county, or ZIP Code or a Canadian province or postal code. When the NamedArea instances should be combined together (union), a list of such NamedArea instances should constitute a study area in the list of requested study areas.
#     + **Example:**
#
#     `usa.subgeographies.states['California'].zip5['92373']`
#
#
# - **Polygon geometries** - Locations can given as polygon geometries.
#     + **Example Polygon geometry: **
#
#     `arcgis.geometry.Geometry({"rings":[[[-117.185412,34.063170],[-122.81,37.81],[-117.200570,34.057196],[-117.185412,34.063170]]],"spatialReference":{"wkid":4326}})`

# %% [markdown]
# # Creating Reports

# %%
report = create_report(study_areas=["380 New York Street, Redlands, CA"],
                     report="tapestry_profileNEW",
                     export_format="PDF", 
                     out_folder=r"c:\xc", out_name="esri_tapestry_profile.pdf")
report
# Out:
# 'c:\\xc\\esri_tapestry_profile.pdf'

# %% [markdown]
# # Enriching study areas
#
# The enrich() method returns a Spatial DataFrame can can either be used for mapping via the gis.content.import_data method or for further analysis. If return_geometry is set to false, a Pandas' DataFrame is returned instead.

# %% [markdown]
# ### Example: Enriching a named statistical area
#
# Enriching zip code 92373 in California using the 'Age' data collection:

# %%
redlands = usa.subgeographies.states['California'].zip5['92373']

# %%
enrich(study_areas=[redlands], data_collections=['Age'], )
# Out:
#    FEM0  FEM10  FEM15  FEM20  FEM25  FEM30  FEM35  FEM40  FEM45  FEM5  \
# 0   871    931    962   1123   1147   1206   1126   1041   1098   891
#
#                          ...                          MALE75  MALE80  MALE85  \
# 0                        ...                             477     317     362
#
#    OBJECTID  StdGeographyID  StdGeographyLevel  StdGeographyName  \
# 0         1           92373            US.ZIP5          Redlands
#
#    aggregationMethod  sourceCountry  \
# 0      Query:US.ZIP5             US
#
#                                                SHAPE
# 0  {'rings': [[[-117.21461999975689, 34.065140000...
#
# [1 rows x 45 columns]

# %% [markdown]
# ### Example: Enrich all counties in a state

# %%
ca_counties = usa.subgeographies.states['California'].counties

# %%
counties_df = enrich(study_areas=ca_counties, data_collections=['Age'])
counties_df
# Out:
#       FEM0   FEM10   FEM15   FEM20   FEM25   FEM30   FEM35   FEM40   FEM45  \
# 0    19698   19147   18260   19310   21750   19492   17346   16063   16077
# 1      252     333     323     274     270     266     293     298     418
# 2     6009    5676    5132    5730    6425    5824    5291    4987    4917
# 3      358     442     406     401     415     392     413     422     538
# 4     6065    5940    8112   10888    7978    6721    5809    5610    6093
# 5    84409   83941   82177   84307   91156   83313   76213   71910   71553
# 6    79477   76497   74857   82633   90066   79719   70374   65761   65744
# 7      851     812     687     643     762     731     665     616     638
# 8     6239    6245    9859   14292    8643    7601    6554    5949    6005
# 9    11190   10499   10649   10553   10943    9667    8397    7576    7507
# 10     371     458     486     426     438     447     390     427     531
# 11   20668   18942   17445   17438   18597   16683   14568   13010   12625
# 12    1097    1155    1158    1112    1115    1071    1043    1052    1238
# 13  313995  318796  334829  387268  415104  390380  356409  335151  336521
# 14   21466   23726   20863   20830   23275   25123   26114   26147   27054
# 15    1039    1027     944     917     965     898     840     795     835
# 16    2042    2252    2096    1976    2101    2000    1859    1827    1936
# 17    4733    5125    5247    5425    5590    5269    4941    4839    5355
# 18  100672   98784  100886  123203  134038  124775  110907  101644  101682
# 19     706     871     867     725     747     790     809     821    1019
# 20     397     355     359     467     545     489     402     366     410
# 21    6874    6699    6450    6743    6986    5970    5310    5122    5226
# 22    2465    2515    2416    2401    2592    2666    2560    2409    2488
# 23   39745   36230   35078   38367   40700   36516   31418   27665   26799
# 24     670     747     733     680     693     686     666     671     721
# 25    3458    3423    3102    3179    3518    3412    3086    2858    2881
# 26    3851    4397    4363    4193    4219    4354    4300    4225    4574
# 27   13177   13747   13000   13843   16400   15619   14126   13209   13670
# 28     468     476     484     455     494     481     453     454     522
# 29   37248   33703   30896   32353   35360   31080   27416   25028   24670
# 30   33105   37969   34909   33084   35970   37115   37950   37532   39225
# 31     890    1117    1111     951     935     976     956    1036    1333
# 32    1058    1246    1263    1277    1291    1272    1160    1164    1453
# 33    2065    2079    1963    1911    2025    1851    1733    1691    1922
# 34    3054    2711    2425    2643    2975    2836    2512    2153    2091
# 35   13498   13207   17418   20766   16144   14871   12999   11841   12273
# 36    6335    5304    4850    5555    5807    5233    4463    3799    3695
# 37     775     714     721     736     722     675     654     599     730
# 38    6438    7053    9401   12114    8568    7964    7310    6905    7450
# 39   13392   14604   15074   15582   16831   16320   15073   14402   15649
# 40   47323   50068   50590   57125   60205   61600   59673   56910   56069
# 41   60405   63567   58623   59560   66840   70305   70303   68350   67343
# 42   93700  102223  103547  110465  119902  114948  107524  105068  109370
# 43    3612    3488    4468    5565    5053    4691    4166    3654    3537
# 44    7204    7592   10653   11658    9835    9178    8197    7700    8333
# 45      65      62      53      49      66      51      58      81     100
# 46      24      33      29      20      24      24      23      25      34
# 47    4511    5911    5508    4830    4933    4885    5121    5477    6425
# 48   10578   12647   11475   10213   10985   11421   11899   12085   12927
# 49   26804   28987   27900   27227   29705   29111   27265   26646   28037
# 50   49947   48457   46689   53634   60782   55985   50878   46989   46812
# 51    1669    1764    1710    1673    1798    1645    1620    1717    2003
# 52    2001    2543    2559    2454    2521    2414    2434    2468    2970
# 53   17345   14648   17316   28160   44192   44437   35755   29202   26468
# 54     252     264     242     215     215     230     217     241     285
# 55   15763   14432   14074   15300   16211   15101   13446   11985   11769
# 56   27548   27407   26074   25934   28114   25846   23836   22632   22349
# 57    6097    7826    7016    5906    5659    6075    6863    8018    9429
#
#       FEM5                        ...                          MALE75  MALE80  \
# 0    19271                        ...                            5020    3217
# 1      271                        ...                             271     165
# 2     5814                        ...                            1772    1072
# 3      366                        ...                             383     255
# 4     5981                        ...                            3095    2107
# 5    84041                        ...                           26944   18151
# 6    77343                        ...                           17677   10838
# 7      835                        ...                             241     150
# 8     6294                        ...                            1895    1222
# 9    10701                        ...                            2283    1421
# 10     440                        ...                             429     244
# 11   19489                        ...                            3872    2410
# 12    1085                        ...                             853     530
# 13  313178                        ...                           98371   64781
# 14   23197                        ...                            9147    6126
# 15    1004                        ...                             349     217
# 16    2163                        ...                             542     337
# 17    4847                        ...                            2882    1770
# 18   99862                        ...                           33285   23139
# 19     769                        ...                             789     510
# 20     357                        ...                             150      92
# 21    6772                        ...                            1798    1186
# 22    2465                        ...                            1277     746
# 23   37791                        ...                            8555    5495
# 24     682                        ...                             335     203
# 25    3453                        ...                            1142     775
# 26    4116                        ...                            1998    1425
# 27   13453                        ...                            4589    2840
# 28     451                        ...                             356     241
# 29   35498                        ...                            7552    4467
# 30   36225                        ...                           12773    8132
# 31     987                        ...                            1011     572
# 32    1137                        ...                            1120     763
# 33    2065                        ...                            1009     652
# 34    2920                        ...                             748     442
# 35   13473                        ...                            5016    3665
# 36    5667                        ...                            1107     653
# 37     731                        ...                             340     225
# 38    6820                        ...                            4059    2744
# 39   13905                        ...                            6298    3966
# 40   49093                        ...                           16318   10422
# 41   63295                        ...                           20230   13240
# 42   98018                        ...                           34895   23305
# 43    3612                        ...                            1656    1033
# 44    7425                        ...                            2688    1689
# 45      65                        ...                              75      40
# 46      33                        ...                              17      10
# 47    5225                        ...                            2897    1706
# 48   11896                        ...                            5437    3571
# 49   28001                        ...                            9234    6041
# 50   49273                        ...                           14749    9959
# 51    1725                        ...                            1123     724
# 52    2242                        ...                            1865    1221
# 53   15785                        ...                           10835    7572
# 54     279                        ...                             175     104
# 55   15169                        ...                            4129    2770
# 56   27371                        ...                            6874    4359
# 57    7157                        ...                            4063    2593
#
#     MALE85  OBJECTID  StdGeographyID  StdGeographyLevel  \
# 0     3120         1           06099        US.Counties
# 1      126         2           06105        US.Counties
# 2      925         3           06039        US.Counties
# 3      172         4           06043        US.Counties
# 4     2277         5           06007        US.Counties
# 5    16402         6           06065        US.Counties
# 6     9276         7           06071        US.Counties
# 7      146         8           06011        US.Counties
# 8     1261         9           06113        US.Counties
# 9     1349        10           06047        US.Counties
# 10     183        11           06063        US.Counties
# 11    2292        12           06107        US.Counties
# 12     511        13           06093        US.Counties
# 13   65018        14           06037        US.Counties
# 14    6547        15           06081        US.Counties
# 15     208        16           06021        US.Counties
# 16     323        17           06069        US.Counties
# 17    1710        18           06089        US.Counties
# 18   25026        19           06073        US.Counties
# 19     495        20           06005        US.Counties
# 20      53        21           06051        US.Counties
# 21    1019        22           06025        US.Counties
# 22     751        23           06045        US.Counties
# 23    5683        24           06019        US.Counties
# 24     189        25           06035        US.Counties
# 25     638        26           06101        US.Counties
# 26    1514        27           06055        US.Counties
# 27    2628        28           06095        US.Counties
# 28     227        29           06027        US.Counties
# 29    3743        30           06029        US.Counties
# 30    8525        31           06013        US.Counties
# 31     447        32           06009        US.Counties
# 32     686        33           06109        US.Counties
# 33     531        34           06103        US.Counties
# 34     364        35           06115        US.Counties
# 35    4088        36           06083        US.Counties
# 36     559        37           06031        US.Counties
# 37     198        38           06015        US.Counties
# 38    2883        39           06079        US.Counties
# 39    4529        40           06097        US.Counties
# 40   10537        41           06001        US.Counties
# 41   12970        42           06085        US.Counties
# 42   22969        43           06059        US.Counties
# 43    1017        44           06023        US.Counties
# 44    1876        45           06087        US.Counties
# 45      39        46           06091        US.Counties
# 46       5        47           06003        US.Counties
# 47    1498        48           06017        US.Counties
# 48    3435        49           06061        US.Counties
# 49    6173        50           06111        US.Counties
# 50    9837        51           06067        US.Counties
# 51     628        52           06033        US.Counties
# 52    1169        53           06057        US.Counties
# 53    7798        54           06075        US.Counties
# 54     103        55           06049        US.Counties
# 55    2876        56           06053        US.Counties
# 56    4282        57           06077        US.Counties
# 57    2712        58           06041        US.Counties
#
#           StdGeographyName  aggregationMethod  sourceCountry  \
# 0        Stanislaus County  Query:US.Counties             US
# 1           Trinity County  Query:US.Counties             US
# 2            Madera County  Query:US.Counties             US
# 3          Mariposa County  Query:US.Counties             US
# 4             Butte County  Query:US.Counties             US
# 5         Riverside County  Query:US.Counties             US
# 6    San Bernardino County  Query:US.Counties             US
# 7            Colusa County  Query:US.Counties             US
# 8              Yolo County  Query:US.Counties             US
# 9            Merced County  Query:US.Counties             US
# 10           Plumas County  Query:US.Counties             US
# 11           Tulare County  Query:US.Counties             US
# 12         Siskiyou County  Query:US.Counties             US
# 13      Los Angeles County  Query:US.Counties             US
# 14        San Mateo County  Query:US.Counties             US
# 15            Glenn County  Query:US.Counties             US
# 16       San Benito County  Query:US.Counties             US
# 17           Shasta County  Query:US.Counties             US
# 18        San Diego County  Query:US.Counties             US
# 19           Amador County  Query:US.Counties             US
# 20             Mono County  Query:US.Counties             US
# 21         Imperial County  Query:US.Counties             US
# 22        Mendocino County  Query:US.Counties             US
# 23           Fresno County  Query:US.Counties             US
# 24           Lassen County  Query:US.Counties             US
# 25           Sutter County  Query:US.Counties             US
# 26             Napa County  Query:US.Counties             US
# 27           Solano County  Query:US.Counties             US
# 28             Inyo County  Query:US.Counties             US
# 29             Kern County  Query:US.Counties             US
# 30     Contra Costa County  Query:US.Counties             US
# 31        Calaveras County  Query:US.Counties             US
# 32         Tuolumne County  Query:US.Counties             US
# 33           Tehama County  Query:US.Counties             US
# 34             Yuba County  Query:US.Counties             US
# 35    Santa Barbara County  Query:US.Counties             US
# 36            Kings County  Query:US.Counties             US
# 37        Del Norte County  Query:US.Counties             US
# 38  San Luis Obispo County  Query:US.Counties             US
# 39           Sonoma County  Query:US.Counties             US
# 40          Alameda County  Query:US.Counties             US
# 41      Santa Clara County  Query:US.Counties             US
# 42           Orange County  Query:US.Counties             US
# 43         Humboldt County  Query:US.Counties             US
# 44       Santa Cruz County  Query:US.Counties             US
# 45           Sierra County  Query:US.Counties             US
# 46           Alpine County  Query:US.Counties             US
# 47        El Dorado County  Query:US.Counties             US
# 48           Placer County  Query:US.Counties             US
# 49          Ventura County  Query:US.Counties             US
# 50       Sacramento County  Query:US.Counties             US
# 51             Lake County  Query:US.Counties             US
# 52           Nevada County  Query:US.Counties             US
# 53    San Francisco County  Query:US.Counties             US
# 54            Modoc County  Query:US.Counties             US
# 55         Monterey County  Query:US.Counties             US
# 56      San Joaquin County  Query:US.Counties             US
# 57            Marin County  Query:US.Counties             US
#
#                                                 SHAPE
# 0   {'rings': [[[-120.52871500011639, 37.739950999...
# 1   {'rings': [[[-122.56813599978592, 41.367034000...
# 2   {'rings': [[[-119.27248000020894, 37.739529999...
# 3   {'rings': [[[-119.53399900030351, 37.902922000...
# 4   {'rings': [[[-121.40462100065271, 40.146641000...
# 5   {'rings': [[[-114.45553799988396, 34.079816000...
# 6   {'rings': [[[-115.65169500002976, 35.809155999...
# 7   {'rings': [[[-122.12562699946037, 39.414593000...
# 8   {'rings': [[[-122.01722099977187, 38.925912999...
# 9   {'rings': [[[-120.25794400016433, 37.390609999...
# 10  {'rings': [[[-121.34653100065071, 40.449715000...
# 11  {'rings': [[[-118.38901200043054, 36.744775000...
# 12  {'rings': [[[-122.32029299986178, 42.008608999...
# 13  {'rings': [[[-117.75310099940796, 34.823241000...
# 14  {'rings': [[[-122.42808200031217, 37.708431000...
# 15  {'rings': [[[-122.78756600045962, 39.800560999...
# 16  {'rings': [[[-121.44911900068922, 36.988210999...
# 17  {'rings': [[[-122.29457300093597, 41.184977999...
# 18  {'rings': [[[-117.24920900024354, 33.451323999...
# 19  {'rings': [[[-120.07763899938011, 38.708886999...
# 20  {'rings': [[[-119.5519919999696, 38.6899440000...
# 21  {'rings': [[[-114.73336699964517, 33.433694999...
# 22  {'rings': [[[-123.70742299986901, 40.001802999...
# 23  {'rings': [[[-119.00146500008938, 37.570896999...
# 24  {'rings': [[[-121.20985400021874, 41.184414000...
# 25  {'rings': [[[-121.63015000029307, 39.305668000...
# 26  {'rings': [[[-122.35188800050159, 38.836267999...
# 27  {'rings': [[[-121.8806179994349, 38.5380259998...
# 28  {'rings': [[[-117.90575400014615, 37.464917999...
# 29  {'rings': [[[-117.75094500013677, 35.798202000...
# 30  {'rings': [[[-121.5922400002879, 38.0951800010...
# 31  {'rings': [[[-120.07246099958044, 38.509088000...
# 32  {'rings': [[[-120.00835999924371, 38.426676999...
# 33  {'rings': [[[-121.68578699991424, 40.453133000...
# 34  {'rings': [[[-121.01774800011697, 39.595758000...
# 35  {'rings': [[[-120.07950499995434, 35.113000000...
# 36  {'rings': [[[-119.54800600034034, 36.488962000...
# 37  {'rings': [[[-123.51791100062034, 42.000756000...
# 38  {'rings': [[[-121.1259369995755, 35.7939409997...
# 39  {'rings': [[[-123.01878499977991, 38.852370000...
# 40  {'rings': [[[-122.27167899966491, 37.904723999...
# 41  {'rings': [[[-121.83286600027165, 37.484336000...
# 42  {'rings': [[[-117.91576500044377, 33.946925000...
# 43  {'rings': [[[-123.88569500039881, 41.465843999...
# 44  {'rings': [[[-122.15057000008379, 37.276200000...
# 45  {'rings': [[[-120.86131400020686, 39.770390000...
# 46  {'rings': [[[-119.90431499971437, 38.933323999...
# 47  {'rings': [[[-120.12602699996667, 39.067455000...
# 48  {'rings': [[[-120.00632299966396, 39.316496000...
# 49  {'rings': [[[-119.44235200000823, 34.901273999...
# 50  {'rings': [[[-121.52176700031845, 38.736400999...
# 51  {'rings': [[[-122.79091300006989, 39.579716999...
# 52  {'rings': [[[-120.65366100020383, 39.526073000...
# 53  {'rings': [[[-122.41880000012479, 37.811470000...
# 54  {'rings': [[[-121.29651300010848, 41.997514000...
# 55  {'rings': [[[-121.69918699992458, 36.915819000...
# 56  {'rings': [[[-121.02708400017943, 38.300252000...
# 57  {'rings': [[[-122.9077279998692, 38.3206429996...
#
# [58 rows x 45 columns]

# %%
m = gis.map('California')
m
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oceans', 'osm', 'satellite', 'streets', 'streets-navigation-vector', 'streets-night-vector', 'streets-relief-vector', 'streets-vector', 'terrain', 'topo', 'topo-vector'], center=[0, 0])

# %%
lyr = gis.content.import_data(df=counties_df, title="CA county population")

# %%
m.add_layer(lyr.layers[0], {'renderer': 'ClassedColorRenderer', 
                            'field_name':'FEM0'})

# %% [markdown]
# ### Example: Using comparison levels

# %% [markdown]
# The information for the study areas can also be compared with standard geography areas in other levels.
# In the example below, the 92373 zip code intersects with both Riverside and San Bernardino counties in California, and hence both these counties as well as the state of California are returned along with the results for the named zip code,  as the comparison levels includes both States and Counties.

# %%
enrich(study_areas=[redlands], data_collections=['Age'], 
       comparison_levels=['US.Counties', 'US.States'])
# Out:
# c:\xc\github\geosaurus\src\arcgis\features\_data\geodataset\geodataframe.py:1038: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   frame.set_value(index=idx, col=self._geometry_column_name, value=g)
#       FEM0    FEM10    FEM15    FEM20    FEM25    FEM30    FEM35    FEM40  \
# 0      871      931      962     1123     1147     1206     1126     1041
# 1    84409    83941    82177    84307    91156    83313    76213    71910
# 2    79477    76497    74857    82633    90066    79719    70374    65761
# 3  1245148  1260883  1269825  1405639  1510193  1429495  1313060  1237282
#
#      FEM45     FEM5                        ...                          \
# 0     1098      891                        ...
# 1    71553    84041                        ...
# 2    65744    77343                        ...
# 3  1250328  1251583                        ...
#
#    MALE75  MALE80  MALE85  OBJECTID  StdGeographyID  StdGeographyLevel  \
# 0     477     317     362         1           92373            US.ZIP5
# 1   26944   18151   16402         2           06065        US.Counties
# 2   17677   10838    9276         3           06071        US.Counties
# 3  408593  268305  266546         4              06          US.States
#
#         StdGeographyName  aggregationMethod  sourceCountry  \
# 0               Redlands      Query:US.ZIP5             US
# 1       Riverside County  Query:US.Counties             US
# 2  San Bernardino County  Query:US.Counties             US
# 3             California    Query:US.States             US
#
#                                                SHAPE
# 0  {'rings': [[[-117.21461999975689, 34.065140000...
# 1  {'spatialReference': {'wkid': 4326, 'latestWki...
# 2  {'spatialReference': {'wkid': 4326, 'latestWki...
# 3  {'spatialReference': {'wkid': 4326, 'latestWki...
#
# [4 rows x 45 columns]

# %% [markdown]
# ### Example: Enriching street address
#
# The example below uses a street address as a study area instead.

# %%
enrich(study_areas=["380 New York St Redlands CA 92373"], data_collections=['Age'], comparison_levels=['US.Counties', 'US.States'])
# Out:
# c:\xc\github\geosaurus\src\arcgis\features\_data\geodataset\geodataframe.py:1038: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   frame.set_value(index=idx, col=self._geometry_column_name, value=g)
#       FEM0    FEM10    FEM15    FEM20    FEM25    FEM30    FEM35    FEM40  \
# 0      435      377      417      602      615      577      508      403
# 1    79477    76497    74857    82633    90066    79719    70374    65761
# 2  1245148  1260883  1269825  1405639  1510193  1429495  1313060  1237282
#
#      FEM45     FEM5                        ...                          \
# 0      386      391                        ...
# 1    65744    77343                        ...
# 2  1250328  1251583                        ...
#
#         StdGeographyName          X          Y  \
# 0                    NaN -117.19567  34.056488
# 1  San Bernardino County -117.19567  34.056488
# 2             California -117.19567  34.056488
#
#                    aggregationMethod    areaType  bufferRadii  bufferUnits  \
# 0  BlockApportionment:US.BlockGroups  RingBuffer          1.0    esriMiles
# 1                  Query:US.Counties         NaN          NaN          NaN
# 2                    Query:US.States         NaN          NaN          NaN
#
#    bufferUnitsAlias  sourceCountry  \
# 0             Miles             US
# 1               NaN             US
# 2               NaN             US
#
#                                                SHAPE
# 0  {'rings': [[[-117.1956703176181, 34.0709967371...
# 1  {'spatialReference': {'wkid': 4326, 'latestWki...
# 2  {'spatialReference': {'wkid': 4326, 'latestWki...
#
# [3 rows x 51 columns]

# %% [markdown]
# ### Example: Buffering locations using non overlapping disks
#
# The example below creates non-overlapping disks of radii 1, 3 and 5 Miles respectively from a street address and enriches these using the 'Age' data collection.

# %%
buffered = BufferStudyArea(area='380 New York St Redlands CA 92373',
                           radii=[1,3,5], units='Miles', overlap=False)
enrich(study_areas=[buffered], data_collections=['Age'])
# Out:
#    FEM0  FEM10  FEM15  FEM20  FEM25  FEM30  FEM35  FEM40  FEM45  FEM5  \
# 0   435    377    417    602    615    577    508    403    386   391
# 1  1759   1809   2158   2280   2404   2369   2060   1908   1941  1786
# 2  2790   2776   2628   3257   3596   2975   2538   2364   2453  2807
#
#                          ...                          OBJECTID          X  \
# 0                        ...                                 1 -117.19567
# 1                        ...                                 2 -117.19567
# 2                        ...                                 3 -117.19567
#
#            Y                  aggregationMethod         areaType  bufferRadii  \
# 0  34.056488  BlockApportionment:US.BlockGroups  RingBufferBands            1
# 1  34.056488  BlockApportionment:US.BlockGroups  RingBufferBands            3
# 2  34.056488  BlockApportionment:US.BlockGroups  RingBufferBands            5
#
#    bufferUnits  bufferUnitsAlias  sourceCountry  \
# 0        Miles             Miles             US
# 1        Miles             Miles             US
# 2        Miles             Miles             US
#
#                                                SHAPE
# 0  {'rings': [[[-117.1956703176181, 34.0709967371...
# 1  {'rings': [[[-117.1956703176181, 34.1000138698...
# 2  {'rings': [[[-117.1956703176181, 34.1290308652...
#
# [3 rows x 48 columns]

# %% [markdown]
# ### Example: Using drive times as study areas
#
# The example below creates 5 and 10 minute drive times from a street address and enriches these using the 'Age' data collection.

# %%
buffered = BufferStudyArea(area='380 New York St Redlands CA 92373', 
                           radii=[5, 10], units='Minutes', 
                           travel_mode='Driving')
drive_time_df = enrich(study_areas=[buffered], data_collections=['Age'])

# %%
drive_time_df
# Out:
#    FEM0  FEM10  FEM15  FEM20  FEM25  FEM30  FEM35  FEM40  FEM45  FEM5  \
# 0   367    319    345    484    509    463    398    320    305   329
# 1  2299   2256   2651   2988   3075   2945   2577   2317   2329  2263
#
#                          ...                          OBJECTID          X  \
# 0                        ...                                 1 -117.19567
# 1                        ...                                 2 -117.19567
#
#            Y                  aggregationMethod            areaType  \
# 0  34.056488  BlockApportionment:US.BlockGroups  NetworkServiceArea
# 1  34.056488  BlockApportionment:US.BlockGroups  NetworkServiceArea
#
#    bufferRadii  bufferUnits    bufferUnitsAlias  sourceCountry  \
# 0            5      Minutes  Drive Time Minutes             US
# 1           10      Minutes  Drive Time Minutes             US
#
#                                                SHAPE
# 0  {'rings': [[[-117.1989212044467, 34.0751628879...
# 1  {'rings': [[[-117.20049285913858, 34.130182266...
#
# [2 rows x 48 columns]

# %% [markdown]
# ### Visualize results on a map

# %% [markdown]
# The returned spatial dataframe can be visualized on a map as shown below:

# %%
redlands_map = gis.map('Redlands, CA')
redlands_map
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oceans', 'osm', 'satellite', 'streets', 'streets-navigation-vector', 'streets-night-vector', 'streets-relief-vector', 'streets-vector', 'terrain', 'topo', 'topo-vector'], center=[0, 0])

# %%
redlands_map.draw(drive_time_df.to_featureset())

# %% [markdown]
# ## Saving GeoEnrichment Results
#
# The results can be saved back to a GIS as a feature layer
#
# #### Example: Save Business Data to a Feature Layer

# %%
gis.content.import_data(df=drive_time_df, title="Age statistics within 5,10 minutes of drive time from Esri")
# Out:
# <Item title:"Age statistics within 5,10 minutes of drive time from Esri" type:Feature Layer Collection owner:singhqa>
