# %% [markdown]
# # What's new in version 1.6.2
#
# #### New
# * Adds `esrly_stopping` and `checkpoint` parameters to [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#) [`Unet.fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#arcgis.learn.UnetClassifier.fit) and [`SingelShotDetector.fit()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#arcgis.learn.SingleShotDetector.fit) methods
# * Adds capability to regenerate a manifest for [`big data file share`](https://enterprise.arcgis.com/en/server/latest/get-started/windows/what-is-a-big-data-file-share.htm%20) item
# * Adds an image classifier to [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#) to classify the area occupied by a geographical feature based on the imagery it overlaps
# * Adds [`find_centroids()`](https://developers.arcgis.com/python/api-reference/arcgis.features.find_locations.html#find-similar-locations) reference documentation
# * Adds support for all `torchvision.models` backbones (except `inception_v3`) to [`SingleShotDetector`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#singleshotdetector)
# * Adds [`query_domains()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayerCollection.query_domains) method and [`relationships`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayerCollection.relationships) property to the [`FeatureLayerCollection`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#featurelayercollection) class
# * Adds reference documentation for [`LivingAtlas`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#livingatlas)
# * Adds [`advanced_search()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.ContentManager.advanced_search) method to [`ContentManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#contentmanager) class
# * Adds `historic_moment` and `return_true_curve` parameters to [`FeatureLayer.query_related_records()`](file:///C:/Users/john3092/Documents/GitHub/geosaurus/docs/api_ref/build/html/arcgis.features.toc.html#arcgis.features.FeatureLayer.query_related_records)
# * Adds support for `areaTypes` in [`OfflineMapAreaManger.create()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#offlinemapareamanager)
# * Adds Dot Density support to the [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#geoaccessor) [`plot()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html?highlight=geoaccessor%20plot#arcgis.features.GeoAccessor.plot) method
# * Adds reference documentation for [`Hub`](https://developers.arcgis.com/python/api-reference/arcgis.apps.hub.html) module to the [`apps`](https://developers.arcgis.com/python/api-reference/arcgis.apps.html#) module
#
# #### Fixes
# * Fixes issue when adding more than 25 [`workers`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce.html#worker) to a [`Workforce Project`](https://developers.arcgis.com/python/api-reference/arcgis.apps.workforce.html#arcgis.apps.workforce.Project)
# * Fixes `KeyError` when using `out_statistics` parameter on [`FeatureLayer.query()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#featurelayer)
# * Fixes BUG-000118809 - The [`job_statistics()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html?highlight=job_statistics#arcgis.mapping.MapImageLayerManager.job_statistics) method fails when using the jobID of updating tiles
# * Fixes BUG-000119377 -Delete_certificate(certificate) function in `arcgis.server` module returns error
# * Fixes error when creating users from a csv in ArcGIS Online
# * Fixes raster load failures when instantiating [`ImageryLayer()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc.html#imagerylayer)
# * Fixes bug in [`UnetClassifier()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#unetclassifier) predicting only one class
# * Fixes to [`raster.analytics.interpolate_points()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics.html#interpolate-points) when the error raster is set to False
# * Fixes [`raster.orthomapping.query_camera_info()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.orthomapping.html#query-camera-info) method when run outside a Jupyter notebook
# * Improvements to [`Item.publish()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.Item.publish) for tile packages
# * Improves reference documentation for
#  * [`arcgis.features.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis.html) module
#  * [`create_buffers()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity.html#create-buffers)
#  * [`create_viewshed()`](https://developers.arcgis.com/python/api-reference/arcgis.features.find_locations.html#create-viewshed)
#  * [`create_drive_time_areas`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity.html#create-drive-time-areas)
#  * [`create_route_layers()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis.html#create-route-layers)
#  * [`derive_new_locations()`](https://developers.arcgis.com/python/api-reference/arcgis.features.find_locations.html#derive-new-locations)
#  * [`create_watersheds()`](https://developers.arcgis.com/python/api-reference/arcgis.features.find_locations.html#create-watersheds)
#  * [`dissolve_boundaries()`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data.html#dissolve-boundaries)
#  * [`enrich_layer()`](https://developers.arcgis.com/python/api-reference/arcgis.features.enrich_data.html)
#  * [`extract_data()`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data.html#extract-data)
#  * [`find_hot_spots()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analyze_patterns.html#find-hot-spots)
#  * [`choose_best_facilities()`](https://developers.arcgis.com/python/api-reference/arcgis.features.find_locations.html#choose-best-facilities)
#  * [`find_nearest()`](https://developers.arcgis.com/python/api-reference/arcgis.features.use_proximity.html#find-nearest)
#  * [`find_existing_locations()`](https://developers.arcgis.com/python/api-reference/arcgis.features.find_locations.html#find-existing-locations)
#  * [`find_outliers()`](https://developers.arcgis.com/python/api-reference/arcgis.features.analyze_patterns.html#find-outliers)
#  * [`find_point_clusters`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis.html#find-point-clusters)
#  * [`find_similiar_locations`](https://developers.arcgis.com/python/api-reference/arcgis.features.find_locations.html#find-similar-locations)
#  * [`join_features()`](https://developers.arcgis.com/python/api-reference/arcgis.features.summarize_data.html#join-features)
#  * [`merge_layers()`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data.html#merge-layers)
#  * [`overlay_layers()`](https://developers.arcgis.com/python/api-reference/arcgis.features.manage_data.html#overlay-layers)
#  * [`plan_routes()`](https://developers.arcgis.com/python/api-reference/arcgis.features.user_proximity.html#plan-routes)
# * Ensures column names of [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#geoaccessor) do not contain invalid characters for drawing
# * Fixes use of complex [`Raster Function Template`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.RFT.html#arcgis-raster-functions-rft) with [`attribute_table`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc.html?highlight=export%20image#arcgis.raster.ImageryLayer.attribute_table) property and [`export_image()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.toc.html?highlight=export%20image#arcgis.raster.ImageryLayer.export_image) function
# * Adds support for a list of lists as the `neighborhood_values` parameter in the [`focal_stats()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.html#focal-stats) function
# * Adds support for the geoextent of linestrings and polygons when reading GeoJSON as a FeatureSet
# * Fixes to the [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#geoaccessor)  [`from_featureclass()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.GeoAccessor.from_featureclass) method when specifying fields in the feature class
# * Improves error handling in the [`map widget`](https://developers.arcgis.com/python/api-reference/arcgis.widgets.html#mapview)
