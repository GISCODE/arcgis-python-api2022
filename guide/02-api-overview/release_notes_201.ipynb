# %% [markdown]
# # What's new in version 2.0.1
#
# ## New
# * Adds [`arcgis.graph`](https://developers.arcgis.com/python/api-reference/arcgis.graph.html) module
#   * [`KnowledgeGraph`](https://developers.arcgis.com/python/api-reference/arcgis.graph.html#knowledgegraph) class
#     * Provides access to adatamodel and properties
#     * Provides methods to search and query the graph
#   * Explore **[ArcGIS Knowledge](https://pro.arcgis.com/en/pro-app/latest/help/data/knowledge/get-started-with-arcgis-knowledge.htm)** to learn more.
# * Adds new [`arcgis.gis.sharing`](https://developers.arcgis.com/python/api-reference/arcgis.gis.sharing.html) submodule
#   * [`UserInvitationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#userinvitationmanager)
#   * [`Invitation`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#invitation)
# * Adds _[Typing](https://docs.python.org/3/library/typing.html)_ to modules
#
#
# ### [Guides](https://developers.arcgis.com/python/guide/)
# * [Working with Big Data](https://developers.arcgis.com/python/guide)
#   * Restructured original 3 guides 10 new guides:
#     * [What is Geospatial big data](https://developers.arcgis.com/python/guide/01-introduction/)
#     * [Make your data accessible to the GeoAnalytics Server](https://developers.arcgis.com/python/guide/02-making-your-data-accessible-to-ga-server/)
#     * [Performing big data analysis](https://developers.arcgis.com/python/guide/03-performing-big-data-analysis/)
#     * [Analyzing Patterns](https://developers.arcgis.com/python/guide/04-analyze-patterns/)
#     * [Finding Locations](https://developers.arcgis.com/python/guide/05-finding-locations/)
#     * [Summarizing Data](https://developers.arcgis.com/python/guide/06-summarizing-data/)
#     * [Use Proximity](https://developers.arcgis.com/python/guide/07-use-proximity/)
#     * [Performing Data Enrichment](https://developers.arcgis.com/python/guide/08-performing-data-enrichment/)
#     * [Managing Big Data](https://developers.arcgis.com/python/guide/08-performing-data-enrichment/)
#     * [Extending GeoAnalytics with Custom Tools](https://developers.arcgis.com/python/guide/08-performing_data_enrichment/)
# * [Deep Learning with ArcGIS](https://developers.arcgis.com/python/guide)
#   * [How WNet_cGAN works](https://developers.arcgis.com/python/guide/how-wnet-cgan-works)
#   * [How AutoDL Works](https://developers.arcgis.com/python/guide/how-AutoDL-works/)
#
#
# ### [Samples](https://developers.arcgis.com/python/sample-notebooks/)
# * [GIS analysts and data scientists](https://developers.arcgis.com/python/sample-notebooks/)
#  * Deprecates [Translating Story Map from one language to another using Deep Learning](https://developers.arcgis.com/python/sample-notebooks/translating-story-map-from-one-language-to-another/)
# * **New Samples:**
#  * [Training a wind turbine detection model using large volumes of training data](https://developers.arcgis.com/python/samples/training-a-wind-turbine-detection-model-using-large-volume-of-training-data/)
#  * [Lunar Craters Detection using Deep Learning](https://developers.arcgis.com/python/samples/lunar-craters-detection-from-dem-using-deep-learning/)
#  * [Landsat 8 to Sentinel-2 using Pix2Pix](https://developers.arcgis.com/python/samples/landsat8-to-sentinel2-pix2pix/)
#  * [Image scene classification using FeatureClassifier](https://developers.arcgis.com/python/samples/image-scene-classification-using-feature-classifier/)
#  * [Covid case forecasting Using TimeSeriesModel from arcgis.learn](https://developers.arcgis.com/python/samples/covid-case-forecasting-for-alabama-state-using-timeseriesmodel-from-arcgis-learn/)
# * [Org Administrators](https://developers.arcgis.com/python/sample-notebooks/)
#
# ### Module Changes
#
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#)
# * [`User`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#user)
#   * Adds `invitations` property
#   * ENH-000142116 Adds [`report()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.User.reset) method to return item size
# * [`UserManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#usermanager)
#   * ENH-000142761 Adds documentation for [`create()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.UserManager.create) to retrieve all possible values for `user_type` parameter
# * [`ContentManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#contentmanager)
#   * Adds documentation to indicate maximum upload size for:
#     * [`analyze()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.ContentManager.analyze)
#     * [`generate()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.ContentManager.generate)
#   * Enhances performance for [`add()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.ContentManager.add) when `data` has to be added in parts
#   * Updates `copy_data` parameter documentation in [`clone_items()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.ContentManager.clone_items)
#   * Adds [`dependency_manager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.ContentManager.dependency_manager) property for `ArcGIS Enterprise` items
#
# #### [`arcgis.gis.admin`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#)
# * Adds [`KubernetesAdmin`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#kubernetesadmin) class documentation
# * [`CollaborationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#collaborationmanager)
#   * Adds `enable_bidirectional_sync` parameter
# * [`LicenseManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#licensemanager)
#   * Adds [`provisions()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.LicenseManager.provisions) method to obtain, assign and revoke provisions
#
# #### [`arcgis.gis.server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server.html)
# * [`Server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server.html#server)
#   * [`publish_sd()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server.html#arcgis.gis.server.Server.publish_sd)
#     * Adds `service_config` parameter to override default values
#     * Adds `future` parameter for asynchronous processing
#
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html)
# * [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#geoaccessor) (_GeoAccessor_)
#   * Updates [`relationship()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.GeoAccessor.relationship) documentation to clarify spatial operation definitions and behavior
#   * Adds `class_count` parameter documentation to [`plot()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.GeoAccessor.plot)
#
# #### [`arcgis.features.managers`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#)
# * [`Version`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#version)
#   * Adds parameter table to [`reconcile()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#arcgis.features._version.Version.reconcile) documentation
#   * Adds parameter documentation to [`differences()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#arcgis.features._version.Version.differnces):
#     * `from_moment`
#     * `layers`
#     * `future` - asynchronous processing
#   * Adds parameter documentation to [`post()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#arcgis.features._version.Version.post)
#     * `rows`
#     * `future` - asynchronous processing
# * [`VersionManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#versionmanager)
#   * Enhances [`create()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#arcgis.features._version.VersionManager.create) to return dictionary object with successful creation
# * [`ParcelFabricManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#parcelfabricmanager)
#   * Updates [`delete()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#arcgis.features._parcel.ParcelFabricManager.delete) to return dictionary as result
#
# #### [`arcgis.raster.analytics`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics.html#)
# * **New Functions:**
#   * [`export_to_tile_package()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics.html#export-to-tile-package)
#
# #### [`arcgis.geometry`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html)
# * For `Point`, `Polyline`, `Polygon` and `Multipoint` objects:
#   * Adds ability to use numeric operators to perform specific spatial operations:
#     * `+` performs `intersect`
#     * `-` performs `difference`
#     * `|` performs `union`
#     * `^` performs `symmetricDifference`
# * [`Geometry`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html#geometry)
#   * Updates [`intersect()`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html#arcgis.geometry.Geometry.intersect) documentation return statement
#   * Updates documentation to note required engine for certain operations:
#     * [`query_point_and_distance()`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html#arcgis.geometry.Geometry.query_point_and_distance)
#     * [`clip()`]([`query_point_and_distance()`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html#arcgis.geometry.Geometry.clip)
#
# #### [`arcgis.mapping`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html)
# * [Working with 2D Maps](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#working-with-2d-maps)
#   * [`WebMap`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#webmap)
#     * Adds [`configure_pop_ups()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#arcgis.mapping.WebMap.configure_pop_ups) method
#     * Adds [`view_bookmarks()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#arcgis.mapping.WebMap.view_bookmarks) method for enabling/disabling bookmarks in Map Viewer
#
# #### [`arcgis.realtime`](https://developers.arcgis.com/python/api-reference/arcgis.realtime.html)
# * General updates to improve documentation
# * Enhances numerous operations with feed configuration
#
# #### [`arcgis.apps`](https://developers.arcgis.com/python/api-reference/arcgis.apps.html)
# * [`dashboard`](https://developers.arcgis.com/python/api-reference/arcgis.apps.dashboard.html#)
#   * [`Indicator`](https://developers.arcgis.com/python/api-reference/arcgis.apps.dashboard.html#indicator)
#     * Adds documention for [`IndicatorData`](https://developers.arcgis.com/python/api-reference/arcgis.apps.dashboard.html#indicatordata) and [`ReferenceData`](https://developers.arcgis.com/python/api-reference/arcgis.apps.dashboard.html#referencedata)
# * [`storymap`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html)
#   * [`Storymap`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#storymap)
#     * Updates [`save()`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.story.StoryMap.save) with additional checks when `publish=True`
#   * [`Text`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#text)
#     * Adds documentation example for creating text object
#   * [`Sidecar`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#sidecar)
#     * Adds [`get()`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.story_content.Sidecar.get) method for editing multiple nodes
#
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#)
# * [Automated Machine Learning](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#automated-machine-learning)
#   * [`AutoDL`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#autodl)
#     * Enhances initializing when `perform="mode"`
# * [3d Models](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html?highlight=pointcloud#d-models)
#   * Adds training support for geographic coordinate systems
# * Unstructured Text Models](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#unstructured-text-models)
#   * [`arcgis.learn.text`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#arcgis-learn-text-module) module
#     * [`EntityRecognizer`](https://developers.arcgis.com/python/api-reference/arcgis.learn.text.html)
#       * Updates data preparation to [`prepare_textdata()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#prepare-textdata) from [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#prepare-data)
#         * see `text_columns` and `label_columns` parameter documentation in _prepare_textdata()_
#
# #### [`arcgis.auth`](https://developers.arcgis.com/python/api-reference/arcgis.auth.html)
# * Enhances module so that `verify_cert` and `proxy` parameters work efficiently
#   * [`arcgis.apps.tools`](https://developers.arcgis.com/python/api-reference/arcgis.auth.tools.html)
#     * Adds helper tool utilties for automatically detecting proxies:
#       * `detect_proxy()`
#       * `merge_proxies()`

# %% [markdown]
# ## Fixes
#
# ### [Guides](https://developers.arcgis.com/python/guide/)
# * [Feature data and analysis](https://developers.arcgis.com/python/guide)
#  * Updates data used in [Working with Feature Layers and Features](https://developers.arcgis.com/python/guide/working-with-feature-layers-and-features/)
# * [Finding places with geocoding](https://developers.arcgis.com/python/guide/)
#  * Updates [Part 3 - Finding Point of interests](https://developers.arcgis.com/python/guide/part3-finding-point-of-interests/)
#
# ### [Samples](https://developers.arcgis.com/python/samples/)
# * [Content Publishers](https://developers.arcgis.com/python/samples)
#  * Updates [Publishing web maps and web scenes](https://developers.arcgis.com/python/samples/publishing-web-maps-and-web-scenes/) to connect to an ArcGIS Online organization
# * [GIS analysts and data scientists](https://developers.arcgis.com/python/samples)
#  * Updates [SAR to RGB image translation using CycleGAN](https://developers.arcgis.com/python/samples/sar-to-rgb-image-translation-using-cyclegan/)
# * [Org Administrators](https://developers.arcgis.com/python/samples)
#  * Updates [Move existing user content to a new user](https://developers.arcgis.com/python/samples/move-existing-user-content-to-a-new-user/) with more explanation
#
# ### Module Changes
#
# #### [`arcgis.gis`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#)
# * [`GIS`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#gis)
#   * Fixes security issues when using `api_key`
#   * Fixes response handling for tokens with `ArcGIS Online` organizations that have terms and conditions
#   * Fixes issue with [`map()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.GIS.map) not initializing correctly when `zoomlevel` used
# * [`User`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#user)
#   * Fixes [`delete()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.User.delete) to properly handle 3rd Party application provisions
# * [`Item`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#item)
#   * Fixes **[Public Repo Issue #1205](https://github.com/Esri/arcgis-python-api/issues/1205)** where [`usage()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.Item.usage) returns None when using default `as_df=True`
#   * Fixes BUG-000146535 where [`update()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.Item.update) or [`download()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.Item.download) fails with files larger than 2GB
# * [`ContentManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#contentmanager)
#   * Fixes BUG-000146678 where [`clone_items()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.toc.html#arcgis.gis.ContentManager.clone_items) fails on form items for `Survey123` if the form contains non-ASCII characters
#
# #### [`arcgis.gis.admin`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#)
# * [`CollaborationManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#collaborationmanager)
#   * Fixes improperly formed url when using [`update_portal_group_link()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.Collaboration.update_portal_group_link)
# * [`Webhook`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#webhook)
#   * Fixes `AttributeError` on [`update()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.Webhook.update) if option `secret` property is not present
# * [`License`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#license)
#   * Fixes BUG-000144927 with `entitlements` parameter documentation for types of inputs to [`assign()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.admin.html#arcgis.gis.admin.License.assign)
#
# #### [`arcgis.gis.server`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server.html)
# * [`DatastoreManager`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server.html#datastoremanager)
#   * Fixes **[Public Repo Issue #1179](https://github.com/Esri/arcgis-python-api/issues/1179)** by increasing speed of [`list()`](https://developers.arcgis.com/python/api-reference/arcgis.gis.server.html#arcgis.gis.server.DataStoreManager.list)
#
# #### [`arcgis.features`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#)
# * [`FeatureLayer`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#featurelayer)
#   * Fixes [`append()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayer.append) not working in ArcGIS Online
#   * Fixes **[Public Repo Issue #1191](https://github.com/Esri/arcgis-python-api/issues/1191)** where [`delete_features()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayer.delete_features) returns `KeyError` when run asynchronously
# * [`Spatially Enabled DataFrame`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#geoaccessor) (_GeoAccessor_)
#   * [`plot()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.GeoAccessor.plot)
#     * Fixes issue where objects with columns containing `int32` values larger than 1e5 do not draw
# * [`FeatureLayerCollection`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#featurelayercollection)
#   * Fixes BUG-000139327 where [`extract_changes()`](https://developers.arcgis.com/python/api-reference/arcgis.features.toc.html#arcgis.features.FeatureLayerCollection.extract_changes) returned a file path instead of a dictionary
# * [`FeatureSet`]()
#   * Addresses **[Esri Community Post](https://community.esri.com/t5/python-ideas/make-arcpy-featureset-interoperable-with-the/idi-p/1150968)** to update objects so they interoperate with `ArcPy` _FeatureSet_ objects
#
# #### [`arcgis.features.managers`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html)
# * [`FeatureLayerCollectionManager`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#featurelayercollectionmanager)
#   * Fixes BUG-000146997 where [`overwrite()`](https://developers.arcgis.com/python/api-reference/arcgis.features.managers.html#arcgis.features.managers.FeatureLayerCollectionManager.overwrite) fails with `AttributeError: 'PropertyMap' instance has no attribute 'Tables'`
#
# #### [`arcgis.features.analysis`](https://developers.arcgis.com/python/api-reference/arcgis.features.analysis.html#)
# * Fixes BUG-000145235 where `overwrite` failed because parameter is only available in `ArcGIS Enterprise` 10.9.1 and above
# * Fixes internal issue with tools so organization is recognized as `ArcGIS Online` when applicable
#
# #### [`arcgis.raster.functions`](https://developers.arcgis.com/python/api-reference/arcgis.raster.functions.html)
# * [`extract_band()`](https://developers.arcgis.com/python/api-reference/arcgis.raster.analytics.html#extract_band)
#    * Fixes `Unable to complete operation` error because of invalid token
#
# #### [`arcgis.geoenrichment`](https://developers.arcgis.com/python/api-reference/arcgis.geoenrichment.html)
# * Fixes permissions error when accessing or searching for when ArcGIS Online properly configured with service
#
# #### [`arcgis.geometry`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html#)
# * [`Geometry`]()
#   * Fixes **[Public Repo Issue #1173](https://github.com/Esri/arcgis-python-api/issues/1173)** where [`from_shapely()`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html#arcgis.geometry.Geometry.from_shapely) returns a `NameError`
#   * Fixes error when functions were returning `None` for respective engines:
#     * [`clip()`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html#arcgis.geometry.Geometry.clip)
#     * [`query_point_and_distance()`](https://developers.arcgis.com/python/api-reference/arcgis.geometry.html#arcgis.geometry.Geometry.query_point_and_distance)
#
# #### [`arcgis.mapping`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html)
# * [Working with 2D Maps](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#working-with-2d-maps)
#   * [`WebMap`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#webmap)
#     * Fixes [`bookmarks`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#arcgis.mapping.WebMap.bookmarks) setter to properly update definition
# * [Utility Functions for Mapping](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#utility-functions-for-mapping)
#   * Fixes **[Public Repo Issue #1138](https://github.com/Esri/arcgis-python-api/issues/1138) where [`export_map()`](https://developers.arcgis.com/python/api-reference/arcgis.mapping.toc.html#export-map)** fails with custom print service
#
# #### [`arcgis.widgets`](https://developers.arcgis.com/python/api-reference/arcgis.widgets.html)
# * [`MapView`](https://developers.arcgis.com/python/api-reference/arcgis.widgets.html#mapview)
#   * Fixes BUG-000141594 where [`export_to_html()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets.html#arcgis.widgets.MapView.export_to_html) output could not be opened in browser
#   * [`embed()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets.html#arcgis.widgets.MapView.embed)       * Fixes failue to create interactive map in place
#     * Fixes failure to overwrite previous ouput of [`take_screenshot()`](https://developers.arcgis.com/python/api-reference/arcgis.widgets.html#arcgis.widgets.MapView.take_screenshot)
#
# #### [`arcgis.apps`](https://developers.arcgis.com/python/api-reference/arcgis.apps.html)
# * [`dashboard`](https://developers.arcgis.com/python/api-reference/arcgis.apps.dashboard.html#)
#   * [`SerialChart`](https://developers.arcgis.com/python/api-reference/arcgis.apps.dashboard.html#serialchart)
#     * Fixes BUG-000144851 where creation fails when using table layer as input
#   * [`PieChart`](* [`SerialChart`](https://developers.arcgis.com/python/api-reference/arcgis.apps.dashboard.html#piechart)
#     * Fixes BUG-000144512 where `item` parameter documentation incorrectly stated input values
# * [`storymap`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#)
#   * [`Storymap`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#storymap)
#     * Fixes issue when creating multiple Storymaps simultaneously, only one was getting content added
#   * [`Map`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#map)
#     * Fixes [`map`](https://developers.arcgis.com/python/api-reference/arcgis.apps.storymap.html#arcgis.apps.storymap.story_content.Map.map) setter to properly update content
#
# #### [`arcgis.learn`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html)
# * [Data Preparation Methods](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#data-preparation-methods)
#   * Fixes issue with [`prepare_data()`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#prepare-data) when `batch_size` is very small
# * [Automated Machine Learning](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#automated-machine-learning)
#   * [`AutoDL`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html#autodl)
#     * Updates supported models in `network` parameter
# * [3d Models](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html?highlight=pointcloud#d-models)
#   * [`PointCNN`](https://developers.arcgis.com/python/api-reference/arcgis.learn.toc.html?highlight=pointcloud#pointcnn)
#     * Fixes index error with `show_batch()` under specific conditions using `min_points` filter
