# %%
from arcgis.gis import GIS
import getpass

password = getpass.getpass("Enter password: ")
gis = GIS('https://www.arcgis.com', 'johnyHack', password)
print("Connected to: {}\nConnected as: {}".format(gis.properties.urlKey + "." + gis.properties.customBaseUrl,
                                                 gis.users.me.username))
# Out:
# Enter password: ········
# Connected to: esrihax.maps.arcgis.com
# Connected as: johnyHack

# %%
from datetime import datetime

user_list = gis.users.search()
print("{:<25}\t{:<25}".format("Username", "Last Login"))
print("{:*<25}\t{:*<25}".format("", ""))
for user in user_list:
    print("{:<25}\t{}".format(user.username,
                            datetime.fromtimestamp(user.lastLogin/1000).ctime()))
# Out:
# Username                 	Last Login
# *************************	*************************
# AgMapper_hax             	Wed Dec 31 16:00:00 1969
# aharshe_hack             	Sat Mar 21 12:28:00 2015
# alamedaEsri              	Mon Sep 15 13:31:27 2014
# allanUKHack              	Wed Dec  3 14:06:36 2014
# andrew.pong              	Wed Apr 29 11:09:20 2015
# Ben_Cajun                	Wed Apr 23 17:39:16 2014
# cajunhealth              	Thu Apr 24 15:23:00 2014
# CWallis_esrihax          	Tue Nov 18 13:20:08 2014
# dmart_esrihax            	Fri Sep 26 13:20:54 2014
# erwinhack123             	Sun Mar 16 14:23:41 2014
# jbaranyi_esrihax         	Tue Sep 16 10:19:22 2014
# jbarryhax                	Wed Dec 31 16:00:00 1969
# jbystedt                 	Mon Nov 21 09:56:35 2016
# jcolville_ze             	Thu Sep  4 15:59:04 2014
# Jeff_Archer5             	Tue Dec  9 14:19:25 2014
# JHauck_Cajun             	Thu Apr 24 17:58:42 2014
# johnyHack                	Thu Mar  8 09:39:13 2018
# JOslislo_esrihax         	Fri Dec  5 16:45:10 2014
# jTesting                 	Fri Jun 26 09:59:02 2015
# kbolger_ze               	Wed Apr 23 18:07:05 2014
# mani.doraisamy           	Sat Feb 22 12:49:15 2014
# mpHackathon              	Thu Mar  8 09:31:42 2018
# mpilouk_ze               	Mon Mar  5 14:52:39 2018
# msumich7                 	Sun Mar 15 15:32:12 2015
# nfurnessHS               	Fri Feb  6 12:23:56 2015
# RNehmer_esrihax          	Thu Dec  4 14:30:31 2014
# Simtable3                	Fri Jan 12 14:34:59 2018
# sparta.cheung_esrihax    	Mon Feb 24 13:41:23 2014
# tbushey_ez               	Tue Apr 29 17:03:35 2014
# tbutcher_esrihax         	Wed Apr 23 19:22:35 2014
# test_divesh              	Wed Dec 31 16:00:00 1969
# ttilton_ze               	Fri Mar  2 14:55:57 2018

# %%
all_content = gis.content.search(query="*", max_items = 600)
len(all_content)
# Out:
# 517

# %%
org_roles = []
for user in gis.users.search():
    if user.role in org_roles:
        pass
    else:
        org_roles.append(user.role)
for role in org_roles:
    print(role)
# Out:
# org_publisher
# org_admin
# org_user

# %%
for user in gis.users.search():
    if len(user.items()) > 0:
        print("{:<50}\t{:<25}{:<8}\t{:<}".format(user.username, "Item Type", "Date Modified", "NumViews"))
        print("{:*<48}\t{:*<23}\t{:*<15}\t{:*<20}".format("","","",""))
        for item in user.items():
            print("{:2}{:<55}{:<28}{}\t{}".format("",
                                            item.title, 
                                            item.type,
                                            datetime.fromtimestamp(item['modified']/1000).strftime("%m-%d-%y"),
                                            item['numViews']))
        print("\n")
# Out:
# AgMapper_hax                                      	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   USDA_Meat_Infrastructure                               CSV                         06-22-13	3
#   USDA_Meat_Infrastructure                               Feature Service             06-23-13	556
#   Food Hubs                                              Feature Service             06-23-13	322
#   Farmers Markets                                        Feature Service             06-23-13	1747
#   USA Soils and Federal Lands Overlay                    Web Map                     06-22-13	39
#   Hot Spots Food Hubs - foodhubs                         Feature Service             06-22-13	0
#   Hot Spots Food Hubs - foodhubs2                        Feature Service             06-22-13	20
#   Food Hubs and Hot Spots                                Web Map                     06-22-13	37
#   Food Hub Buffers 50, 100, 150 miles                    Feature Service             06-22-13	16
#   Buffer of Food Hubs 25 50 100                          Feature Service             06-22-13	313
#   Food Hub Buffers                                       Web Map                     06-23-13	47
#   Food Hubs with Buffers                                 Web Mapping Application     06-22-13	0
#   Buffer of Meat Infrastructure - Meat_Infrastructure    Feature Service             06-23-13	8
#   USGS Eros Land Cover                                   Web Map                     06-23-13	42
#   Buffer of Farmers Markets 10 20 50                     Feature Service             06-23-13	137
#   Farmers Markets Buffer 10 20 50                        Web Map                     06-23-13	64
#
#
# aharshe_hack                                      	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   Public Garage or Parking Lot                           Web Map                     03-20-15	22
#   Seattle & North area Bus                               Web Map                     03-20-15	49
#   Seattle Bus Stops                                      Feature Service             03-20-15	112
#   Bus Stops                                              Web Map                     03-20-15	38
#   Parking Garage                                         Feature Service             03-20-15	14
#   Community Transit - Bus Routes                         Feature Service             03-20-15	36
#   sdot_parking - Street Parking by Category              Feature Service             03-21-15	8
#
#
# alamedaEsri                                       	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   Alameda Networkfleet-GeoEvent Demo-Update              Web Map                     09-06-14	39
#   Alameda Networkfleet-GeoEvent Demo-2                   Web Map                     09-06-14	35
#   Alameda Networkfleet-GeoEvent Demo-3                   Web Map                     09-06-14	41
#   Urban Shield Operation View 3                          Operation View              09-06-14	1
#   Urban Shield Operation View 4                          Operation View              09-06-14	11
#   Alameda Networkfleet-GeoEvent Demo-4                   Web Map                     09-06-14	40
#   Alameda Networkfleet-GeoEvent Demo-5                   Web Map                     09-07-14	114
#   Urban Shield Operations View Demo 5                    Operation View              09-06-14	18
#   Alameda Networkfleet-GeoEvent Demo-6                   Web Map                     09-06-14	35
#   Alameda Networkfleet-GeoEvent Demo-7                   Web Map                     09-07-14	35
#
#
# andrew.pong                                       	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   weathermap                                             Web Map                     06-08-13	41
#   dstcontrols-osihackathon15                             Application                 01-12-18	0
#
#
# cajunhealth                                       	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   ArcGIS Online Public Senior Content                    Web Map                     04-23-14	54
#   LouisianaCounties                                      Shapefile                   04-24-14	1
#   LouisianaCounties                                      Feature Service             04-24-14	231
#   Enriched LouisianaCounties                             Feature Service             04-24-14	8
#
#
# CWallis_esrihax                                   	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   RoadCenterline_Ground_and_Above_1K                     Layer Package               11-18-14	3
#
#
# dmart_esrihax                                     	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   LicensedSwimmingFacilities                             Service Definition          11-05-13	1
#   Licensed Swimming Facilities                           Feature Service             11-05-13	234
#   Condom_distribution                                    CSV                         11-18-13	1
#   Condom_distribution                                    Feature Service             11-18-13	2645
#   Condom Distribution Sites                              Web Map                     11-18-13	61
#   Speciality_Clinic                                      CSV                         11-18-13	1
#   Speciality_Clinic                                      Feature Service             11-18-13	2648
#   Speciality Clinic                                      Web Map                     11-18-13	71
#   IL_County                                              Feature Service             11-18-13	2
#   Hot Spots Teen_Mot_1                                   Feature Service             09-26-14	948
#   Hot Spots F2012_Coun                                   Feature Service             09-26-14	16
#   IDPH_Pregnancy_Termination_Center (1)                  CSV                         09-26-14	2
#   IDPH_Pregnancy_Termination_Center (1)                  Feature Service             09-26-14	915
#   Nearest IL_Counties to IDPH_Pregnancy_Termination_CenterFeature Service             09-26-14	27
#   Enriched IL_TeenPregnancy_by_County - IL_Counties      Feature Service             09-26-14	34
#   Merge IL_Gonorrhea_By_County - IL_Counties IL_TeenPregnancy_by_County - IL_CountiesFeature Service             09-26-14	14
#   Pregnancy and Gonorrhea                                Feature Service             09-26-14	12
#   STITPcombo                                             Feature Service             09-26-14	173
#   Speciality Clinic-Copy                                 Web Map                     09-26-14	40
#   WebMapEmbedTest                                        Web Map                     09-26-14	138
#   STITPCombo                                             Web Map                     09-26-14	60
#   TeenPregnancyHotSpots                                  Web Map                     09-26-14	252
#   Chlamydia By Illinois County                           Web Map                     09-26-14	696
#   Syphilis By Illinois County                            Web Map                     09-26-14	690
#   Gonorrhea By Illinois County                           Web Map                     09-26-14	693
#   TeenPregnancyHotSpots-Copy                             Web Map                     09-26-14	487
#
#
# erwinhack123                                      	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   Zoning                                                 Shapefile                   03-12-14	1
#   Zoning                                                 Feature Service             03-12-14	137
#   City_Boundary                                          Shapefile                   03-12-14	1
#   City_Boundary                                          Feature Service             03-12-14	95
#   CSA                                                    Shapefile                   03-12-14	1
#   CSA                                                    Feature Service             03-12-14	124
#   General_Plan_Land_Use                                  Shapefile                   03-12-14	1
#   General_Plan_Land_Use                                  Feature Service             03-12-14	230
#   Pasadena_Bike_Routes                                   Shapefile                   03-12-14	1
#   Pasadena_Bike_Routes                                   Feature Service             03-12-14	111
#   Pasadena_Council_Districts                             Shapefile                   03-12-14	1
#   Pasadena_Council_Districts                             Feature Service             03-12-14	89
#   Pasadena_Public_Art                                    Shapefile                   03-12-14	1
#   Pasadena_Public_Art                                    Feature Service             03-12-14	76
#   Pasadena_Refuse_Areas                                  Shapefile                   03-12-14	1
#   Pasadena_Refuse_Areas                                  Feature Service             03-12-14	97
#   PasadenaUSD                                            Shapefile                   03-12-14	1
#   PasadenaUSD                                            Feature Service             03-12-14	12
#   Street_Sweeping                                        Shapefile                   03-12-14	1
#   Street_Sweeping                                        Feature Service             03-20-14	106
# jbarryhax                                         	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   foodhubs                                               CSV                         06-22-13	3
#   Green Schools                                          CSV                         06-22-13	3
#   Green Schools                                          Feature Service             06-22-13	162
#   farmersmarkets                                         CSV                         06-22-13	2
#   Wholesale Markets                                      CSV                         06-22-13	3
#   Wholesale Markets                                      Feature Service             06-22-13	290
#   Meat Infrastructure                                    CSV                         06-22-13	3
#   Meat Infrastructure                                    Feature Service             06-22-13	529
#   ndvi_clipped                                           Image Service               06-22-13	109
#   Pct_Wheat                                              Image Service               06-22-13	30
#   Pct_Rice                                               Image Service               06-22-13	101
#   Pct_Maize                                              Image Service               06-22-13	163
#   Pct_Soybean                                            Image Service               06-22-13	28
#   farmers                                                Web Map                     06-22-13	74
#   Farmers Markets Web Map                                Web Map                     06-22-13	45
#   ranchers_wm                                            Shapefile                   06-23-13	1
#   ranchers_wm                                            Feature Service             06-23-13	12
#   ranchers                                               Shapefile                   06-23-13	1
#   ranchers                                               Feature Service             06-23-13	202
#   Map of Ranchers with Video                             Web Map                     06-23-13	75
#   Ranchers with Videos                                   Web Mapping Application     06-23-13	22
#
#
# jbystedt                                          	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   Geocortex Essentials                                   Application                 11-21-13	0
#
#
# jcolville_ze                                      	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   BayAreaChargers                                        Service Definition          04-26-14	2
#   BayAreaChargers                                        Feature Service             04-26-14	12
#
#
# Jeff_Archer5                                      	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   index                                                  Web Mapping Application     05-31-14	2
#   Test Geotrigger App                                    Application                 12-04-14	0
#   ArcGIS Runtime iOS samples                             Document Link               12-04-14	2
#   ArcGIS Runtime samples for .NET                        Document Link               12-04-14	2
#   ArcGIS Runtime samples for Android                     Document Link               12-04-14	2
#   ArcGIS API for Javascript                              Document Link               12-04-14	2
#   Esri Developer Portal                                  Document Link               12-04-14	3
#   Comet 67P - City Engine Web Scene                      Web Mapping Application     12-04-14	6
#   Getting Started With Esri APIs Blog Post               Document Link               12-04-14	3
#
#
# johnyHack                                         	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   XPopTest                                               Microsoft Excel             01-30-14	1
#   Agg Pasadena Citizen Svc Req CSA                       Feature Service             03-05-18	16
#   TLH_BlkGrp                                             Service Definition          05-22-14	1
#   TLH_BlkGrp                                             Feature Service             12-15-16	297
#   RestaurantFS                                           CSV                         09-16-14	2
#   RestaurantFS                                           Feature Service             09-16-14	75
#   Toronto                                                Service Definition          10-18-14	1
#   Toronto                                                Feature Service             10-18-14	314
#   Toronto Stuff                                          Web Map                     10-18-14	70
#   Toronto Stuff-Copy                                     Web Map                     10-18-14	45
#   USCounties                                             Shapefile                   11-14-14	1
#   USCounties                                             Feature Service             11-14-14	33
#   D.C Agg Pts Neighborhood                               Feature Service             03-05-18	14
#   Summ Tree Locations within D.C.                        Feature Service             03-05-18	17
#   Haunted_Houses__Ghost_Tours                            CSV                         02-03-17	2
#   Haunted_Houses__Ghost_Tours                            Feature Service             02-03-17	5
#   Embassies_V                                            CSV                         02-14-17	2
#   Embassies_V                                            Feature Service             02-14-17	18
#   Test_Country                                           Feature Service             09-16-17	3
#   Zurick Track for Collector                             Feature Service             09-16-17	18
#   Trying_Collector_in_Zurich                             Web Map                     09-16-17	60
#   Parks                                                  Service Definition          02-07-18	1
#   Parks                                                  Feature Service             02-07-18	0
#   US Counties Map                                        Web Map                     03-07-18	40
#
#
# jTesting                                          	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   Toronto                                                Map Package                 10-18-14	0
#
#
# mani.doraisamy                                    	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   Location Tracking                                      Feature Service             06-08-13	211
#   Oasis                                                  Application                 02-22-14	0
#
#
# mpHackathon                                       	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   IAB PlugFest 2013 Long Beach Scenario                  Web Map                     10-30-13	68
#   IAB PlugFest 2013 Operation View                       Operation View              10-30-13	8
#   TrafficSignal                                          CSV                         10-30-13	1
#   RTDevice                                               Web Map                     04-16-14	904
#   RTDevices                                              Operation View              12-23-13	48
#   Networkfleet-GeoEvent Demo                             Web Map                     10-01-14	1097
#   Networkfleet-GeoEvent Operation View Demo              Operation View              10-01-14	179
#   AFCEA West PlugFest 2014 Long Beach Scenario           Web Map                     02-12-14	1383
#   AFCEA West PlugFest 2014 Operation View                Operation View              02-12-14	57
#   AFCEA West PlugFest 2014 Long Beach Scenario with TrafficWeb Map                     02-06-14	45
#   Software AG - GeoEvent                                 Web Map                     02-06-14	496
#   Virtual_Agility_Shelter_Data                           CSV                         02-10-14	0
#   Virtual_Agility_Shelter_Data                           Feature Service             02-10-14	0
#   Long_Beach_Shelters                                    CSV                         02-10-14	1
#   Long_Beach_Shelters                                    Feature Service             02-10-14	0
#   AFCEA West PlugFest 2014 Long Beach Scenario-Copy      Web Map                     02-11-14	19
#   AFCEA West PlugFest 2014                               Web Map                     02-12-14	52
#   AFCEA West Plume Alerting Operation View               Operation View              02-12-14	5
#   AFCEA West PlugFest 2014 Operation View Academia Team  Operation View              02-12-14	1
#   Wind Speed                                             Web Map                     03-04-14	39
#   Boston Marathon 2014                                   Web Map                     04-14-14	53
#   Boston Marathon 2014 Operation View                    Operation View              04-14-14	23
#   Boston Marathon Multi View                             Operation View              04-14-14	2
#   OSISoft Nissan Leafs Tracking Operation View - Copy    Operation View              05-05-14	8
#   Fire                                                   Web Map                     05-22-14	38
#   Geotab AVL BP Feed Service                             Web Map                     07-01-14	60
#   BP-Geotab AVL Operations View                          Operation View              07-01-14	9
#   Mashup Map                                             Web Map                     08-22-14	74
#   Mashup Operation View                                  Operation View              08-08-14	3
#   Alameda Units Operation View                           Operation View              08-29-14	14
#   Alameda Networkfleet-GeoEvent Demo                     Web Map                     09-06-14	319
#   Alemeda Simple Operation View                          Operation View              09-04-14	18
#   Networkfleet-GeoEvent Alameda Operation View Demo      Operation View              08-21-14	7
#   Networkfleet-GeoEvent Demo with Simple Symbols         Web Map                     08-21-14	103
#   GPX Demo                                               Web Map                     08-22-14	38
#   GPX Demo Operation View                                Operation View              08-22-14	3
#   TechNet Augusta PlugFest                               Web Map                     11-06-15	205
#   Alemeda Simple Operation View 2                        Operation View              09-06-14	34
#   Alameda Networkfleet-GeoEvent Demo-bak                 Web Map                     09-05-14	35
#   Alameda Operation Multi-View                           Operation View              09-06-14	32
#   Alameda Networkfleet-GeoEvent Demo-MP                  Web Map                     09-05-14	38
#   Alameda Networkfleet Team                              Web Map                     09-07-14	66
#   Alameda Team Operation View                            Operation View              09-07-14	6
#   TechNet Augusta PlugFest-2                             Web Map                     09-08-14	19
#   TechNet Augusta Operation View                         Operation View              09-09-14	68
#   TechNet Augusta Editable                               Web Map                     09-09-14	80
#   TechNet Augusta PlugFest                               Web Mapping Application     09-10-14	22
#   FAA Flight Monitoring                                  Web Map                     10-07-14	63
#   FAA Flight Tracking Operation View                     Operation View              10-15-14	7
#   Manhattan USGS Orthoimage                              Web Map                     10-02-14	35
#   Flight Demo                                            Web Map                     11-21-14	73
#   Flight Demo                                            Web Mapping Application     10-16-14	56
#   Flight Routes                                          Web Map                     10-29-14	168
#   Flight Routes                                          Web Mapping Application     10-29-14	39
#   Alameda Networkfleet Team                              Web Mapping Application     11-05-14	5
#   GPX Demo                                               Web Mapping Application     11-05-14	5
#   MPWebApp                                               Application                 11-05-14	0
#   Wearable World Invent                                  Web Map                     11-18-14	35
#   Flight Demo App                                        Web Mapping Application     11-28-14	1
#   Flight Demo App                                        Code Attachment             11-28-14	0
#   SFO Demo                                               Web Map                     12-17-14	42
#   Realtime Device Tracking                               Web Map                     12-26-14	17
#   Networkfleet GeoEvent Stream Service                   Web Map                     01-23-15	39
#   CalTrans Freeway Traffic Sensors                       Web Map                     01-09-15	56
#   World Satellites Demo                                  Web Map                     01-14-15	40
#   My Test Scene                                          Web Scene                   01-14-15	1
#   AFCEA PlugFest West 2015                               Web Map                     02-06-15	61
#   Redlands Shelter Management MP                         Operation View              04-24-15	4
#   LA Bus Stop Alert                                      Operation View              09-02-15	13
#   AVL-Ambulance Demo Operation View                      Operation View              09-02-15	7
#   OSIsoft | Esri | Oil and Gas Dashboard                 Operation View              09-03-15	11
#   OSIsoft | Esri | Pipeline Dashboard                    Operation View              09-02-15	1
#   Cat Canyon Operations                                  Operation View              09-02-15	1
#   AFCEA PlugFest West 2015-FS                            Web Map                     11-06-15	68
#   TechNet Augusta PlugFest-3                             Web Map                     11-06-15	19
#   TechNet Augusta Scene                                  Web Scene                   11-06-15	0
#   Mojio                                                  Web Map                     11-15-15	124
#   Buffer of AffectedArea                                 Feature Service             11-15-15	5
#   Buffer of AffectedArea                                 Shapefile                   11-15-15	1
#   Buffer of AffectedArea                                 CSV                         11-15-15	1
#   Buffer of VanCouver AffectedArea                       Feature Service             11-15-15	1
#   Buffer of VanCouver Affected Area                      Feature Service             11-15-15	2
#   Buffer of VanCouver Affected Area                      Shapefile                   11-15-15	1
#   Caltrans Major Freeway Traffics Operation View         Operation View              05-02-16	4
#   Caltrans Major Freeway Traffics Operation View - Copy  Operation View              05-11-16	4
#   Caltrans Major Freeway Traffics Operation View 1       Operation View              06-28-17	54
#   exactEarth Panama Ship Operation View                  Operation View              06-22-16	21
#   Sandy Plowed Status Operation View                     Operation View              08-09-16	28
#   Sandy Plowed Status Mutidisplay Operation View         Operation View              08-11-17	50
#   FlightAwareBDS                                         Web Map                     04-14-17	47
#   FAA Sectional Charts                                   Web Map                     09-06-16	39
#   SFO-FlightAware                                        Web Map                     09-07-16	39
#   SFO-FlightAware Historical                             Web Map                     09-07-16	17
#   Panama Tugboat Service Demo                            Web Map                     01-03-17	4346
#   Panama Tugboat Service Operation View                  Operation View              01-03-17	81
#   Panama Tugboat Service Single Operation View           Operation View              10-28-16	4
#   exactEarth AIS - USACE IENC                            Web Map                     10-31-16	44
#   Esri Campus Geofence Notification                      Web Map                     11-16-16	90
#   Zonar-Columbia-MS                                      Web Map                     11-17-16	37
#   JFX FlightAware Surface Movement                       Web Map                     11-30-16	17
# mpilouk_ze                                        	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   ZeInnEVation OSISoft Nissan Leafs Tracking             Web Map                     04-27-14	1025
#   OSISoft Nissan Leafs Tracking Operation View - Copy    Operation View              04-27-14	20
#   LA Bus Dev Summit 2018                                 Web Map                     03-04-18	47
#   LA Bus Service                                         Dashboard                   03-05-18	33
#   LA Bus BDS Aggregation                                 Web Map                     03-04-18	64
#   FAA Stream Service                                     Web Map                     03-04-18	34
#   FAA Stream Service                                     Dashboard                   03-04-18	17
#   Verizon Networkfleet Telematics Demo (Copy)            Dashboard                   03-07-18	1
#
#
# RNehmer_esrihax                                   	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   Geotrigger App                                         Application                 12-05-14	0
#   Test service                                           Feature Service             12-05-14	19
#   airport noise                                          Web Map                     12-05-14	54
#
#
# Simtable3                                         	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   TEST                                                   Web Scene                   05-08-15	0
#   AnyHazard                                              Web Mapping Application     05-08-15	1
#   AnyHazard                                              Code Attachment             05-08-15	0
#   NPS Trails                                             Map Service                 05-08-15	2
#
#
# tbushey_ez                                        	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   ChargingStations                                       Service Definition          04-24-14	1
#   Charging Stations                                      Feature Service             04-24-14	288
#   California EV Charging Stations                        Web Map                     04-24-14	61
#
#
# tbutcher_esrihax                                  	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   RTDevice-Copy                                          Web Map                     04-17-14	43
#   Test                                                   Web Map                     04-18-14	39
#   Test                                                   Web Mapping Application     04-18-14	6
#
#
# test_divesh                                       	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   map_data                                               CSV                         06-09-13	2
#   map_data                                               Feature Service             06-09-13	199
#   Phishing                                               Web Map                     06-09-13	18
#
#
# ttilton_ze                                        	Item Type                Date Modified	NumViews
# ************************************************	***********************	***************	********************
#   LAPD_Crime_and_Collision_Raw_Data_-_April_2014         Feature Service             06-28-14	2602
#   Riverside county ZIP codes                             Feature Service             10-26-15	145
#   LA Crime                                               Web Map                     11-13-14	2458
#   SoCal POI                                              Feature Service             11-14-14	126
#   SFO_Area_Buildings                                     Service Definition          11-18-14	3
#   SFO_Area_Buildings                                     Feature Service             11-18-14	138
#   SFO Wearable World Web Map                             Web Map                     11-18-14	72
#   Spaces_T3                                              Service Definition          11-18-14	3
#   Spaces_T2                                              Feature Service             11-18-14	117
#   Roads                                                  Service Definition          11-18-14	3
#   Roads                                                  Feature Service             11-18-14	51
#   ServicesFC                                             Feature Service             01-19-15	35
#   TES Species Summary                                    PDF                         11-19-15	0
#   Map Notes                                              Feature Collection          04-12-17	7
#   tteesstt                                               Web Map                     12-12-17	32
