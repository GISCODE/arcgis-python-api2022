# %%
from arcgis.gis import GIS
import getpass

password = getpass.getpass("Enter password: ")
g = GIS('https://www.arcgis.com', 'johnyHack', password)
print("Connected to: {}\nConnected as: {}".format(g.properties.urlKey + "." + g.properties.customBaseUrl,
                                                 g.users.me.username))
# Out:
# Enter password: ········
# Connected to: esrihax.maps.arcgis.com
# Connected as: johnyHack

# %%
wmaps = g.content.search("*", item_type="Web Map", max_items = 200, outside_org=False)

# %%
for wbmap in wmaps:
    print("{}".format(wbmap.title))
    print("{:*<90}".format(""))
    raw_data = wbmap.get_data()
    lyrs = raw_data['operationalLayers']
    for lyr in lyrs:
        try:
            if 'itemId' in lyr.keys():
                print("\t{:<50}{}".format(lyr['title'][:45], lyr['itemId']))
            else:
                print("\t{:<50}{}".format(lyr['title'][:45], lyr['id']))
        except:
            pass
    print("\n")
# Out:
# Speciality Clinic
# ******************************************************************************************
# 	Table1                                            927a57e055ce4528b4463883d5b958e1
#
#
# Charlotte Political and Service Districts
# ******************************************************************************************
# 	PoliticalAndServiceDists                          PoliticalAndServiceDists_1014
#
#
# Chlamydia By Illinois County
# ******************************************************************************************
# 	Chlamydia Cases by County                         1d89559928ec430aa4afd47d53ee9a08
# 	Specialty Clinic                                  20a29db43f11408db2e6088b30740363
# 	Condom Distribution Site                          dc1c98a0b9414368b63b1e76770e9b1d
#
#
# Geotab AVL BP Feed Service
# ******************************************************************************************
# 	BP - GeoTabHistoricalGps                          BP_212
# 	BP - GeoTabGpsData                                BP_15
#
#
# USGS Eros Land Cover
# ******************************************************************************************
# 	USGS EROS Web Map Service: USGS_EDC_LandCover     57097e55fd6f4143a128a8a59fd24063
#
#
# Illinois_Nursing_Homes
# ******************************************************************************************
# 	Illinois_Health_Care_Facilities - Nursing_Hom     Illinois_Health_Care_Facilities_7297
#
#
# AFCEA West PlugFest 2014 Long Beach Scenario with Traffic
# ******************************************************************************************
# 	Traffic                                           Traffic_1076
# 	National_Bridge_Inventory_2                       National_Bridge_Inventory_2_4985
# 	plume                                             plume_1486
# 	RadarAIS - RadarAIS                               RadarAIS_7963
# 	IABCounty - Counties                              IABCounty_2446
# 	TrafficSignals - TrafficSignals                   TrafficSignals_3621
#
#
# TechNet Augusta Editable
# ******************************************************************************************
# 	Augusta - RangeFans                               Augusta_335
# 	UAVPaths - UAVPaths                               UAVPaths_6235
# 	TechNetLine - CommConn                            TechNetLine_7356
# 	Augusta - CommNodes                               Augusta_9530
# 	CPTs                                              Augusta_9879
#
#
# Flight-Enter-Exit-DC
# ******************************************************************************************
# 	FlightAwarePosition                               FlightAwarePosition_2232
# 	Real-time Weather Radar WMS Service               bb37ceceeac14c829b2cf449ff0c14d8
# 	NEXRAD Base Reflectivity (WMS)                    252e7ac912a24fa79d5039108212f893
# 	Current NEXRAD Radar                              61b24d3148224738aeb323ffa69b5337
# 	NOAA_NOWCOAST_Nexrad_RADAR                        44c40c5614b1414d88308dcacabf815c
# 	FlightAwarePositionWithAirline                    FlightAwarePositionWithAirline_3205
# 	FlightEnterDC                                     FlightEnterDC_5570
# 	FlightExitDC                                      FlightExitDC_8378
#
#
# Toronto Stuff-Copy
# ******************************************************************************************
# 	Toronto - Fun Neighborhood                        facf5167ea264545b4d3092967e1f3b1
# 	Toronto - Streets to Checkout                     facf5167ea264545b4d3092967e1f3b1
# 	Toronto - Awesome Spots                           facf5167ea264545b4d3092967e1f3b1
#
#
# Illinois Licensed Swimming Facilities
# ******************************************************************************************
# 	IL Licensed Swimming Pools                        38cffdfa53424dbd8e695f187111def7
# 	IL Swimming Facility Licensees                    38cffdfa53424dbd8e695f187111def7
#
#
# CalTrans Freeway Traffic Sensors
# ******************************************************************************************
# 	CaltransTrafficSensors                            stream_4288
#
#
# Trying_Collector_in_Zurich
# ******************************************************************************************
# 	Zurick Track for Collector                        be327f31407247aa93ff434209a66293
#
#
# Alameda Networkfleet-GeoEvent Demo-4
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	UrbanShieldGeoFences - geofenceCenters            UrbanShieldGeoFences_4481
# 	Geofence Alerts                                   AssetMonitor_3506
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	Urban Shield Teams                                NetworkfleetAgency_6421
# 	Vehicle in Motion                                 NetworkfleetAgency_6421_7527
#
#
# Verizon Networkfleet Telematics Demo
# ******************************************************************************************
# 	NetworkfleetVehicleHistory                        NetworkfleetVehicleHistory_6840
# 	NetworkfleetVehicle                               NetworkfleetVehicle_254
#
#
# Waze Inland Empire
# ******************************************************************************************
# 	WazeJam                                           stream_4327
# 	WazeAlert                                         stream_7385
#
#
# LA Bus BDS Aggregation
# ******************************************************************************************
# 	LABusHistorical                                   LABusHistorical_4527
# 	LABus                                             LABus_181
#
#
# Nursing Homes CCA SumSkill
# ******************************************************************************************
# 	Chicago_Community_Areas - Chgo_Community_Area     682f83805fa04cacae1dd75dbd7b171b
# 	IL_Nursing_Homes - Nursing_Homes                  d58a327632684943ab44ed857d612a41
# 	Aggregation of IL_Nursing_Homes - Nursing_Hom     14b3fdcbba95480392af3e9e16a89b67
#
#
# Panama Rotation
# ******************************************************************************************
# 	PanamaTugBoatCurrent                              PanamaTugBoatCurrent_6206
#
#
# Charlotte Landmarks
# ******************************************************************************************
# 	Landmarks                                         Landmarks_7749
#
#
# Wind Speed
# ******************************************************************************************
# 	Wind Speed and Direction                          e6107ff599c843f196915a608dd02958
#
#
# Seattle & North area Bus
# ******************************************************************************************
# 	Community Transit - Bus Routes                    f2f4bac5997f4089a4108207273bac4e
# 	Community Transit - Bus Stops                     64c64861631e4a1d8db02fb87b540dd2
#
#
# Mojio
# ******************************************************************************************
# 	MojioDevices                                      stream_8851
# 	AffectedArea                                      csv_7906
# 	Buffer of AffectedArea                            d8a8868887a542ff9e441c93c549ba81
# 	Officers                                          csv_5084
# 	VanCouverAffectedArea                             csv_6956
# 	Buffer of VanCouver Affected Area                 d4505177091f4ad79019907cf013432c
#
#
# Panama Tugboat Service Demo
# ******************************************************************************************
# 	exactEarthHistorical                              exactEarthHistorical_116
# 	Panama-TugBoat-Buffer-Current                     Panama-TugBoat-Buffer-Current_4758
# 	Panama-Tugboat-Hist                               Panama-Tugboat-Hist_7823
# 	Panama-in-Service-Ship-Current                    Panama-in-Service-Ship-Current_7765
# 	Panama-Tugboat-Service-Log                        Panama-Tugboat-Service-Log_293
# 	PanamaTugBoatCurrent                              PanamaTugBoatCurrent_2926
#
#
# SFO Wearable World Web Map
# ******************************************************************************************
# 	SFO_Area_Buildings - BuildingFootprint_1K         84189e3d83e24325a3f32368dc12e168
# 	POIs                                              bebc06442aa040c587c3424d683f4ae2
#
#
# Structural Deficiencies in US Bridges
# ******************************************************************************************
# 	USDOT_FHWA_NumberOfStructurallyDeficientBridg     USDOT_FHWA_NumberOfStructurallyDeficientBridges_1277
#
#
# exactEarth AIS Worldwide Ship Monitoring
# ******************************************************************************************
# 	exactEarthRawAISHist                              exactEarthRawAISHist_9155
# 	exactEarthRawAISCurrent                           exactEarthRawAISCurrent_5367
# 	NDBCData                                          NDBCData_7774
# 	exactEarthRawAIS                                  stream_4378
#
#
# AFCEA West PlugFest 2014 Long Beach Scenario
# ******************************************************************************************
# 	USA Transmission Lines                            918e6d9b1cc84d15ba13e911d18a0c5e
# 	National_Bridge_Inventory_2                       National_Bridge_Inventory_2_4985
# 	plume                                             plume_1486
# 	IEM WMS Service                                   61b24d3148224738aeb323ffa69b5337
# 	RadarAIS - RadarAIS                               RadarAIS_7963
# 	IABCounty - Counties                              IABCounty_2446
# 	Shelters - Shelters                               Shelters_9728
# 	TrafficSignals - TrafficSignals                   TrafficSignals_3621
# 	TrafficCams - Camera Locations                    TrafficCams_2320
# 	SoftwareAG - SignData                             SoftwareAG_5420
# 	SoftwareAG - LoginAttempts                        SoftwareAG_3134
# 	FlightMonitor - GeoFences                         FlightMonitor_9682
# 	FlightMonitor - Alerts                            FlightMonitor_2964
# 	FlightTrack - Flight Track                        FlightTrack_7407
#
#
# FAA Flight Monitoring
# ******************************************************************************************
# 	FAATrackInfoR - FAA_TrackInfo                     FAATrackInfoR_5468
#
#
# Alameda Networkfleet-GeoEvent Demo
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	UrbanShieldGeoFences - geofenceCenters            UrbanShieldGeoFences_4481
# 	AssetMonitor - Alerts                             AssetMonitor_3506
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	NetworkfleetAgency - NetworkcarAgency             NetworkfleetAgency_6421
#
#
# Las Vegas CES 2018 Cisco-GeoEvent
# ******************************************************************************************
# 	LasVegas-CES-CISCO                                stream_9301
#
#
# Alameda Networkfleet-GeoEvent Demo-Update
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	UrbanShieldGeoFences - geofenceCenters            UrbanShieldGeoFences_4481
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	AssetMonitor - Alerts                             AssetMonitor_3506
# 	NetworkfleetAgency - NetworkcarAgency             NetworkfleetAgency_6421
#
#
# Gonorrhea By Illinois County
# ******************************************************************************************
# 	Gonorrhea Cases by County                         1f3a431f8f6840aba3274220c1937887
# 	Specialty Clinic                                  20a29db43f11408db2e6088b30740363
# 	Condom Distribution Site                          dc1c98a0b9414368b63b1e76770e9b1d
#
#
# Bus Stops
# ******************************************************************************************
# 	Seattle Bus Stops - Community Transit - Bus S     6e7e0c4a005c46de815e3319f7bc05e9
#
#
# Michels AEMP Demo
# ******************************************************************************************
# 	MichelsAEMPEquipmentFlat                          stream_3785
#
#
# LA Crime
# ******************************************************************************************
# 	LAPD_Crime_and_Collision_Raw_Data_-_April_201     5906863ba29b4b3f9d5671d014743124
#
#
# Speciality Clinic-Copy
# ******************************************************************************************
# 	Hot Spots F2012_Coun                              35ee4e64bb6e4c12a3e7970aede49812
# 	Table1                                            927a57e055ce4528b4463883d5b958e1
# 	Speciality_Clinic                                 20a29db43f11408db2e6088b30740363
# 	Condom_distribution                               dc1c98a0b9414368b63b1e76770e9b1d
# 	IL_Chlamydia_by_County - IL_Counties              1d89559928ec430aa4afd47d53ee9a08
# 	IL_Gonorrhea_By_County - IL_Counties              1f3a431f8f6840aba3274220c1937887
# 	IL_Syphilis_by_County - IL_Counties               99513152ee1d45eea89a2987171efe88
# 	IL_TeenPregnancy_by_County - IL_Counties          e25982e98d1a49819f22cbd7af440ca8
# 	IDPH_Pregnancy_Termination_Center_(1) - IDPH_     IDPH_Pregnancy_Termination_Center_(1)_3987
# 	IL_Counties - IL_Counties                         IL_Counties_8815
# 	Nearest IL_Counties to IDPH_Pregnancy_Termina     3d82c3a3cf2a49d9a1e8c70228fc9a77
# 	Nearest IL_Counties to IDPH_Pregnancy_Termina     3d82c3a3cf2a49d9a1e8c70228fc9a77
# 	Enriched IL_TeenPregnancy_by_County - IL_Coun     556efb91d3064479bf3a34aa5d093952
# 	Merge IL_Gonorrhea_By_County - IL_Counties IL     f6048d19d6a84163869c5ffe20b549b9
# 	Pregnancy and Gonorrhea - OverlayOutput           bf8954b038a646c2aca7a9bf9627434f
# 	Test Syphillis Hot Spot - HotSpots_F2012_Coun     c895ee46ceb94af787b9fd5792eaa058
#
#
# IAB PlugFest 2013 Long Beach Scenario
# ******************************************************************************************
# 	Traffic                                           Traffic_1076
# 	National_Bridge_Inventory_2                       National_Bridge_Inventory_2_4985
# 	plume                                             plume_1486
# 	RadarAIS - RadarAIS                               RadarAIS_7963
# 	IABCounty - Counties                              IABCounty_2446
# 	TrafficSignals - TrafficSignals                   TrafficSignals_6129
#
#
# USA Soils and Federal Lands Overlay
# ******************************************************************************************
# 	USA Soil Survey                                   204d94c9b1374de9a21574c9efa31164
# 	USA Federal Lands                                 690e0fe1ceb74ee5b10de1a2cf61ea87
#
#
# Alameda Networkfleet-GeoEvent Demo-MP
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	UrbanShieldGeoFences - geofenceCenters            UrbanShieldGeoFences_4481
# 	AssetMonitor - Alerts                             AssetMonitor_3506
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	NetworkfleetAgency - NetworkcarAgency             NetworkfleetAgency_6421
#
#
# San Diego UC Test
# ******************************************************************************************
# 	UC_SDCC - BuildingInteriorSpace_UC_Use            UC_SDCC_6220
# 	RTDevice                                          RTDevice_8399
#
#
# weathermap
# ******************************************************************************************
# 	Nexrad Live - Time Enabled (5 min incr for pa     5220503de69345b7a5d52eaba293160c
#
#
# Alameda Networkfleet Team
# ******************************************************************************************
# 	Traffic                                           Traffic_7575
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_8913
# 	UrbanShieldGeoFences - geofenceCenters            UrbanShieldGeoFences_9207
# 	AssetMonitor - Alerts                             AssetMonitor_7805
# 	AlamedaAlerts - alamedaGFAlert                    AlamedaAlerts_1590
# 	NetworkfleetTeam - NetworkfleetTeamHist           NetworkfleetTeam_2974
# 	NetworkfleetTeam - NetworkfleetTeam               NetworkfleetTeam_3786
#
#
# Condom Distribution Sites
# ******************************************************************************************
# 	Table1                                            e53e28e018524f8a94afabd33aa764b0
#
#
# Fire
# ******************************************************************************************
# 	US Forest Service Forests To Faucets              006693a23c72488493fde0d9d8d7121f
# 	emergency_public_hosted_features - Fire Perim     f5d64cf756f649299c640ac8a8c8c317
# 	emergency_public_hosted_features - Emergency      f5d64cf756f649299c640ac8a8c8c317
# 	emergency_public_hosted_features - Evacuation     f5d64cf756f649299c640ac8a8c8c317
# 	emergency_public_hosted_features - Evacuation     f5d64cf756f649299c640ac8a8c8c317
# 	emergency_public_hosted_features - Road Closu     f5d64cf756f649299c640ac8a8c8c317
# 	emergency_public_hosted_features - Localized      f5d64cf756f649299c640ac8a8c8c317
#
#
# World Satellites Demo
# ******************************************************************************************
# 	WorldSatellites                                   stream_2837
#
#
# Farmers Markets Web Map
# ******************************************************************************************
# 	Farmers Markets - farmersmarkets                  9bd22b77a13649c49148489b3d958bc0
#
#
# US Counties Map
# ******************************************************************************************
# 	USCounties                                        4dd18d078c7a436eb7d58509de905293
#
#
# WebMapEmbedTest
# ******************************************************************************************
# 	IL_Syphilis_by_County - IL_Counties               99513152ee1d45eea89a2987171efe88
# 	IL_Gonorrhea_By_County - IL_Counties              1f3a431f8f6840aba3274220c1937887
# 	IL_Chlamydia_by_County - IL_Counties              1d89559928ec430aa4afd47d53ee9a08
#
#
# Kansas City Zoning
# ******************************************************************************************
# 	Zoning                                            31a2efe7e30242b6a8210fc291900a18
#
#
# farmers
# ******************************************************************************************
# 	Farmers Markets - farmersmarkets                  9bd22b77a13649c49148489b3d958bc0
#
#
# FlightAware Surface Movement BDS
# ******************************************************************************************
# 	FlightAwarePositionHistorical                     FlightAwarePositionHistorical_5461
# 	FlightAwareGroundPosition - Vehicles              FlightAwareGroundPosition_5812
# 	FlightAwareGroundPosition - Airplanes             FlightAwareGroundPosition_133
#
#
# Map 1
# ******************************************************************************************
# 	Excel Layer                                       4592a3de987b449db6cc492cce2d2a06
#
#
# FAA Sectional Charts
# ******************************************************************************************
# 	FAA Sectional Charts - Map Service                9ff892e372e84a8eb23c866865b2e6cc
#
#
# Illinois_Hospitals
# ******************************************************************************************
# 	Illinois_Health_Care_Facilities - Hospitals       Illinois_Health_Care_Facilities_8015
#
#
# Software AG - GeoEvent
# ******************************************************************************************
# 	SoftwareAG - LoginAttempts                        SoftwareAG_2172
# 	SoftwareAG - SignData                             SoftwareAG_8780
#
#
# Flight Cancellations
# ******************************************************************************************
# 	National Weather Service Precipitation Foreca     71afd16b8845426e9435c5dbb9ca8ea6
# 	National Weather Service Ice Accumulation For     633a82d5917e4ceab13319266ce6ec3f
# 	National Weather Service Smoke Forecast           8e6cddf31bde4f4095a4b0ef32fef144
# 	National Weather Service Wind Speed Forecast      d6089124cd0f43118bf00789c371e649
# 	National Weather Service Wind Gust Forecast       d248c7e831f24b239aca63f131322d2c
# 	National Weather Service Wind Forecast            c0b7fd03f13d43f38b7fb9586c664bcb
# 	Current Wind and Weather Conditions               29d3ea0ef52a43abab68be309479f2ac
# 	FlightCancellationHistorical                      FlightCancellationHistorical_8364
# 	FlightCancellationUpdate                          FlightCancellationUpdate_2338
#
#
# Toronto Stuff
# ******************************************************************************************
# 	Toronto - Fun Neighborhood                        facf5167ea264545b4d3092967e1f3b1
# 	Toronto - Streets to Checkout                     facf5167ea264545b4d3092967e1f3b1
# 	Toronto - Awesome Spots                           facf5167ea264545b4d3092967e1f3b1
#
#
# Flight Demo
# ******************************************************************************************
# 	FAAStream                                         stream_1286
#
#
# FlightAwareBDS
# ******************************************************************************************
# 	FlightAwarePosition                               FlightAwarePosition_9394
#
#
# Networkfleet-GeoEvent Demo
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	AssetMonitor - Alerts                             AssetMonitor_1870
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_9844
# 	NetworkfleetAgency - NetworkcarAgency             NetworkfleetAgency_6421
#
#
# FlightAware Ground Position
# ******************************************************************************************
# 	FlightAwareGroundPosition                         stream_2364
#
#
# Flight Routes
# ******************************************************************************************
# 	FlightRouteCounter                                stream_5170
# 	flightCounter                                     stream_5278
# 	FAAStream                                         stream_28
# 	Digital Aeronautical Flight Information File      f08bc75e3a8d426bb097251e30517e4b
# 	flight_routes                                     38a36712e2fc457190709e513442135a
# 	airroutes - Route10Miles                          airroutes_820
# 	airroutes - Route3D                               airroutes_4414
#
#
# BioDiesel Plant Locations
# ******************************************************************************************
# 	BioDiesel Plants                                  csv_4178
#
#
# Energy Infrastructure
# ******************************************************************************************
# 	20130617StateEnergyProfilesMap                    20130617StateEnergyProfilesMap_6861
#
#
# Boston Fire Hydrants
# ******************************************************************************************
# 	Fire Hydrants                                     fd64be3aa6344b1fa56c23b0017266f5
#
#
# Renewable Energy Consumption
# ******************************************************************************************
# 	Excel Layer                                       43256024a7784814a302c7b63e11814b
#
#
# San Diego Neighborhood Map
# ******************************************************************************************
# 	San Diego Neighborhood Map - San_Diego_Neighb     e87ccd2b7912450ba5d138044849640d
#
#
# Alameda Networkfleet-GeoEvent Demo-5
# ******************************************************************************************
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	Geofence Centers                                  UrbanShieldGeoFences_4481
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	Urban Shield Teams                                NetworkfleetAgency_6421
# 	Vehicle in Motion                                 NetworkfleetAgency_6421_7527
# 	Geofence Alerts                                   AlamedaAlerts_608
# 	Historical Alerts                                 AlamedaAlerts_4934
#
#
# Roads and Railroad Overview
# ******************************************************************************************
# 	USA Railroads                                     acf0f51a2c0b4950b3b65f77c59e6f3f
# 	USA Roads                                         64a95b092457466388f09136e331ff09
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
#
#
# Illinois Hospitals
# ******************************************************************************************
# 	IDPH Regions                                      5f053b9961dc419980a7ef616121014b
# 	Local Health Departments                          5f053b9961dc419980a7ef616121014b
# 	Hospitals                                         5f053b9961dc419980a7ef616121014b
#
#
# Charlotte Area Bus Stops
# ******************************************************************************************
# 	CATS Bus Stops                                    dfc3ed807fb248dcbc9903388f3542b9
#
#
# California EV Charging Stations
# ******************************************************************************************
# 	Charging Stations                                 58046e78de464ab595bb8a54303e0115
#
#
# STITPCombo
# ******************************************************************************************
# 	STITPcombo - HotSpots_F2012_Coun                  c895ee46ceb94af787b9fd5792eaa058
# 	IL_Syphilis_by_County - IL_Counties               99513152ee1d45eea89a2987171efe88
# 	IL_Gonorrhea_By_County - IL_Counties              1f3a431f8f6840aba3274220c1937887
# 	IL_Chlamydia_by_County - IL_Counties              1d89559928ec430aa4afd47d53ee9a08
# 	STITPcombo - HotSpots_F2012_Coun                  c895ee46ceb94af787b9fd5792eaa058
# 	IL_TeenPregnancy_by_County - IL_Counties          e25982e98d1a49819f22cbd7af440ca8
# 	Condom_distribution                               dc1c98a0b9414368b63b1e76770e9b1d
# 	Speciality_Clinic                                 20a29db43f11408db2e6088b30740363
# 	IDPH_Pregnancy_Termination_Center (1)             8732f0584698440d85cc74e97727ebae
#
#
# Mashup Map
# ******************************************************************************************
# 	Hurricanes Active                                 017f6d57c4b74974886ce9e5d08a9f56
# 	IEM WMS Service                                   61b24d3148224738aeb323ffa69b5337
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	AssetMonitor - GeoFences                          AssetMonitor_1788
#
#
# AFCEA PlugFest West 2015-FS
# ******************************************************************************************
# 	Hurricanes Active                                 017f6d57c4b74974886ce9e5d08a9f56
# 	IEM WMS Service                                   61b24d3148224738aeb323ffa69b5337
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	catalinaHoneycomb - Catalina                      catalinaHoneycomb_4718
# 	catalinaHoneycomb - CatalinaHex                   catalinaHoneycomb_7861
# 	Augusta - RangeFans                               Augusta_6473
# 	UAVPaths - UAVPaths                               UAVPaths_4015
# 	Augusta - Connectivity                            Augusta_9278
# 	Augusta - CommNodes                               Augusta_9993
# 	CPTs                                              Augusta_780
#
#
# Flight Cancellations Test
# ******************************************************************************************
# 	FlightCancellationUpdate                          FlightCancellationUpdate_8598
#
#
# Test
# ******************************************************************************************
#
#
# Illinois Tanning Salons
# ******************************************************************************************
# 	IDPH_Tanning_Facilities                           8f871b55cdb04d96b6c1345e817a8a5c
#
#
# Manhattan USGS Orthoimage
# ******************************************************************************************
# 	USGS Orthoimagery from The National Map           5903c82adf4a42cfa525463593d0c66a
#
#
# RTDevice-Copy
# ******************************************************************************************
# 	RTDevice - RTDevice                               RTDevice_6849
# 	AssetMonitor - GeoFences                          AssetMonitor_4036
# 	AssetMonitor - Alerts                             AssetMonitor_341
# 	RTDeviceHistory - RTDeviceHistory                 RTDeviceHistory_9354
#
#
# Networkfleet-GeoEvent Demo with Simple Symbols
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	AssetMonitor - Alerts                             AssetMonitor_1870
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	NetworkfleetAgency - NetworkcarAgency             NetworkfleetAgency_6421
#
#
# TeenPregnancyHotSpots
# ******************************************************************************************
# 	Hot Spots for Teen Mothers                        6f93c95f46134dec9ed72b7ea101773a
# 	IDPH Pregnancy Termination Center                 8732f0584698440d85cc74e97727ebae
# 	Speciality_Clinic                                 20a29db43f11408db2e6088b30740363
# 	Condom Distribution Site                          dc1c98a0b9414368b63b1e76770e9b1d
#
#
# airport noise
# ******************************************************************************************
# 	DallasAirportNoiseContours                        99d896bcfb1c45c8b7faff490b1d1fb1
#
#
# Alameda Networkfleet-GeoEvent Demo-2
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	UrbanShieldGeoFences - geofenceCenters            UrbanShieldGeoFences_4481
# 	AssetMonitor - Alerts                             AssetMonitor_3506
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	NetworkfleetAgency - NetworkcarAgency             NetworkfleetAgency_6421
#
#
# Chicago Libraries
# ******************************************************************************************
# 	Libraries_-_2012_Holds_Filled_by_Location         featColl_7570
#
#
# Airport Traffics - Minneapolis
# ******************************************************************************************
# 	AirportTrafficsFSHist                             AirportTrafficsFSHist_8233
# 	AirportTraffics                                   AirportTraffics_7666
#
#
# Alameda Networkfleet-GeoEvent Demo-bak
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	UrbanShieldGeoFences - geofenceCenters            UrbanShieldGeoFences_4481
# 	AssetMonitor - Alerts                             AssetMonitor_3506
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	NetworkfleetAgency - NetworkcarAgency             NetworkfleetAgency_6421
#
#
# exactEarth AIS - USACE IENC
# ******************************************************************************************
# 	Caution_Areas_(USACE_IENC)                        Caution_Areas__USACE_IENC__5072
# 	exactEarthCurrent                                 exactEarthCurrent_1771
#
#
# FlightAware - Surface Movement
# ******************************************************************************************
# 	FlightAwareGroundPosition - Vehicles              stream_2150_7798
# 	FlightAwareGroundPosition - Aircrafts             stream_2150
#
#
# SFO Demo
# ******************************************************************************************
# 	SFO                                               SFO_8520
# 	Devices                                           stream_3988
#
#
# Alameda Networkfleet-GeoEvent Demo-7
# ******************************************************************************************
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	Geofence Centers                                  UrbanShieldGeoFences_4481
# 	Geofence Alerts                                   AssetMonitor_3506
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	Urban Shield Teams                                NetworkfleetAgency_6421
# 	Vehicle in Motion                                 NetworkfleetAgency_6421_7527
#
#
# Food Hubs and Hot Spots
# ******************************************************************************************
# 	Food Hubs - foodhubs                              a3354c96c0314c04a58922242e0fe8af
# 	Hot Spots Food Hubs - foodhubs2 - HotSpots_fo     f6224ce888c04e0483786870890db21c
#
#
# ZeInnEVation OSISoft Nissan Leafs Tracking
# ******************************************************************************************
# 	ChargingStations - ChargingStations               ChargingStations_578
# 	bayleafs2 - vehicles                              bayleafs2_5833
# 	ZInnEVation - NissanLeafs                         ZInnEVation_1378
#
#
# FlightAware - Surface Movement and In-Flight
# ******************************************************************************************
# 	FlightAwareGroundPosition - Vehicles              stream_2150_7798
# 	FlightAwareGroundPosition - Aircrafts             stream_2150
# 	FlightAwarePosition                               stream_8322
#
#
# Alameda Networkfleet-GeoEvent Demo-6
# ******************************************************************************************
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	Geofence Centers                                  UrbanShieldGeoFences_4481
# 	Geofence Alerts                                   AssetMonitor_3506
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	Urban Shield Teams                                NetworkfleetAgency_6421
# 	Vehicle in Motion                                 NetworkfleetAgency_6421_7527
#
#
# Pasadena Citizens Service Requests
# ******************************************************************************************
# 	Pasadena Citizen Service Requests                 d3d0599784064ed9a7aef50314ac3ce7
#
#
# Networkfleet GeoEvent Stream Service
# ******************************************************************************************
# 	NetworkfleetVehicleReg                            stream_9482
# 	Networkfleet                                      stream_3540
#
#
# D.C. Tree Plantings 2014
# ******************************************************************************************
# 	World Dark Gray Reference                         233a6a2fe58e444296b30512e1bcbb42
# 	D.C. ANC Neighborhoods                            a8fd06fc7d6741138af855cb6b247398
# 	Tree Locations                                    ffe843b8db1447d9a78bdd7a9cf99566
# 	Tree Species per D.C. Neighborhoods               2d33107de67c46b2b9beb3b7d4328f07
# 	Walter E Washington Convention Center             mapNotes_5174
#
#
# GPX Demo
# ******************************************************************************************
# 	gpx - gpxTrackxHistorical                         gpx_2895
# 	gpx - gpxTrackx                                   gpx_7864
#
#
# SFO-FlightAware
# ******************************************************************************************
# 	FAA Sectional Charts - Map Service                9ff892e372e84a8eb23c866865b2e6cc
# 	Watches, Warnings and Advisories NOAA nowCOAS     fd9845227db745a28f2fb11956d216d2
# 	Recent Weather Radar Imagery                      da53700b1f324cc685c4d3bcc00c12fc
# 	FlightAwarePositionHistorical                     FlightAwarePositionHistorical_6463
# 	sfo - metar                                       sfo_4021
# 	airep                                             airep_2829
# 	FlightAwarePosition                               stream_4401
#
#
# City of Columbus WAZE
# ******************************************************************************************
# 	WazeJam                                           stream_8547
# 	WazeAlert                                         stream_2978
#
#
# Redcross Vehicle Demo
# ******************************************************************************************
# 	USA Wildfire Activity                             4d63f7de557c4a69bab44c376c0d3565
# 	Live Stream Gauges (Flooding)                     61003c853d2c4c338841429610b5747f
# 	RedcrossVehicleHist                               RedcrossVehicleHist_3415
# 	RedcrossVehicles                                  RedcrossVehicles_7521
#
#
# LA County SNAP and Food Pantry Locations
# ******************************************************************************************
# 	BlockGroupsWithPopArea                            2f369c0fc194431ba29516dfed36ef41
# 	LA_COUNTY_BNDRY                                   c53d54bba1c641b0a1f008c4fbb1c977
# 	LA_CITY_COUNCIL_DISTRICTS                         c53d54bba1c641b0a1f008c4fbb1c977
# 	LA_CITY_NEIGHBORHOOD_COUNCILS                     c53d54bba1c641b0a1f008c4fbb1c977
# 	LA_COUNTY_HEALTH_DISTRICTS                        c53d54bba1c641b0a1f008c4fbb1c977
# 	CA WIC Farmers Markets                            eb2af563d8dd42d0bf504dcba540c8f2
# 	Food Pantries                                     e7f86e576960466ebcefcb991c28ce52
# 	SNAP Locations                                    756f86b351fb48db82393e12dd8a220a
#
#
# Farmers Markets Buffer 10 20 50
# ******************************************************************************************
# 	Farmers Markets - farmersmarkets                  9bd22b77a13649c49148489b3d958bc0
# 	Buffer of Farmers Markets 10 20 50 - Buffered     0c050e4689754e10b2fca30eddccc40c
#
#
# Map of Ranchers with Video
# ******************************************************************************************
# 	ranchers                                          678253ac417d45b0b84a9233df465c8b
#
#
# AFCEA PlugFest West 2015
# ******************************************************************************************
# 	RangeFans                                         stream_7574
# 	TechNetEntiites                                   stream_6485
# 	Hurricanes Active                                 017f6d57c4b74974886ce9e5d08a9f56
# 	IEM WMS Service                                   61b24d3148224738aeb323ffa69b5337
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	Augusta - RangeFans                               Augusta_6473
# 	UAVPaths - UAVPaths                               UAVPaths_4015
# 	Augusta - Connectivity                            Augusta_9278
# 	Augusta - CommNodes                               Augusta_9993
# 	CPTs                                              Augusta_780
#
#
# Drones
# ******************************************************************************************
# 	drones - airports5miles                           drones_9930
# 	Drone                                             stream_4296
# 	DroneAlert                                        stream_1230
#
#
# Zonar-Columbia-MS
# ******************************************************************************************
# 	ZonarEventSegment                                 stream_5512
# 	ZonarEvent                                        stream_5681
# 	ZonarSystemsCurrentLoc                            stream_8359
#
#
# Syphilis By Illinois County
# ******************************************************************************************
# 	Syphilis Cases by County                          99513152ee1d45eea89a2987171efe88
# 	Specialty Clinic                                  20a29db43f11408db2e6088b30740363
# 	Condom Distribution Site                          dc1c98a0b9414368b63b1e76770e9b1d
#
#
# RTDevice
# ******************************************************************************************
# 	RTDevice - RTDevice                               RTDevice_6849
# 	AssetMonitor - GeoFences                          AssetMonitor_4036
# 	AssetMonitor - Alerts                             AssetMonitor_341
# 	RTDeviceHistory - RTDeviceHistory                 RTDeviceHistory_9354
#
#
# Neighborhood Crime Map
# ******************************************************************************************
# 	San Diego Neighborhoods                           e87ccd2b7912450ba5d138044849640d
# 	San Diego Crime - 2103                            6d93ec53c68f4a269e85e433c761c6c0
#
#
# Wearable World Invent
# ******************************************************************************************
# 	SFO_Network                                       21b7ed5d4e3b4abc970dbbeb2b6de873
# 	SFO_Area_Buildings - BuildingFootprint_1K         84189e3d83e24325a3f32368dc12e168
# 	Spaces_T2 - SFO Spaces                            80828bbbe89a4079b6780e218336118b
# 	SFO_Area_POIs - FacilitySitePoint_Label_1K        bebc06442aa040c587c3424d683f4ae2
# 	SFO_Network - Transportation_ND_Junctions         57cf7240e5e3444e9836064757cd6285
# 	SFO_Network - RoadCenterline_Ground_and_Above     57cf7240e5e3444e9836064757cd6285
# 	Roads - RoadCenterline_Ground_and_Above_1K        a946d01294d34d5183f3e0aebfd7e464
#
#
# tteesstt
# ******************************************************************************************
# GTFS RealTime Demo
# ******************************************************************************************
# 	Sound Transit Vehicles                            stream_2728
#
#
# United States Fossil Fuel Consumption
# ******************************************************************************************
# 	Excel Layer                                       4d6b3d72238d4a8fba2a9dd30a6e523a
#
#
# LA Bus Dev Summit 2018
# ******************************************************************************************
# 	LABusHistorical-FS                                LABusHistorical_3432
# 	LABus                                             LABus_2457
#
#
# Boston Marathon 2014
# ******************************************************************************************
# 	BostonMarathon2014 - SplitLineFeatures            BostonMarathon2014_3346
# 	BostonMarathon2014 - TimingMatCount               BostonMarathon2014_2430
# 	BostonMarathon2014 - TimingMatLocations           BostonMarathon2014_3631
# 	BostonMarathon2014 - Runners                      BostonMarathon2014_7967
#
#
# TechNet Augusta PlugFest-3
# ******************************************************************************************
# 	Hurricanes Active                                 017f6d57c4b74974886ce9e5d08a9f56
# 	IEM WMS Service                                   61b24d3148224738aeb323ffa69b5337
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	catalinaHoneycomb - Catalina                      catalinaHoneycomb_3838
# 	catalinaHoneycomb - CatalinaHex                   catalinaHoneycomb_6184
# 	RangeFans                                         stream_5649
# 	UAVPaths - UAVPaths                               UAVPaths_4015
# 	Augusta - Connectivity                            Augusta_9278
# 	Augusta - CommNodes                               Augusta_9993
# 	CPTs                                              Augusta_780
#
#
# Snow Removal Operation
# ******************************************************************************************
# 	SandyPlowedStatus - Plowed Status                 SandyPlowedStatus_9559
# 	Vehicles                                          Vehicles_9835
# 	VehiclesLatest                                    VehiclesLatest_5521
#
#
# Illinois Tanning Facility Hotspots
# ******************************************************************************************
# 	Illinois Tanning Hot Spots                        c6dea27ae029425399427a36d24014d5
# 	IDPH_Tanning_Facilities                           8f871b55cdb04d96b6c1345e817a8a5c
#
#
# Illinois Body Art Facilities
# ******************************************************************************************
# 	colIDPH FDD Body Art Facilities List 102413       featColl_133
#
#
# TechNet Augusta PlugFest
# ******************************************************************************************
# 	Hurricanes Active                                 017f6d57c4b74974886ce9e5d08a9f56
# 	IEM WMS Service                                   61b24d3148224738aeb323ffa69b5337
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	catalinaHoneycomb - Catalina                      catalinaHoneycomb_3838
# 	catalinaHoneycomb - CatalinaHex                   catalinaHoneycomb_6184
# 	Augusta - RangeFans                               Augusta_6473
# 	UAVPaths - UAVPaths                               UAVPaths_4015
# 	Augusta - Connectivity                            Augusta_9278
# 	Augusta - CommNodes                               Augusta_9993
# 	CPTs                                              Augusta_780
#
#
# AFCEA West PlugFest 2014 Long Beach Scenario-Copy
# ******************************************************************************************
# 	National_Bridge_Inventory_2                       National_Bridge_Inventory_2_4985
# 	plume                                             plume_1486
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	IABCounty - Counties                              IABCounty_2446
# 	RadarAIS - RadarAIS                               RadarAIS_7963
# 	Shelters - Shelters                               Shelters_9728
# 	TrafficSignals - TrafficSignals                   TrafficSignals_3621
# 	CommuterLink Traffic Cameras                      255c63989337466a9a3be98f0afe7a79
#
#
# FlightAware-TSA
# ******************************************************************************************
# 	TSAFlightAware                                    TSAFlightAware_7763
#
#
# SFO-FlightAware Historical
# ******************************************************************************************
# 	FAA Sectional Charts - Map Service                9ff892e372e84a8eb23c866865b2e6cc
# 	Watches, Warnings and Advisories NOAA nowCOAS     fd9845227db745a28f2fb11956d216d2
# 	Recent Weather Radar Imagery                      da53700b1f324cc685c4d3bcc00c12fc
# 	FlightAwarePosition                               FlightAwarePosition_9096
# 	FlightAwarePositionHistorical                     FlightAwarePositionHistorical_4055
# 	sfo - metar                                       sfo_4021
# 	airep                                             airep_2829
#
#
# ArcGIS Online Public Senior Content
# ******************************************************************************************
# 	USA Census 65 and Over Population                 a2446f4c7f7c4008a9e7a6607e766a09
# 	USA HHS Primary Care Providers                    3e64b767289446cdb3a3124126b3c863
# 	USA HHS Environmental Quality                     95c655c6e964401c900646ef1ca6d451
# 	USA Supermarket Access                            752578ccc3f046beaca78661d277ea8a
# 	Healthy Food Access                               cc5336bd76bf4758a2a9b1852ee032ce
# 	Senior_Services_-_New_Orleans                     37ce33001b754a8d850402b37e72c1b9
# 	US_Seniors - SeniorsByCounty                      3696ae4e80bd4b6ea50f9fa70fdeed58
# 	US_Seniors - SeniorsByState                       3696ae4e80bd4b6ea50f9fa70fdeed58
# 	USHHS Health Resources Locations - Hospitals      9ba9d3e2b032461a88c17c0a004c1915
# 	USHHS Health Resources Locations - MedicalCen     9ba9d3e2b032461a88c17c0a004c1915
# 	USHHS Health Resources Locations - FederallyQ     9ba9d3e2b032461a88c17c0a004c1915
# 	USHHS Health Resources Locations - HomeHealth     9ba9d3e2b032461a88c17c0a004c1915
# 	USHHS Health Resources Locations - NursingHom     9ba9d3e2b032461a88c17c0a004c1915
#
#
# Networkfleet Demo
# ******************************************************************************************
# 	NetworkfleetVehicle                               stream_6719
#
#
# FAA Stream Service
# ******************************************************************************************
# 	faa-stream                                        stream_9118
#
#
# JFX FlightAware Surface Movement
# ******************************************************************************************
#
#
# Kmoni-Bonsai
# ******************************************************************************************
# 	kv-kmoni-bonsai                                   kv-kmoni-bonsai_3172
# 	kv-kmoni-bonsai                                   kv-kmoni-bonsai_8696
#
#
# TechNet Augusta PlugFest-2
# ******************************************************************************************
# 	Hurricanes Active                                 017f6d57c4b74974886ce9e5d08a9f56
# 	IEM WMS Service                                   61b24d3148224738aeb323ffa69b5337
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	Augusta - Connectivity                            Augusta_9278
# 	Augusta - CommNodes                               Augusta_9993
#
#
# Food Hub Buffers
# ******************************************************************************************
# 	Farmers Markets - farmersmarkets                  9bd22b77a13649c49148489b3d958bc0
# 	Buffer of Farmers Markets 10 20 50 - Buffered     0c050e4689754e10b2fca30eddccc40c
#
#
# Alameda Networkfleet-GeoEvent Demo-3
# ******************************************************************************************
# 	AssetMonitor - GeoFences                          AssetMonitor_3673
# 	UrbanShieldGeoFences - geofences300ft             UrbanShieldGeoFences_6020
# 	UrbanShieldGeoFences - geofences50ft              UrbanShieldGeoFences_6566
# 	UrbanShieldGeoFences - geofenceCenters            UrbanShieldGeoFences_4481
# 	AssetMonitor - Alerts                             AssetMonitor_3506
# 	NetworkfleetHistorical - NetworkcarHistorical     NetworkfleetHistorical_421
# 	Networkfleet - Networkcar                         Networkfleet_2497
# 	NetworkfleetAgency - NetworkcarAgency             NetworkfleetAgency_6421
#
#
# Realtime Device Tracking
# ******************************************************************************************
# 	Devices                                           stream_3988
# 	SFO                                               SFO_8520
#
#
# Illinois Climate Change Data
# ******************************************************************************************
# 	ClimateData - Climate: % Age > 75                 64c60a729c0440f59b2e991680d56ab4
# 	ClimateData - Aquifers                            64c60a729c0440f59b2e991680d56ab4
# 	ClimateData - TornadoTracks by Year               64c60a729c0440f59b2e991680d56ab4
#
#
# TeenPregnancyHotSpots-Copy
# ******************************************************************************************
# 	Hot Spots for Teen Mothers                        6f93c95f46134dec9ed72b7ea101773a
# 	IDPH Pregnancy Termination Center                 8732f0584698440d85cc74e97727ebae
# 	Speciality_Clinic                                 20a29db43f11408db2e6088b30740363
# 	Condom Distribution Site                          dc1c98a0b9414368b63b1e76770e9b1d
#
#
# Public Garage or Parking Lot
# ******************************************************************************************
# 	Parking Garage - Public Garage or Parking Lot     3999234de8224a5f88f631d6346af179
#
#
# Phishing
# ******************************************************************************************
# 	map_data                                          9cae8f6ceb254b8daacbd2df0bab120b
# 	map_data                                          csv_9057
#
#
# AFCEA West PlugFest 2014
# ******************************************************************************************
# 	USA Transmission Lines                            918e6d9b1cc84d15ba13e911d18a0c5e
# 	National_Bridge_Inventory_2                       National_Bridge_Inventory_2_4985
# 	plume                                             plume_1486
# 	IEM WMS Service                                   61b24d3148224738aeb323ffa69b5337
# 	World Traffic Service                             ff11eb5b930b4fabba15c47feb130de4
# 	RadarAIS - RadarAIS                               RadarAIS_7963
# 	IABCounty - Counties                              IABCounty_2446
# 	Shelters - Shelters                               Shelters_9728
# 	TrafficSignals - TrafficSignals                   TrafficSignals_3621
# 	TrafficCams - Camera Locations                    TrafficCams_2320
# 	SoftwareAG - SignData                             SoftwareAG_5420
# 	SoftwareAG - LoginAttempts                        SoftwareAG_3134
# 	FlightMonitor - GeoFences                         FlightMonitor_7954
# 	FlightMonitor - Alerts                            FlightMonitor_653
# 	FlightTrack - Flight Track                        FlightTrack_968
#
#
# National Bridge Inventory Map
# ******************************************************************************************
# 	National Bridge Inventory 2013                    29062a6f3c5a40848da955afcabc52d7
#
#
# Esri Campus Geofence Notification
# ******************************************************************************************
# 	Campus_Viewer_20160919_WFL - Building             Campus_Viewer_20160919_WFL_7671
# 	Campus_Viewer_20160918_b_WFL - Building Floor     Campus_Viewer_20160918_b_WFL_8845
# 	Campus_Viewer_20160919_WFL - Spaces               Campus_Viewer_20160919_WFL_4539
# 	Campus_Viewer_20160919_WFL - Gate                 Campus_Viewer_20160919_WFL_2559
# 	EsriEmployeeLocation                              stream_5273
# 	EsriEmployeeInfo                                  stream_5060
# 	EsriGeoFence                                      stream_3538
#
#
# NYC Attractios
# ******************************************************************************************
# 	NYC sites of interest                             38d8072d2b344a81995da30eee3ce447
# 	Attractions                                       mapNotes_6705

# %%
id_of_interest = '20a29db43f11408db2e6088b30740363'

# %%
lyr_itm = g.content.get(id_of_interest)
lyr = lyr_itm.layers[0]
print("{} is in the following Web Maps:".format(lyr.properties.name))
print("{:-<50}".format(""))
lyr = None
for wm in wmaps:
     raw_data = wm.get_data()
     lyrs = raw_data['operationalLayers']
     for lyr in lyrs:
        if 'itemId' in lyr.keys() and lyr['itemId'] == id_of_interest:
            print("\t" + wm.title)
# Out:
# Speciality_Clinic is in the following Web Maps:
# --------------------------------------------------
# 	Chlamydia By Illinois County
# 	Gonorrhea By Illinois County
# 	Speciality Clinic-Copy
# 	STITPCombo
# 	TeenPregnancyHotSpots
# 	Syphilis By Illinois County
# 	TeenPregnancyHotSpots-Copy
