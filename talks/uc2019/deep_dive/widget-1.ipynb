# %%
from arcgis.gis import GIS
from arcgis import geocoding
gis = GIS("https://www.arcgis.com", "DavidJVitale")
# Out:
# Enter password: ········

# %%
usa_map.rotation = 180

# %%
usa_map = gis.map('USA', zoomlevel=4)  # you can specify the zoom level when creating a map
usa_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=4.0)
# <div class="map-static-img-preview-38d96323-f346-4e82-bc5d-e32e93f6fa4b"><img src=""></img></div>

# %% [markdown]
# ## Add web layers from item

# %%
from arcgis.gis import *
item = gis.content.get('2158ce05955d4c529636b9fa0943193f')
usa_map.add_layer(item, {"renderer" : "ClassedColorRenderer",
                         "field_name" : "TOTPOP10",
                         "opacity": 0.7})
item
# Out:
# <Item title:"Race Demographics in the 2010 Census" type:Feature Layer Collection owner:Federal_User_Community>

# %% [markdown]
# ### Add Layer from CSV

# %%
import pandas as pd
df = pd.read_csv('data/chennai-rainfall.csv')
df.head()
# Out:
#   WEATHER STATION                    LOCATION  RAINFALL
# 0        TAMBARAM        TAMBARAM, TAMIL NADU        49
# 1  CHEMBARABAKKAM  CHEMBARABAKKAM, TAMIL NADU        47
# 2      MARAKKANAM      MARAKKANAM, TAMIL NADU        42
# 3    CHENGALPATTU    CHENGALPATTU, TAMIL NADU        39
# 4         PONNERI         PONNERI, TAMIL NADU        39

# %%
# Create an arcgis.features.FeatureCollection object by importing the pandas dataframe with an address field
rainfall = gis.content.import_data(df, {"Address" : "LOCATION"})
rainfall

# %%
tamil_map = gis.map("Tamil Nadu", zoomlevel=7)
tamil_map.add_layer(rainfall, { "renderer":"ClassedSizeRenderer",
                                 "field_name":"RAINFALL" })

tamil_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=7.0)
# <div class="map-static-img-preview-d26524e0-4329-40c2-bf57-d937431d7378"><img src=""></img></div>

# %% [markdown]
# ### Save map

# %%
item_properties={'title':'Rainfall in Tamil',
                    'snippet': 'Jupyter notebook widget saved as a web map',
                    'tags':['automation', 'python']}

# %%
webmap_item = tamil_map.save(item_properties)
webmap_item
# Out:
# <Item title:"Rainfall in Tamil" type:Web Map owner:DavidJVitale>

# %% [markdown]
# # Basemaps

# %%
from arcgis.gis import GIS
map4 = gis.map('New York City, NY')
map4
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-305361af-f73d-432d-8bf2-eb7ff9a3a21b"><img src=""></img></div>

# %%
import time

for basemap in map4.basemaps:
    map4.basemap = basemap
    print(basemap)
    time.sleep(3)
# Out:
# dark-gray
# dark-gray-vector
# gray
# gray-vector
# hybrid
# national-geographic
# oceans
# osm
# satellite
# streets
# streets-navigation-vector
# streets-night-vector
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-94d092845abe> in <module>
#       4     map4.basemap = basemap
#       5     print(basemap)
# ----> 6     time.sleep(3)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Asyncronous Widget Behavior

# %%
map = gis.map('San Diego convention center, San Diego, CA', 16)
map
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=16.0)
# <div class="map-static-img-preview-0fdcdb41-50ec-4603-900a-b2307300337b"><img src=""></img></div>
# 315 J St, San Diego, California, 92101
# 500-598 1st Ave, San Diego, California, 92101

# %%
def find_addr(map, g):
    try:
        map.draw(g)
        geocoded = geocoding.reverse_geocode(g)
        print(geocoded['address']['Match_addr'])
    except Exception as e:
        print("Couldn't match address. Try another place...")
        print(e)

# %%
map.on_click(find_addr)
