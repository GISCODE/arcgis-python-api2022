# %% [markdown]
# # An introduction to geocoding
#
# Geocoders are tools to which you pass in an address / place of interest and it gives back the coordinates of that place.
#
# The **`arcgis.geocoding`** module provides types and functions for geocoding, batch geocoding and reverse geocoding.

# %%
from arcgis.gis import GIS
from arcgis import geocoding
from getpass import getpass

# %%
gis = GIS("http://www.arcgis.com", "arcgis_python", "P@ssword123")

# %% [markdown]
# ## Geocoding addresses
# All geocoding operations are handled by `geocode()` function. It can geocode
#
#  1. single line address
#  2. multi field address
#  3. points of interest
#  4. administrative place names
#  5. postal codes

# %%
results = geocoding.geocode('San Diego, CA')
results
# Out:
# [{'address': 'San Diego, California',
#   'location': {'x': -117.16170999999997, 'y': 32.71568000000008},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego, California',
#    'LongLabel': 'San Diego, CA, USA',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'Locality',
#    'Type': 'City',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, California',
#    'Phone': '',
#    'URL': '',
#    'Rank': 2,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.16170999999997,
#    'Y': 32.71568000000008,
#    'DisplayX': -117.16170999999997,
#    'DisplayY': 32.71568000000008,
#    'Xmin': -117.40070999999998,
#    'Xmax': -116.92270999999997,
#    'Ymin': 32.47668000000008,
#    'Ymax': 32.954680000000074,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.40070999999998,
#    'ymin': 32.47668000000008,
#    'xmax': -116.92270999999997,
#    'ymax': 32.954680000000074}},
#  {'address': 'San Diego, Carabobo',
#   'location': {'x': -67.95480999999995, 'y': 10.257310000000075},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego, Carabobo',
#    'LongLabel': 'San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'Locality',
#    'Type': 'City',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 8.51,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': '',
#    'MetroArea': '',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.95480999999995,
#    'Y': 10.257310000000075,
#    'DisplayX': -67.95480999999995,
#    'DisplayY': 10.257310000000075,
#    'Xmin': -68.02080999999995,
#    'Xmax': -67.88880999999995,
#    'Ymin': 10.191310000000074,
#    'Ymax': 10.323310000000076,
#    'ExInfo': ''},
#   'extent': {'xmin': -68.02080999999995,
#    'ymin': 10.191310000000074,
#    'xmax': -67.88880999999995,
#    'ymax': 10.323310000000076}},
#  {'address': 'San-Diego',
#   'location': {'x': -117.19743999999997, 'y': 32.732350000000054},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'M',
#    'Score': 100,
#    'Match_addr': 'San-Diego',
#    'LongLabel': 'San-Diego, San Diego, CA, USA',
#    'ShortLabel': 'San-Diego',
#    'Addr_type': 'POI',
#    'Type': 'Airport',
#    'PlaceName': 'San-Diego',
#    'Place_addr': 'San Diego, California',
#    'Phone': '',
#    'URL': '',
#    'Rank': 9,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': '',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.19743999999997,
#    'Y': 32.732350000000054,
#    'DisplayX': -117.19743999999997,
#    'DisplayY': 32.732350000000054,
#    'Xmin': -117.22243999999998,
#    'Xmax': -117.17243999999997,
#    'Ymin': 32.707350000000055,
#    'Ymax': 32.75735000000005,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.22243999999998,
#    'ymin': 32.707350000000055,
#    'xmax': -117.17243999999997,
#    'ymax': 32.75735000000005}},
#  {'address': 'San-Diego, San Diego, California',
#   'location': {'x': -117.15725999999995, 'y': 32.71533000000005},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San-Diego, San Diego, California',
#    'LongLabel': 'San-Diego, San Diego, CA, USA',
#    'ShortLabel': 'San-Diego',
#    'Addr_type': 'Locality',
#    'Type': 'City',
#    'PlaceName': 'San-Diego',
#    'Place_addr': 'San Diego, California',
#    'Phone': '',
#    'URL': '',
#    'Rank': 10,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': '',
#    'Subregion': 'San Diego',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.15725999999995,
#    'Y': 32.71533000000005,
#    'DisplayX': -117.15725999999995,
#    'DisplayY': 32.71533000000005,
#    'Xmin': -117.39525999999995,
#    'Xmax': -116.91925999999995,
#    'Ymin': 32.47733000000005,
#    'Ymax': 32.95333000000005,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.39525999999995,
#    'ymin': 32.47733000000005,
#    'xmax': -116.91925999999995,
#    'ymax': 32.95333000000005}},
#  {'address': 'San Diego, San Roque, Cádiz, Andalucía',
#   'location': {'x': -5.256909999999948, 'y': 36.31313000000006},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego, San Roque, Cádiz, Andalucía',
#    'LongLabel': 'San Diego, San Roque, Cádiz, Andalucía, ESP',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'Locality',
#    'Type': 'Village',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Roque, Cádiz, Andalucía',
#    'Phone': '',
#    'URL': '',
#    'Rank': 15,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'San Diego',
#    'District': '',
#    'City': 'San Roque',
#    'MetroArea': '',
#    'Subregion': 'Cádiz',
#    'Region': 'Andalucía',
#    'RegionAbbr': 'Andalucía',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'ESP',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -5.256909999999948,
#    'Y': 36.31313000000006,
#    'DisplayX': -5.256909999999948,
#    'DisplayY': 36.31313000000006,
#    'Xmin': -5.266909999999948,
#    'Xmax': -5.246909999999948,
#    'Ymin': 36.30313000000006,
#    'Ymax': 36.323130000000056,
#    'ExInfo': ''},
#   'extent': {'xmin': -5.266909999999948,
#    'ymin': 36.30313000000006,
#    'xmax': -5.246909999999948,
#    'ymax': 36.323130000000056}},
#  {'address': 'San Diego County, California',
#   'location': {'x': -116.75640998399996, 'y': 33.03389888100003},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego County, California',
#    'LongLabel': 'San Diego County, CA, USA',
#    'ShortLabel': 'San Diego County',
#    'Addr_type': 'Locality',
#    'Type': 'County',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'California',
#    'Phone': '',
#    'URL': '',
#    'Rank': 17.1,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': '',
#    'MetroArea': '',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -116.75640998399996,
#    'Y': 33.03389888100003,
#    'DisplayX': -116.75640998399996,
#    'DisplayY': 33.03389888100003,
#    'Xmin': -117.63040998399995,
#    'Xmax': -115.88240998399996,
#    'Ymin': 32.159898881000025,
#    'Ymax': 33.90789888100003,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.63040998399995,
#    'ymin': 32.159898881000025,
#    'xmax': -115.88240998399996,
#    'ymax': 33.90789888100003}},
#  {'address': 'San Diego',
#   'location': {'x': -6.3511100766056, 'y': 36.77962002553528},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Calle Carril de San Diego 38, 11540, Sanlúcar de Barrameda, Cádiz, Andalucía, ESP',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Bakery',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Calle Carril de San Diego 38, 11540, Sanlúcar de Barrameda, Cádiz, Andalucía',
#    'Phone': '+34 956369108',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '38',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': 'L',
#    'StPreDir': '',
#    'StPreType': 'Calle',
#    'StName': 'Carril de San Diego',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Calle Carril de San Diego 38',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': 'Sanlúcar de Barrameda',
#    'City': 'Sanlúcar de Barrameda',
#    'MetroArea': '',
#    'Subregion': 'Cádiz',
#    'Region': 'Andalucía',
#    'RegionAbbr': 'Andalucía',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '11540',
#    'PostalExt': '',
#    'Country': 'ESP',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -6.3511100766056,
#    'Y': 36.77962002553528,
#    'DisplayX': -6.35113999999993,
#    'DisplayY': 36.779630000000054,
#    'Xmin': -6.35613999999993,
#    'Xmax': -6.34613999999993,
#    'Ymin': 36.77463000000005,
#    'Ymax': 36.78463000000006,
#    'ExInfo': ''},
#   'extent': {'xmin': -6.35613999999993,
#    'ymin': 36.77463000000005,
#    'xmax': -6.34613999999993,
#    'ymax': 36.78463000000006}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96510999999998, 'y': 10.221920000000068},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Grocery',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96510999999998,
#    'Y': 10.221920000000068,
#    'DisplayX': -67.96510999999998,
#    'DisplayY': 10.221920000000068,
#    'Xmin': -67.97010999999998,
#    'Xmax': -67.96010999999999,
#    'Ymin': 10.216920000000068,
#    'Ymax': 10.226920000000069,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.97010999999998,
#    'ymin': 10.216920000000068,
#    'xmax': -67.96010999999999,
#    'ymax': 10.226920000000069}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96510999999998, 'y': 10.221920000000068},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Pharmacy',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96510999999998,
#    'Y': 10.221920000000068,
#    'DisplayX': -67.96510999999998,
#    'DisplayY': 10.221920000000068,
#    'Xmin': -67.97010999999998,
#    'Xmax': -67.96010999999999,
#    'Ymin': 10.216920000000068,
#    'Ymax': 10.226920000000069,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.97010999999998,
#    'ymin': 10.216920000000068,
#    'xmax': -67.96010999999999,
#    'ymax': 10.226920000000069}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96346999999997, 'y': 10.208500000000072},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Grocery',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96346999999997,
#    'Y': 10.208500000000072,
#    'DisplayX': -67.96346999999997,
#    'DisplayY': 10.208500000000072,
#    'Xmin': -67.96846999999997,
#    'Xmax': -67.95846999999998,
#    'Ymin': 10.203500000000071,
#    'Ymax': 10.213500000000073,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.96846999999997,
#    'ymin': 10.203500000000071,
#    'xmax': -67.95846999999998,
#    'ymax': 10.213500000000073}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96511999999996, 'y': 10.222920000000045},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Shopping Center',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96511999999996,
#    'Y': 10.222920000000045,
#    'DisplayX': -67.96511999999996,
#    'DisplayY': 10.222920000000045,
#    'Xmin': -67.97011999999995,
#    'Xmax': -67.96011999999996,
#    'Ymin': 10.217920000000044,
#    'Ymax': 10.227920000000045,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.97011999999995,
#    'ymin': 10.217920000000044,
#    'xmax': -67.96011999999996,
#    'ymax': 10.227920000000045}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96749999999997, 'y': 10.194800000000043},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Calle 102, San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Hotel',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Calle 102, San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': 'Calle',
#    'StName': '102',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Calle 102',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96749999999997,
#    'Y': 10.194800000000043,
#    'DisplayX': -67.96749999999997,
#    'DisplayY': 10.194800000000043,
#    'Xmin': -67.97249999999997,
#    'Xmax': -67.96249999999998,
#    'Ymin': 10.189800000000043,
#    'Ymax': 10.199800000000044,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.97249999999997,
#    'ymin': 10.189800000000043,
#    'xmax': -67.96249999999998,
#    'ymax': 10.199800000000044}},
#  {'address': 'San Diego',
#   'location': {'x': -67.95372999999995, 'y': 10.256020000000035},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Avenida Sucre, San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Church',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Avenida Sucre, San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': 'Avenida',
#    'StName': 'Sucre',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Avenida Sucre',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.95372999999995,
#    'Y': 10.256020000000035,
#    'DisplayX': -67.95372999999995,
#    'DisplayY': 10.256020000000035,
#    'Xmin': -67.95872999999995,
#    'Xmax': -67.94872999999995,
#    'Ymin': 10.251020000000034,
#    'Ymax': 10.261020000000036,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.95872999999995,
#    'ymin': 10.251020000000034,
#    'xmax': -67.94872999999995,
#    'ymax': 10.261020000000036}},
#  {'address': 'California St, San Diego, California, 92101',
#   'location': {'x': -117.17192553524667, 'y': 32.7275932796634},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'California St, San Diego, California, 92101',
#    'LongLabel': 'California St, San Diego, CA, 92101, USA',
#    'ShortLabel': 'California St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92101',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'California',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'California St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Midway District',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92101',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.17192553524667,
#    'Y': 32.7275932796634,
#    'DisplayX': -117.17192553524667,
#    'DisplayY': 32.7275932796634,
#    'Xmin': -117.17292553524668,
#    'Xmax': -117.17092553524667,
#    'Ymin': 32.726593279663405,
#    'Ymax': 32.7285932796634,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.17292553524668,
#    'ymin': 32.726593279663405,
#    'xmax': -117.17092553524667,
#    'ymax': 32.7285932796634}},
#  {'address': 'California St, San Diego, California, 92101',
#   'location': {'x': -117.18068953162087, 'y': 32.74010467588971},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'California St, San Diego, California, 92101',
#    'LongLabel': 'California St, San Diego, CA, 92101, USA',
#    'ShortLabel': 'California St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92101',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'California',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'California St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Middletown',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92101',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.18068953162087,
#    'Y': 32.74010467588971,
#    'DisplayX': -117.18068953162087,
#    'DisplayY': 32.74010467588971,
#    'Xmin': -117.18168953162088,
#    'Xmax': -117.17968953162087,
#    'Ymin': 32.73910467588971,
#    'Ymax': 32.74110467588971,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.18168953162088,
#    'ymin': 32.73910467588971,
#    'xmax': -117.17968953162087,
#    'ymax': 32.74110467588971}},
#  {'address': 'California St, San Diego, California, 92110',
#   'location': {'x': -117.184975344957, 'y': 32.744994140771496},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'California St, San Diego, California, 92110',
#    'LongLabel': 'California St, San Diego, CA, 92110, USA',
#    'ShortLabel': 'California St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92110',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'California',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'California St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Mission Hills',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92110',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.184975344957,
#    'Y': 32.744994140771496,
#    'DisplayX': -117.184975344957,
#    'DisplayY': 32.744994140771496,
#    'Xmin': -117.185975344957,
#    'Xmax': -117.18397534495699,
#    'Ymin': 32.7439941407715,
#    'Ymax': 32.745994140771494,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.185975344957,
#    'ymin': 32.7439941407715,
#    'xmax': -117.18397534495699,
#    'ymax': 32.745994140771494}},
#  {'address': 'San Diego Fwy, Camp Pendleton, California, 92055',
#   'location': {'x': -117.3869447261332, 'y': 33.20991452968718},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego Fwy, Camp Pendleton, California, 92055',
#    'LongLabel': 'San Diego Fwy, Camp Pendleton, CA, 92055, USA',
#    'ShortLabel': 'San Diego Fwy',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Fwy, Camp Pendleton, California, 92055',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'Fwy',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego Fwy',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Camp Pendleton',
#    'MetroArea': '',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92055',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.3869447261332,
#    'Y': 33.20991452968718,
#    'DisplayX': -117.3869447261332,
#    'DisplayY': 33.20991452968718,
#    'Xmin': -117.3879447261332,
#    'Xmax': -117.38594472613319,
#    'Ymin': 33.208914529687185,
#    'Ymax': 33.21091452968718,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.3879447261332,
#    'ymin': 33.208914529687185,
#    'xmax': -117.38594472613319,
#    'ymax': 33.21091452968718}},
#  {'address': 'San Diego Ave, Ramona, California, 92065',
#   'location': {'x': -116.88237179204032, 'y': 33.023157872780885},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego Ave, Ramona, California, 92065',
#    'LongLabel': 'San Diego Ave, Ramona, CA, 92065, USA',
#    'ShortLabel': 'San Diego Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Ave, Ramona, California, 92065',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Ramona',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92065',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -116.88237179204032,
#    'Y': 33.023157872780885,
#    'DisplayX': -116.88237179204032,
#    'DisplayY': 33.023157872780885,
#    'Xmin': -116.88337179204032,
#    'Xmax': -116.88137179204031,
#    'Ymin': 33.02215787278089,
#    'Ymax': 33.02415787278088,
#    'ExInfo': ''},
#   'extent': {'xmin': -116.88337179204032,
#    'ymin': 33.02215787278089,
#    'xmax': -116.88137179204031,
#    'ymax': 33.02415787278088}},
#  {'address': 'San Diego St, Spring Valley, California, 91977',
#   'location': {'x': -116.9891696429678, 'y': 32.70609375015952},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego St, Spring Valley, California, 91977',
#    'LongLabel': 'San Diego St, Spring Valley, CA, 91977, USA',
#    'ShortLabel': 'San Diego St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego St, Spring Valley, California, 91977',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'La Presa',
#    'District': '',
#    'City': 'Spring Valley',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '91977',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -116.9891696429678,
#    'Y': 32.70609375015952,
#    'DisplayX': -116.9891696429678,
#    'DisplayY': 32.70609375015952,
#    'Xmin': -116.9901696429678,
#    'Xmax': -116.98816964296779,
#    'Ymin': 32.70509375015952,
#    'Ymax': 32.707093750159515,
#    'ExInfo': ''},
#   'extent': {'xmin': -116.9901696429678,
#    'ymin': 32.70509375015952,
#    'xmax': -116.98816964296779,
#    'ymax': 32.707093750159515}},
#  {'address': 'San Diego Fwy, San Diego, California, 92136',
#   'location': {'x': -117.1098764094998, 'y': 32.67886179888846},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego Fwy, San Diego, California, 92136',
#    'LongLabel': 'San Diego Fwy, San Diego, CA, 92136, USA',
#    'ShortLabel': 'San Diego Fwy',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Fwy, San Diego, California, 92136',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'Fwy',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego Fwy',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92136',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.1098764094998,
#    'Y': 32.67886179888846,
#    'DisplayX': -117.1098764094998,
#    'DisplayY': 32.67886179888846,
#    'Xmin': -117.11087640949981,
#    'Xmax': -117.1088764094998,
#    'Ymin': 32.677861798888465,
#    'Ymax': 32.67986179888846,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.11087640949981,
#    'ymin': 32.677861798888465,
#    'xmax': -117.1088764094998,
#    'ymax': 32.67986179888846}}]

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# {'address': 'San Diego, California',
#  'location': {'x': -117.16170999999997, 'y': 32.71568000000008},
#  'score': 100,
#  'attributes': {'Loc_name': 'World',
#   'Status': 'T',
#   'Score': 100,
#   'Match_addr': 'San Diego, California',
#   'LongLabel': 'San Diego, CA, USA',
#   'ShortLabel': 'San Diego',
#   'Addr_type': 'Locality',
#   'Type': 'City',
#   'PlaceName': 'San Diego',
#   'Place_addr': 'San Diego, California',
#   'Phone': '',
#   'URL': '',
#   'Rank': 2,
#   'AddBldg': '',
#   'AddNum': '',
#   'AddNumFrom': '',
#   'AddNumTo': '',
#   'AddRange': '',
#   'Side': '',
#   'StPreDir': '',
#   'StPreType': '',
#   'StName': '',
#   'StType': '',
#   'StDir': '',
#   'BldgType': '',
#   'BldgName': '',
#   'LevelType': '',
#   'LevelName': '',
#   'UnitType': '',
#   'UnitName': '',
#   'SubAddr': '',
#   'StAddr': '',
#   'Block': '',
#   'Sector': '',
#   'Nbrhd': '',
#   'District': '',
#   'City': 'San Diego',
#   'MetroArea': 'San Diego Metro Area',
#   'Subregion': 'San Diego County',
#   'Region': 'California',
#   'RegionAbbr': 'CA',
#   'Territory': '',
#   'Zone': '',
#   'Postal': '',
#   'PostalExt': '',
#   'Country': 'USA',
#   'LangCode': 'ENG',
#   'Distance': 0,
#   'X': -117.16170999999997,
#   'Y': 32.71568000000008,
#   'DisplayX': -117.16170999999997,
#   'DisplayY': 32.71568000000008,
#   'Xmin': -117.40070999999998,
#   'Xmax': -116.92270999999997,
#   'Ymin': 32.47668000000008,
#   'Ymax': 32.954680000000074,
#   'ExInfo': ''},
#  'extent': {'xmin': -117.40070999999998,
#   'ymin': 32.47668000000008,
#   'xmax': -116.92270999999997,
#   'ymax': 32.954680000000074}}

# %%
map1 = gis.map('San Diego, CA')
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-f7dec9f2-a45b-4634-beb2-9a3a940e9118"><img src=""></img></div>

# %%
map1.draw(results[0]['location'])

# %% [markdown]
# ### Geocode single line addresses

# %%
r2 = geocoding.geocode('San Diego Convention center')
len(r2)
# Out:
# 20

# %%
[str(r['score']) +"  :  "+ r['attributes']['Match_addr'] for r in r2]
# Out:
# ['100  :  San Diego Convention Center',
#  '100  :  Convention Center',
#  '100  :  San Diego Concourse',
#  '100  :  University Club Atop Symphony Towers',
#  '100  :  San Diego Fashion Week',
#  '100  :  Golden Hall',
#  '100  :  Aztec Student Union',
#  '100  :  Hall H',
#  '100  :  Residence Inn-San Diego',
#  '100  :  San Diego Convention Center C Ent',
#  '100  :  San Diego Convention Center B Ent',
#  '100  :  San Diego Convention Center A Ent',
#  '100  :  San Diego Convention Center D Ent',
#  '100  :  San Diego Convention Center ter Ent',
#  '100  :  San Diego Conv Ctr Mezzanine Ent',
#  '100  :  San Diego Convention Center E Ent',
#  '100  :  San Diego Convention Center F Ent',
#  '100  :  San Diego Convention Center H Ent',
#  '100  :  San Diego Convention Center G Ent',
#  '100  :  SEAT Planners']

# %% [markdown]
# ### Geocode multi field address

# %%
multi_field_address = { 
    "Address" : "111 Harbor Dr",
    "City" : "San Diego",
    "Region" : "CA",
    "Subregion":"San Diego",
    "Postal" : 92103,
    "Country":"USA"
    }
r_multi_fields = geocoding.geocode(multi_field_address)
len(r_multi_fields)
# Out:
# 14

# %% [markdown]
# ## Batch geocoding

# %%
addresses = ["380 New York St, Redlands, CA", 
             "1 World Way, Los Angeles, CA",
             "1200 Getty Center Drive, Los Angeles, CA", 
             "5905 Wilshire Boulevard, Los Angeles, CA",
             "100 Universal City Plaza, Universal City, CA 91608",
             "4800 Oak Grove Dr, Pasadena, CA 91109"]

# %%
results = geocoding.batch_geocode(addresses)

# %%
len(results)
# Out:
# 6

# %%
map5 = gis.map('Los Angeles, CA')
map5
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-63bdf279-aa16-4057-bfc0-1c920f29f6bd"><img src=""></img></div>

# %%
for address in results:
    map5.draw(address['location'])

# %% [markdown]
# ## Reverse geocoding

# %%
reverse_geocode_results = geocoding.reverse_geocode([2.2945, 48.8583])
reverse_geocode_results
# Out:
# {'address': {'Match_addr': 'Salle Gustave Eiffel',
#   'LongLabel': 'Salle Gustave Eiffel, Avenue Gustave Eiffel, 75007, 7e Arrondissement, Paris, Île-de-France, FRA',
#   'ShortLabel': 'Salle Gustave Eiffel',
#   'Addr_type': 'POI',
#   'Type': 'Convention Center',
#   'PlaceName': 'Salle Gustave Eiffel',
#   'AddNum': '',
#   'Address': 'Avenue Gustave Eiffel',
#   'Block': '',
#   'Sector': '',
#   'Neighborhood': 'Gros Caillou',
#   'District': '7e Arrondissement',
#   'City': 'Paris',
#   'MetroArea': '',
#   'Subregion': 'Paris',
#   'Region': 'Île-de-France',
#   'Territory': '',
#   'Postal': '75007',
#   'PostalExt': '',
#   'CountryCode': 'FRA'},
#  'location': {'x': 2.2951599583073303,
#   'y': 48.85784000836726,
#   'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}

# %%
map6 = gis.map('San Diego convention center, San Diego, CA', 16)
map6
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=16.0)
# <div class="map-static-img-preview-35380003-4fb7-4eb6-9250-2861f1c07de3"><img src=""></img></div>
# 275 5th Ave, San Diego, California, 92101

# %%
def find_addr(map6, g):
    try:
        map6.draw(g)
        geocoded = geocoding.reverse_geocode(g)
        print(geocoded['address']['Match_addr'])
    except:
        print("Couldn't match address. Try another place...")

# %%
map6.on_click(find_addr)

# %%
2 +2
